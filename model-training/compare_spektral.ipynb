# %% [markdown]
# General breakdown of the processing steps for embedding BPMN files:
#
#
# IMPORTANT:
# The current model uses an embedding created by 'paraphrase-multilingual-MiniLM-L12-v2' with an embedding dimension of 384.
# Using any other sentence-transformer will result in unexpected behavior, so when using the kerasEmbedder use it toghether with the correct sentence-transformer.
# If using it with mu-search, adjust the 'dims' parameter to the appropriate size.
#
#
# Motivation:
# The goal is to create embeddings for BPMN files that can be used for search, similarity, and clustering tasks.
#
# The embeddings should be able to capture the semantics of the BPMN files, such that similar BPMN files have similar embeddings. The embeddings should be able to capture the structure of the BPMN files, such that BPMN files with similar structures have similar embeddings.
#
# Make semantic search possible: Given a query BPMN file, the system should be able to retrieve similar BPMN files based on the query of the user. User queries can be keywords, key phrases, or natural language queries. Example: "Geef mij alle BPMN diagrammen over het melden van klachten."
#
# Design choices:
# Embedding models have a fixed input size, so we need to preprocess the BPMN files so it fits the input size or we need a way to handle large inputs by splitting them into smaller parts.
# Embedding models do not take the structure of the BPMN diagrams into account, so we need to find a way to encode the structure of the BPMN diagrams into the embeddings.
# We want to create a single embedding for the BPMN file that captures both the semantics and structure of the BPMN file.
# Semantics: The most important information in BPMN files is in the nodes and edges, so we need to extract the nodes and edges from the BPMN files. More specifically, we need to extract the labels of the nodes and edges and additional information. This comes down to 'name' and 'documentation' fields of the nodes and edges.
# To encode the structure of the BPMN diagrams, we can use graph embedding techniques such as Graph Neural Networks (GNNs) or Graph Convolutional Networks (GCNs).
# As these methods expect a graph as input, we need to convert the BPMN diagrams into a graph representation. A great library for this is NetworkX.
# To use the information of the nodes and edges, we need to convert them into numerical vectors. This can be done by using pre-trained embeddings or by training our own embeddings (see RoBERTa-model trained on Lokaal Beslist).
# To create a baseline, we can simply average the embeddings of the nodes and edges to create a single embedding for the BPMN file.
# To create a more advanced model, we can use a GNN or GCN using libraries such as Spektral or DGL.
#
#
# Similarity model specifics:
# The similarity model should be able to calculate the similarity between two BPMN files based on their embeddings.
# The similarity model should be able to rank the BPMN files based on their similarity to a query BPMN file.
# The similarity model should be able to handle large datasets of BPMN files efficiently.
#
#
# Similarity model design:
# The similarity model can be a simple cosine similarity model that calculates the cosine similarity between two embeddings.
# The embedding only needs to be calculated once for each BPMN file and stored within the triplestore.
# Integration with Elasticsearch or other search engines can be used to efficiently retrieve the most similar BPMN files based on the query (BPMN embedding of the source BPMN).
#
#
# Current approach:
# Convert BPMN files to graph representations using NetworkX.
# Create embeddings for the nodes and edges using pre-trained embeddings.
# Use the embeddings as features for a GNN or GCN model to create a single graph embedding for a BPMN file using Spektral.
#
#
# Shortcomings:
# Lack of BPMN files to train our own embeddings and validate the model (similar to search).
# Lack of real user queries to validate the model. For this model, this is the accuracy of the model in retrieving similar BPMN files based on a user query. How well are the suggestions of the model aligned with the expectations of the user?
# Future steps or what should be done next when enough data is available:
# Start gathering information: Gather BPMN files, user interactions with the recommendations, and feedback on the recommendations. Requirements (same as search): It's important to have a large enough dataset of BPMN files with enough variety to train the embeddings and validate the model. E.g., if all the data is about the same process (handling of disputes), the model will not be able to generalize to other processes. It's hard to quantify how much data is needed, but a few hundred BPMN files should be a good start.
# Train our own text embeddings for the nodes and edges using a model such as RoBERTa trained on BPMN files.
# Validate the current Spektral model using the new data.
# Change the architecture of the GNN or GCN model if needed (possibly add more layers, change the activation functions, etc.).
# Merge the two models: There is a lot of overlap between the two models, so it might be possible to merge them into a single model and use the graph embeddings for both tasks.
#
#
# Suggestions:
# Store all search results from mu-search (anonymously) to use as training data, so all types of queries are automatically covered. E.g., store each search request to BPMN-search to gain insights into how users typically structure their queries.
# Store the interactions with the search results to gain insights into how users interact with the search results. E.g., store the retrieved BPMN search results and the interactions. This can be used to train a model to rank the search results based on the interactions of the users.

# %%
import os
import json
from tqdm import tqdm
from library.BPMNGraphEmbedder import BPMNGraphEmbedder
from library.BPMNGraph import BPMNGraph

def process_bpmn_file(graphEmbedder, bpmn_file_path):
    bpmn_graph = BPMNGraph(bpmn_file_path)
    graphEmbedder.process_graph(bpmn_graph, logging=False)
    return bpmn_graph

def process_bpmn_files(graphEmbedder, files):
    all_bpmns = {}

    # Process each BPMN file in the list
    for bpmn_file in tqdm(files):
        # Check if the file has .bpmn extension
        if bpmn_file.endswith('.bpmn'):
            bpmn_graph = process_bpmn_file(graphEmbedder, bpmn_file)
            all_bpmns[bpmn_file.split("\\")[-1]] = bpmn_graph

    return all_bpmns

def process_bpmn_files_in_folders(folders):
    graphEmbedder = BPMNGraphEmbedder()
    sentence_embedder = graphEmbedder.get_embedding_model()
    all_bpmns = {}

    for folder in folders:
        files = os.listdir(folder)
        folder_bpmns = process_bpmn_files(graphEmbedder, files)
        all_bpmns.update(folder_bpmns)

    return all_bpmns, sentence_embedder

def create_samples(comparisons, all_bpmns):
    samples = []

    # example of a comparison: {'source_bpmn_id': '01_-_Vorbereitung_Warenversand_e29ad857608345f4a3c8ee5eefc44129.bpmn', 'source_class': '01-Dispatch-of-goods', 'target_bpmn_id': '01_-_Vorbereitung_Warenversand_e29ad857608345f4a3c8ee5eefc44129.bpmn', 'target_class': '01-Dispatch-of-goods', 'similarity': 1.0, 'normalized_similarity': 1.0}
    for comparing in comparisons:
        source_bpmn_id = comparing.get("source_bpmn_id")
        target_bpmn_id = comparing.get("target_bpmn_id")
        similarity = comparing.get("similarity")

        source_bpmn = all_bpmns.get(source_bpmn_id)
        target_bpmn = all_bpmns.get(target_bpmn_id)

        if source_bpmn is None:
            print("BPMN not found: ", source_bpmn_id)
            continue

        if target_bpmn is None:
            print("BPMN not found: ", target_bpmn_id)
            continue
        
        samples.append({
            "query": source_bpmn,
            "target": target_bpmn,
            "score": similarity,
            "query_class": comparing.get("source_class"),
            "target_class": comparing.get("target_class")
        })

    return samples

folders = [
    "data\\camunda\\German\\01-Vorbereitung-des-Warenversands\\02-Ergebnisse\\",
    "data\\camunda\\German\\02-Regressnahme\\02-Ergebnisse\\",
    "data\\camunda\\German\\03-Schufascoring\\02-Ergebnisse\\",
    "data\\camunda\\German\\04-Selbstbedienungsrestaurant\\02-Ergebnisse\\",
    "data\\camunda\\English\\01-Dispatch-of-goods\\02-Results\\",
    "data\\camunda\\English\\02-Recourse\\02-Results\\",
    "data\\camunda\\English\\03-Credit-scoring\\02-Results\\",
    "data\\camunda\\English\\04-Self-service-restaurant\\02-Results\\",
]

#all_bpmns, sentence_embedder = process_bpmn_files_in_folders(folders)

# %%
def read_jsonl(file_path, same_class_check=True):
    data = []
    unique_bpmn_ids = set()

    with open(file_path, 'r') as f:
        for line in f:
            entry = json.loads(line)

            if entry["source_bpmn_id"] not in unique_bpmn_ids:
                unique_bpmn_ids.add("\\".join(entry["source_bpmn_id"].split("\\")[-4:]))
            if entry["target_bpmn_id"] not in unique_bpmn_ids:
                unique_bpmn_ids.add("\\".join(entry["target_bpmn_id"].split("\\")[-4:]))

            if same_class_check:
                similarity = entry["edit_distance"] if entry["source_class"] == entry["target_class"] else 0.0
                normalized_similarity = entry["normalized_edit_distance"] if entry["source_class"] == entry["target_class"] else 0.0
            else:
                similarity = entry["edit_distance"]
                normalized_similarity = entry["normalized_edit_distance"]

            data.append({
                'source_bpmn_id': entry["source_bpmn_id"].split("\\")[-1],
                'source_class': entry["source_class"],
                'target_bpmn_id':entry["target_bpmn_id"].split("\\")[-1],
                'target_class': entry["target_class"],
                "similarity": similarity,
                "normalized_similarity": normalized_similarity
            })

    sorted_data = sorted(data, key=lambda x: x["similarity"], reverse=True)
    return sorted_data, list(unique_bpmn_ids)

compare_file_path = "camunda\\camunda_edit_distance_dataset_01.jsonl"
data, files = read_jsonl(compare_file_path, same_class_check=False)
print(len(data),data[0])
# Out:
# 50688 {'source_bpmn_id': '01_-_Vorbereitung_Warenversand_e29ad857608345f4a3c8ee5eefc44129.bpmn', 'source_class': '01-Dispatch-of-goods', 'target_bpmn_id': '01_-_Vorbereitung_Warenversand_e29ad857608345f4a3c8ee5eefc44129.bpmn', 'target_class': '01-Dispatch-of-goods', 'similarity': 1.0, 'normalized_similarity': 1.0}

# %%
import importlib
from library.BPMNGraphEmbedder import BPMNGraphEmbedder


location = "data\\camunda"
all_bpmns = process_bpmn_files(BPMNGraphEmbedder(),[location+"\\"+file_name for file_name in files] )
#all_bpmns_testing = process_bpmn_files(BPMNGraphEmbedder(),[location+"\\"+file_name for file_name in files[:50]] )
# Out:
#   0%|          | 1/597 [00:03<34:26,  3.47s/it]WARNING:root:Failed to extract keywords from text: 'no'. Likely due to text length being too short.
# WARNING:root:Failed to extract keywords from text: 'no'. Likely due to text length being too short.
#   0%|          | 2/597 [00:05<25:50,  2.61s/it]WARNING:root:Failed to extract keywords from text: 'no'. Likely due to text length being too short.
# WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
#   1%|          | 4/597 [00:09<22:51,  2.31s/it]WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
#   3%|▎         | 15/597 [00:31<18:10,  1.87s/it]WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
#   3%|▎         | 18/597 [00:39<21:53,  2.27s/it]WARNING:root:Failed to extract keywords from text: 'Done'. Likely due to text length being too short.
# WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
#   3%|▎         | 19/597 [00:41<20:53,  2.17s/it]WARNING:root:Failed to extract keywords from text: 'no'. Likely due to text length being too short.
#   4%|▎         | 21/597 [00:44<19:22,  2.02s/it]WARNING:root:Failed to extract keywords from text: 'no'. Likely due to text length being too short.
# WARNING:root:Failed to extract keywords from text: 'always'. Likely due to text length being too short.
#   4%|▍         | 26/597 [00:57<24:00,  2.52s/it]WARNING:root:Failed to extract keywords from text: 'NO'. Likely due to text length being too short.
# WARNING:root:Failed to extract keywords from text: 'NO'. Likely due to text length being too short.
#   6%|▌         | 35/597 [01:15<20:47,  2.22s/it]WARNING:root:Failed to extract keywords from text: 'NO'. Likely due to text length being too short.
#   7%|▋         | 44/597 [01:41<26:13,  2.85s/it]WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
# WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
#   8%|▊         | 47/597 [01:46<19:53,  2.17s/it]WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
# WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
#   9%|▊         | 52/597 [01:57<19:02,  2.10s/it]WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
#   9%|▉         | 55/597 [02:03<18:06,  2.00s/it]WARNING:root:Failed to extract keywords from text: 'no'. Likely due to text length being too short.
#  10%|█         | 62/597 [02:16<15:52,  1.78s/it]WARNING:root:Failed to extract keywords from text: 'I'. Likely due to text length being too short.
#  11%|█         | 64/597 [02:20<17:43,  2.00s/it]WARNING:root:Failed to extract keywords from text: 'no'. Likely due to text length being too short.
#  12%|█▏        | 69/597 [02:32<21:46,  2.47s/it]WARNING:root:Failed to extract keywords from text: 'no'. Likely due to text length being too short.
#  14%|█▎        | 82/597 [03:03<22:18,  2.60s/it]WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
#  15%|█▌        | 90/597 [03:20<19:36,  2.32s/it]WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
#  15%|█▌        | 92/597 [03:23<17:24,  2.07s/it]WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
# WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
#  16%|█▌        | 95/597 [03:29<15:58,  1.91s/it]WARNING:root:Failed to extract keywords from text: 'no'. Likely due to text length being too short.
# WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
#  16%|█▌        | 96/597 [03:31<15:53,  1.90s/it]WARNING:root:Failed to extract keywords from text: 'NO'. Likely due to text length being too short.
# WARNING:root:Failed to extract keywords from text: 'NO'. Likely due to text length being too short.
#  16%|█▌        | 97/597 [03:33<15:52,  1.91s/it]WARNING:root:Failed to extract keywords from text: 'no'. Likely due to text length being too short.
#  17%|█▋        | 99/597 [03:38<19:10,  2.31s/it]WARNING:root:Failed to extract keywords from text: 'no'. Likely due to text length being too short.
#  17%|█▋        | 101/597 [03:41<15:36,  1.89s/it]WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
#  18%|█▊        | 106/597 [03:52<19:07,  2.34s/it]WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
# WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
#  19%|█▉        | 112/597 [04:06<17:10,  2.12s/it]WARNING:root:Failed to extract keywords from text: 'no'. Likely due to text length being too short.
# WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
#  19%|█▉        | 116/597 [04:15<17:45,  2.21s/it]WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
#  20%|██        | 120/597 [04:23<16:51,  2.12s/it]WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
# WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
#  20%|██        | 122/597 [04:28<16:53,  2.13s/it]WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
# WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
#  21%|██        | 124/597 [04:32<17:08,  2.17s/it]WARNING:root:Failed to extract keywords from text: 'no'. Likely due to text length being too short.
#  21%|██        | 125/597 [04:35<18:46,  2.39s/it]WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
# WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
#  21%|██        | 126/597 [04:38<20:59,  2.67s/it]WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
#  21%|██▏       | 127/597 [04:42<22:13,  2.84s/it]WARNING:root:Failed to extract keywords from text: 'no'. Likely due to text length being too short.
# WARNING:root:Failed to extract keywords from text: 'no'. Likely due to text length being too short.
#  21%|██▏       | 128/597 [04:44<21:10,  2.71s/it]WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
# WARNING:root:Failed to extract keywords from text: 'Always'. Likely due to text length being too short.
#  22%|██▏       | 130/597 [04:49<21:26,  2.76s/it]WARNING:root:Failed to extract keywords from text: 'no'. Likely due to text length being too short.
# WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
#  25%|██▍       | 148/597 [05:33<20:31,  2.74s/it]WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
# WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
#  25%|██▌       | 152/597 [05:41<16:59,  2.29s/it]WARNING:root:Failed to extract keywords from text: 'amount'. Likely due to text length being too short.
# WARNING:root:Failed to extract keywords from text: 'no'. Likely due to text length being too short.
# WARNING:root:Failed to extract keywords from text: 'no'. Likely due to text length being too short.
#  26%|██▋       | 158/597 [05:53<14:24,  1.97s/it]WARNING:root:Failed to extract keywords from text: 'no'. Likely due to text length being too short.
# WARNING:root:Failed to extract keywords from text: 'no'. Likely due to text length being too short.
#  27%|██▋       | 160/597 [05:59<19:14,  2.64s/it]WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
#  28%|██▊       | 169/597 [06:19<14:30,  2.03s/it]WARNING:root:Failed to extract keywords from text: 'no'. Likely due to text length being too short.
#  29%|██▉       | 173/597 [06:27<14:36,  2.07s/it]WARNING:root:Failed to extract keywords from text: 'NO'. Likely due to text length being too short.
# WARNING:root:Failed to extract keywords from text: 'NO'. Likely due to text length being too short.
#  29%|██▉       | 176/597 [06:33<14:06,  2.01s/it]WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
# WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
#  31%|███       | 186/597 [06:59<17:58,  2.62s/it]WARNING:root:Failed to extract keywords from text: 'NO'. Likely due to text length being too short.
#  32%|███▏      | 194/597 [07:18<15:40,  2.33s/it]WARNING:root:Failed to extract keywords from text: 'ME'. Likely due to text length being too short.
# WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
# WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
#  36%|███▌      | 212/597 [08:01<14:43,  2.29s/it]WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
# WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
#  36%|███▌      | 216/597 [08:09<12:29,  1.97s/it]WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
#  37%|███▋      | 218/597 [08:13<12:48,  2.03s/it]WARNING:root:Failed to extract keywords from text: 'Done'. Likely due to text length being too short.
# WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
#  38%|███▊      | 225/597 [08:30<16:04,  2.59s/it]WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
#  39%|███▉      | 232/597 [08:46<12:07,  1.99s/it]WARNING:root:Failed to extract keywords from text: 'no'. Likely due to text length being too short.
#  40%|████      | 241/597 [09:06<11:45,  1.98s/it]WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
# WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
#  42%|████▏     | 251/597 [09:30<14:52,  2.58s/it]WARNING:root:Failed to extract keywords from text: 'no'. Likely due to text length being too short.
#  43%|████▎     | 254/597 [09:38<15:51,  2.77s/it]WARNING:root:Failed to extract keywords from text: 'NO'. Likely due to text length being too short.
# WARNING:root:Failed to extract keywords from text: 'NO'. Likely due to text length being too short.
#  43%|████▎     | 255/597 [09:41<15:22,  2.70s/it]WARNING:root:Failed to extract keywords from text: 'no'. Likely due to text length being too short.
# WARNING:root:Failed to extract keywords from text: 'no'. Likely due to text length being too short.
#  44%|████▍     | 263/597 [10:05<19:19,  3.47s/it]WARNING:root:Failed to extract keywords from text: 'no'. Likely due to text length being too short.
#  45%|████▌     | 271/597 [10:23<12:58,  2.39s/it]WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
#  46%|████▌     | 273/597 [10:31<16:22,  3.03s/it]WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
#  46%|████▌     | 275/597 [10:35<13:57,  2.60s/it]WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
# WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
#  49%|████▊     | 290/597 [11:09<10:56,  2.14s/it]WARNING:root:Failed to extract keywords from text: 'A 1'. Likely due to text length being too short.
# WARNING:root:Failed to extract keywords from text: 'A 2'. Likely due to text length being too short.
# WARNING:root:Failed to extract keywords from text: 'A 3'. Likely due to text length being too short.
#  49%|████▉     | 292/597 [11:14<11:58,  2.35s/it]WARNING:root:Failed to extract keywords from text: '.....'. Likely due to text length being too short.
#  51%|█████▏    | 307/597 [11:55<13:38,  2.82s/it]WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
# WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
#  52%|█████▏    | 309/597 [11:59<10:37,  2.22s/it]WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
#  52%|█████▏    | 310/597 [12:00<09:44,  2.04s/it]WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
#  52%|█████▏    | 313/597 [12:07<10:33,  2.23s/it]WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
#  53%|█████▎    | 314/597 [12:10<11:58,  2.54s/it]WARNING:root:Failed to extract keywords from text: 'Amount'. Likely due to text length being too short.
# WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
#  53%|█████▎    | 316/597 [12:14<10:59,  2.35s/it]WARNING:root:Failed to extract keywords from text: 'NO'. Likely due to text length being too short.
# WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
#  53%|█████▎    | 318/597 [12:19<10:49,  2.33s/it]WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
# WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
# WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
#  55%|█████▍    | 328/597 [12:36<08:24,  1.88s/it]WARNING:root:Failed to extract keywords from text: 'NO'. Likely due to text length being too short.
# WARNING:root:Failed to extract keywords from text: 'NO'. Likely due to text length being too short.
#  56%|█████▌    | 332/597 [12:44<08:29,  1.92s/it]WARNING:root:Failed to extract keywords from text: 'amount?'. Likely due to text length being too short.
# WARNING:root:Failed to extract keywords from text: 'no'. Likely due to text length being too short.
#  56%|█████▋    | 337/597 [12:55<10:14,  2.36s/it]WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
#  57%|█████▋    | 339/597 [12:58<08:06,  1.88s/it]WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
# WARNING:root:Failed to extract keywords from text: 'no'. Likely due to text length being too short.
#  57%|█████▋    | 342/597 [13:04<08:14,  1.94s/it]WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
# WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
#  59%|█████▉    | 355/597 [13:30<07:19,  1.82s/it]WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
#  61%|██████    | 363/597 [13:44<07:01,  1.80s/it]WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
# WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
#  63%|██████▎   | 377/597 [14:14<07:37,  2.08s/it]WARNING:root:Failed to extract keywords from text: 'no'. Likely due to text length being too short.
#  64%|██████▍   | 385/597 [14:33<11:12,  3.17s/it]WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
#  65%|██████▌   | 389/597 [14:43<08:46,  2.53s/it]WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
#  65%|██████▌   | 391/597 [14:47<07:09,  2.08s/it]WARNING:root:Failed to extract keywords from text: 'no'. Likely due to text length being too short.
#  66%|██████▌   | 394/597 [14:55<08:18,  2.46s/it]WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
# WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
#  68%|██████▊   | 403/597 [15:17<06:30,  2.01s/it]WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
# WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
#  68%|██████▊   | 406/597 [15:21<05:26,  1.71s/it]WARNING:root:Failed to extract keywords from text: 'Amount?'. Likely due to text length being too short.
# WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
#  68%|██████▊   | 407/597 [15:23<05:18,  1.68s/it]WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
#  70%|███████   | 418/597 [15:47<08:24,  2.82s/it]WARNING:root:Failed to extract keywords from text: 'me'. Likely due to text length being too short.
# WARNING:root:Failed to extract keywords from text: 'no'. Likely due to text length being too short.
# WARNING:root:Failed to extract keywords from text: 'no'. Likely due to text length being too short.
# WARNING:root:Failed to extract keywords from text: 'no'. Likely due to text length being too short.
# WARNING:root:Failed to extract keywords from text: 'no'. Likely due to text length being too short.
#  70%|███████   | 419/597 [15:51<09:09,  3.08s/it]WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
# WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
#  71%|███████   | 422/597 [15:59<07:44,  2.65s/it]WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
#  73%|███████▎  | 434/597 [16:24<05:59,  2.21s/it]WARNING:root:Failed to extract keywords from text: 'no'. Likely due to text length being too short.
#  73%|███████▎  | 436/597 [16:27<05:17,  1.97s/it]WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
#  79%|███████▉  | 474/597 [17:41<03:46,  1.84s/it]WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
# WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
#  81%|████████▏ | 486/597 [18:12<04:40,  2.53s/it]WARNING:root:Failed to extract keywords from text: 'no'. Likely due to text length being too short.
# WARNING:root:Failed to extract keywords from text: 'no'. Likely due to text length being too short.
#  82%|████████▏ | 487/597 [18:14<04:40,  2.55s/it]WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
#  82%|████████▏ | 488/597 [18:16<04:16,  2.35s/it]WARNING:root:Failed to extract keywords from text: 'done'. Likely due to text length being too short.
# WARNING:root:Failed to extract keywords from text: 'done'. Likely due to text length being too short.
#  83%|████████▎ | 494/597 [18:30<04:03,  2.36s/it]WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
#  83%|████████▎ | 498/597 [18:38<03:30,  2.12s/it]WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
#  84%|████████▎ | 499/597 [18:41<03:59,  2.45s/it]WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
#  84%|████████▍ | 502/597 [18:47<03:18,  2.09s/it]WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
#  85%|████████▌ | 509/597 [19:00<03:08,  2.14s/it]WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
#  87%|████████▋ | 518/597 [19:21<02:48,  2.14s/it]WARNING:root:Failed to extract keywords from text: 'no'. Likely due to text length being too short.
#  89%|████████▉ | 530/597 [19:46<02:07,  1.90s/it]WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
#  89%|████████▉ | 533/597 [19:52<02:02,  1.91s/it]WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
# WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
#  91%|█████████▏| 546/597 [20:14<01:27,  1.72s/it]WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
#  93%|█████████▎| 556/597 [20:33<01:29,  2.19s/it]WARNING:root:Failed to extract keywords from text: 'no'. Likely due to text length being too short.
# WARNING:root:Failed to extract keywords from text: 'no'. Likely due to text length being too short.
#  93%|█████████▎| 557/597 [20:37<01:43,  2.59s/it]WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
# WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
#  94%|█████████▍| 564/597 [20:51<01:06,  2.02s/it]WARNING:root:Failed to extract keywords from text: 'System'. Likely due to text length being too short.
#  95%|█████████▍| 566/597 [20:54<00:55,  1.80s/it]WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
# WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
# WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
#  97%|█████████▋| 577/597 [21:16<00:39,  1.98s/it]WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
#  97%|█████████▋| 578/597 [21:18<00:33,  1.74s/it]WARNING:root:Failed to extract keywords from text: 'no'. Likely due to text length being too short.
#  97%|█████████▋| 582/597 [21:25<00:29,  1.96s/it]WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
# WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
#  98%|█████████▊| 584/597 [21:28<00:22,  1.72s/it]WARNING:root:Failed to extract keywords from text: 'No'. Likely due to text length being too short.
#  99%|█████████▉| 592/597 [21:42<00:09,  1.99s/it]WARNING:root:Failed to extract keywords from text: '3'. Likely due to text length being too short.
# WARNING:root:Failed to extract keywords from text: '2'. Likely due to text length being too short.
# WARNING:root:Failed to extract keywords from text: '1'. Likely due to text length being too short.
# 100%|██████████| 597/597 [21:52<00:00,  2.20s/it]

# %%
samples = create_samples(data, all_bpmns)

import random

# display 5 random samples
random_samples = random.sample(samples, 5)
for sample in random_samples:
    print("\n-------------------------Sample:")
    print(sample["query_class"])
    print(sample["target_class"])
    print("---")
    print(sample["query"].file_path)
    print(sample["target"].file_path)
    print("---")
    print(sample["score"])
# Out:
# -------------------------Sample:
# 01-Dispatch-of-goods
# 02-Recourse
# ---
# data\camunda\English\01-Dispatch-of-goods\02-Results\Warenversand_e74e4fbcba1a48d3a4283a2e5bea3a2f.bpmn
# data\camunda\English\02-Recourse\02-Results\Recourse_Process_4ec053cbebfd4cb88665ee6916ae9ff9.bpmn
# ---
# 0.3167259786476868
#
# -------------------------Sample:
# 01-Dispatch-of-goods
# 02-Recourse
# ---
# data\camunda\German\01-Vorbereitung-des-Warenversands\02-Ergebnisse\Uebung1_6b0205981ffc42f1bfc71dede2cad8ec.bpmn
# data\camunda\German\02-Regressnahme\02-Ergebnisse\Regressnahme_084e5fb09cce4df886e2ff9c5323498f.bpmn
# ---
# 0.49822064056939497
#
# -------------------------Sample:
# 04-Self-service-restaurant
# 02-Recourse
# ---
# data\camunda\German\04-Selbstbedienungsrestaurant\02-Ergebnisse\sb_res_1b65580336c24531b6fab5d7c94a9555.bpmn
# data\camunda\German\02-Regressnahme\02-Ergebnisse\Regressnahme_0aad426b5f3347f695af87588489460b.bpmn
# ---
# 0.5160142348754448
#
# -------------------------Sample:
# 04-Self-service-restaurant
# 04-Self-service-restaurant
# ---
# data\camunda\English\04-Self-service-restaurant\02-Results\Self_service_restaurant_3dfe8771037544b8943240cca22b8f00.bpmn
# data\camunda\German\04-Selbstbedienungsrestaurant\02-Ergebnisse\Neuer_Prozess_b6a9732ef2874d58bbd70a96b0244a68.bpmn
# ---
# 0.5729537366548043
#
# -------------------------Sample:
# 03-Credit-scoring
# 04-Self-service-restaurant
# ---
# data\camunda\German\03-Schufascoring\02-Ergebnisse\Getting_started_1f8e95e3da60497c881e9fd8cd35b6ef.bpmn
# data\camunda\English\04-Self-service-restaurant\02-Results\sb_res_3523a86015e04bbf99649a9b43198da6.bpmn
# ---
# 0.18149466192170816

# %%
# Initialize counters
total_positive = 0
total_negative = 0
class_counts = {}
same_class_positive = 0
same_class_negative = 0
diff_class_positive = 0
diff_class_negative = 0


similarity_threshold = 0.5

for sample in samples:
    # Count positive and negative samples
    if sample["score"] > similarity_threshold:
        total_positive += 1
        if sample["query_class"] == sample["target_class"]:
            same_class_positive += 1
        else:
            diff_class_positive += 1
    else:
        total_negative += 1
        if sample["query_class"] == sample["target_class"]:
            same_class_negative += 1
        else:
            diff_class_negative += 1

    # Count samples per class
    if sample["query_class"] not in class_counts:
        class_counts[sample["query_class"]] = {"positive": 0, "negative": 0}
    if sample["score"] > similarity_threshold:
        class_counts[sample["query_class"]]["positive"] += 1
    else:
        class_counts[sample["query_class"]]["negative"] += 1

print("Total positive samples: ", total_positive)
print("Total negative samples: ", total_negative)
print("Same class positive samples: ", same_class_positive)
print("Same class negative samples: ", same_class_negative)
print("Different class positive samples: ", diff_class_positive)
print("Different class negative samples: ", diff_class_negative)
print("Samples per class: ", class_counts)
# Out:
# Total positive samples:  29097
# Total negative samples:  21591
# Same class positive samples:  11409
# Same class negative samples:  1410
# Different class positive samples:  17688
# Different class negative samples:  20181
# Samples per class:  {'01-Dispatch-of-goods': {'positive': 9735, 'negative': 4885}, '02-Recourse': {'positive': 8769, 'negative': 3859}, '03-Credit-scoring': {'positive': 7145, 'negative': 4136}, '04-Self-service-restaurant': {'positive': 3448, 'negative': 8711}}

# %% [markdown]
# # Baseline averaging model

# %%
import numpy as np

from sklearn.utils import resample

similarity_threshold = 0.5
similarity_threshold_baseline = 0.7

# Separate positive and negative samples
positive_samples = [sample for sample in samples if sample["score"] > similarity_threshold]
negative_samples = [sample for sample in samples if sample["score"] <= similarity_threshold]


# Balance the samples
if len(positive_samples) > len(negative_samples):
    # Undersample the positive samples
    positive_samples = resample(positive_samples, replace=False, n_samples=len(negative_samples), random_state=42)
else:
    # Oversample the negative samples
    negative_samples = resample(negative_samples, replace=True, n_samples=len(positive_samples), random_state=42)

# Combine the balanced samples
balanced_samples = positive_samples + negative_samples

TP = FP = TN = FN = 0

samples_with_scores_and_diffs = []

for sample in balanced_samples:
    query_embedding = sample["query"].get_graph().get("embedding")
    target_embedding = sample["target"].get_graph().get("embedding")

    # calculate the cosine similarity between the two embeddings and threshold it if both are not None
    if query_embedding is not None and target_embedding is not None:
        similarity = np.dot(query_embedding, target_embedding) / (np.linalg.norm(query_embedding) * np.linalg.norm(target_embedding))
        prediction = similarity > similarity_threshold_baseline
        actual = sample["score"] > similarity_threshold

        # Calculate the difference between the score and the actual value
        #print(similarity, sample["score"], similarity - sample["score"])
        diff = abs(similarity - sample["score"])

        #print("same_file:", sample["query"].file_path == sample["target"].file_path, "same_class:", sample["query_class"] == sample["target_class"],
         #      "actual: ", sample["score"], "prediction: ", similarity, "diff: ", diff)

        # Add the sample, similarity score, and difference to the list
        samples_with_scores_and_diffs.append((sample, similarity, diff))
        
        if prediction and actual:
            TP += 1
        elif prediction and not actual:
            FP += 1
        elif not prediction and actual:
            FN += 1
        else:
            TN += 1

precision = TP / (TP + FP)
recall = TP / (TP + FN)
f1_score = 2 * precision * recall / (precision + recall)

print("Precision: ", precision)
print("Recall: ", recall)
print("F1 Score: ", f1_score)

# Calculate the number of positive and negative samples
positive_samples = TP + FN
negative_samples = TN + FP

# Calculate the ratio of positive to negative samples
positive_negative_ratio = positive_samples / negative_samples

print("Positive samples: ", positive_samples)
print("Negative samples: ", negative_samples)
print("Ratio of positive to negative samples: ", positive_negative_ratio)

# Calculate the total number of samples
total_samples = positive_samples + negative_samples

# Calculate the percentage of positive and negative samples
positive_percentage = (positive_samples / total_samples) * 100
negative_percentage = (negative_samples / total_samples) * 100

print("Positive samples: {:.2f}%".format(positive_percentage))
print("Negative samples: {:.2f}%".format(negative_percentage))

# Sort the list by the absolute difference, in descending order
samples_with_scores_and_diffs.sort(key=lambda x: x[2], reverse=True)
# Out:
# Precision:  0.6527429805615551
# Recall:  0.6998749478949562
# F1 Score:  0.6754878076037639
# Positive samples:  21591
# Negative samples:  21591
# Ratio of positive to negative samples:  1.0
# Positive samples: 50.00%
# Negative samples: 50.00%

# %%
different_class_samples = [sample for sample in samples_with_scores_and_diffs if sample[0]["query_class"] != sample[0]["target_class"] and sample[-2] > 0.6]
print("Different class samples: ", len(different_class_samples))
# Out:
# Different class samples:  23234

# %%
def print_difference(index, same_class_samples):
    sample = same_class_samples[index]
    print("\n-------------------------Sample:")
    print(sample[0]["query_class"])
    print(sample[0]["target_class"])
    print("---")
    print("Similarity: ", sample[1])
    print("Score: ", sample[0]["score"])
    print("Difference: ", sample[2])
    sample[0]["query"].draw_graph()
    sample[0]["target"].draw_graph()

print_difference(0, different_class_samples)
# Out:
# -------------------------Sample:
# 02-Recourse
# 01-Dispatch-of-goods
# ---
# Similarity:  0.86086524
# Score:  0.15658362989323849
# Difference:  0.7042816054354358

# %%
for diff_sample in different_class_samples[:10]:
    print(diff_sample[-1], diff_sample[0]["query_class"], diff_sample[0]["target_class"])
# Out:
# 0.7042816054354358 02-Recourse 01-Dispatch-of-goods
# 0.6850296583464137 01-Dispatch-of-goods 02-Recourse
# 0.6767175271841979 01-Dispatch-of-goods 02-Recourse
# 0.6649286475470058 04-Self-service-restaurant 01-Dispatch-of-goods
# 0.6595597430480332 01-Dispatch-of-goods 04-Self-service-restaurant
# 0.6555902605803412 04-Self-service-restaurant 01-Dispatch-of-goods
# 0.6547212093750353 04-Self-service-restaurant 01-Dispatch-of-goods
# 0.6540211263076267 01-Dispatch-of-goods 02-Recourse
# 0.6539431112516817 02-Recourse 01-Dispatch-of-goods
# 0.6520686393530768 02-Recourse 01-Dispatch-of-goods

# %%
print_difference(1000, different_class_samples)
# Out:
# -------------------------Sample:
# 01-Dispatch-of-goods
# 04-Self-service-restaurant
# ---
# Similarity:  0.8662122
# Score:  0.37010676156583633
# Difference:  0.49610542763170395

# %% [markdown]
# # Training and evaluating GNN model

# %%
from spektral.data import Graph, Dataset, Loader, BatchLoader
from spektral.data.utils import get_spec, collate_labels_batch, sp_matrices_to_sp_tensors, to_batch, pad_jagged_array

import tensorflow as tf
import networkx as nx
import numpy as np

class BpmmComparingSpektralLoader(Loader):
    def __init__(self, dataset, mask=False, batch_size=1, epochs=None, shuffle=True, node_level=False):
        self.mask = mask
        self.node_level = node_level
        self.signature = dataset.signature
        super().__init__(dataset, batch_size=batch_size, epochs=epochs, shuffle=shuffle)

    def numpy(self, graph):
        # Return tuple of non-None elements
        return tuple(ret for ret in [graph.a_x, graph.a_a, graph.b_x, graph.b_a, graph.y] if ret is not None)
    
    def to_batch(self, a_x_list=None, a_a_list=None, b_x_list=None, b_a_list=None, mask=False):
        if a_a_list is None and a_x_list is None and b_a_list is None and b_x_list is None:
            raise ValueError("Need at least a_x_list or a_a_list or b_x_list or b_a_list")
    
        n_max = max([x.shape[0] for x in (a_x_list if a_x_list is not None else a_a_list)] +
                    [x.shape[0] for x in (b_x_list if b_x_list is not None else b_a_list)])
    
        # Node features for graph A
        a_x_out = None
        if a_x_list is not None:
            if mask:
                a_x_list = [np.concatenate((x, np.ones((x.shape[0], 1))), -1) for x in a_x_list]
            a_x_out = pad_jagged_array(a_x_list, (n_max, -1))
    
        # Adjacency matrix for graph A
        a_a_out = None
        if a_a_list is not None:
            if hasattr(a_a_list[0], "toarray"):  # Convert sparse to dense
                a_a_list = [a.toarray() for a in a_a_list]
            a_a_out = pad_jagged_array(a_a_list, (n_max, n_max))
    
        # Node features for graph B
        b_x_out = None
        if b_x_list is not None:
            if mask:
                b_x_list = [np.concatenate((x, np.ones((x.shape[0], 1))), -1) for x in b_x_list]
            b_x_out = pad_jagged_array(b_x_list, (n_max, -1))
    
        # Adjacency matrix for graph B
        b_a_out = None
        if b_a_list is not None:
            if hasattr(b_a_list[0], "toarray"):  # Convert sparse to dense
                b_a_list = [b.toarray() for b in b_a_list]
            b_a_out = pad_jagged_array(b_a_list, (n_max, n_max))
    
        return tuple(out for out in [a_x_out, a_a_out, b_x_out, b_a_out] if out is not None)

    def collate(self, batch):
        # Prepare output and keys
   
        output = [list(elem) for elem in zip(*[self.numpy(g) for g in batch])]
        keys = [k + "_list" for k in self.dataset.signature.keys()]
        packed = dict(zip(keys, output))

        # Process labels
        y = packed.pop("y_list", None)


        if y is not None:
            y = collate_labels_batch(y, node_level=self.node_level)


        # Print the length of output
        output = self.to_batch(**packed, mask=self.mask)

        # Convert sparse matrices to tensors
        A_X, A_A, B_X, B_A = output
        output = sp_matrices_to_sp_tensors((A_X, A_A, B_X, B_A))
        
        # Return output
        if len(output) == 1:
            output = output[0]
        if y is None:
            return output
        else:
            return output, y

class BPMNGraphProcessor:
 
    def get_node_features(self, bpmn_graph):
        # Get node features
        x = [node.get("embedding", np.zeros(384)).reshape(-1) for _, node in bpmn_graph.network.nodes(data=True)]
        return np.stack(x)

    def get_adjacency_matrix(self, bpmn_graph):
        # Get adjacency matrix
        return nx.adjacency_matrix(bpmn_graph.network).tocoo()

class BPMNGraphDataset(Dataset):
    def __init__(self, samples, **kwargs):
        self.samples = samples
        self.embedding_dims = 384
        self.processor = BPMNGraphProcessor()
        super().__init__(**kwargs)

    def process_graph(self, bpmn_graph):
        # Add self loop
        for node in bpmn_graph.network.nodes():
            bpmn_graph.network.add_edge(node, node)

        # Get adjacency matrix and node features
        a = self.processor.get_adjacency_matrix(bpmn_graph)
        x = self.processor.get_node_features(bpmn_graph)

        return a, x

    def read(self):
        return [self.create_graph(sample) for sample in self.samples if self.valid_sample(sample)]

    def valid_sample(self, sample):
        bpmn_graph_a = sample["query"]
        bpmn_graph_b = sample["target"]

        return all(len(bpmn_graph.get_nodes()) > 0 and len(bpmn_graph.get_edges()) > 0 for bpmn_graph in [bpmn_graph_a, bpmn_graph_b])

    def create_graph(self, sample):
        bpmn_graph_a = sample["query"]
        bpmn_graph_b = sample["target"]

        a_a, a_x = self.process_graph(bpmn_graph_a)
        b_a, b_x = self.process_graph(bpmn_graph_b)

        # Get class labels (convert boolean to int)
        if "score" in sample:
            y = float(sample["score"])
            return Graph(a_x=a_x, a_a=a_a, b_x=b_x, b_a=b_a, y=y)
        else:
            return Graph(a_x=a_x, a_a=a_a, b_x=b_x, b_a=b_a)
    
    @property
    def signature(self):
        """
        This property computes the signature of the dataset, which can be
        passed to `spektral.data.utils.to_tf_signature(signature)` to compute
        the TensorFlow signature. You can safely ignore this property unless
        you are creating a custom `Loader`.

        A signature consist of the TensorFlow TypeSpec, shape, and dtype of
        all characteristic matrices of the graphs in the Dataset. This is
        returned as a dictionary of dictionaries, with keys `x`, `a`, `e`, and
        `y` for the four main data matrices.

        Each sub-dictionary will have keys `spec`, `shape` and `dtype`.
        """
        if len(self.graphs) == 0:
            return None
        signature = {}
        graph = self.graphs[0]  # This is always non-empty
        if graph.a_x is not None:
            signature["a_x"] = dict()
            signature["a_x"]["spec"] = get_spec(graph.a_x)
            signature["a_x"]["shape"] = (None, self.embedding_dims)
            signature["a_x"]["dtype"] = tf.as_dtype(graph.a_x.dtype)
        if graph.a_a is not None:
            signature["a_a"] = dict()
            signature["a_a"]["spec"] = get_spec(graph.a_a)
            signature["a_a"]["shape"] = (None, None)
            signature["a_a"]["dtype"] = tf.as_dtype(graph.a_a.dtype)
        if graph.b_x is not None:
            signature["b_x"] = dict()
            signature["b_x"]["spec"] = get_spec(graph.b_x)
            signature["b_x"]["shape"] = (None, self.embedding_dims)
            signature["b_x"]["dtype"] = tf.as_dtype(graph.b_x.dtype)
        if graph.b_a is not None:
            signature["b_a"] = dict()
            signature["b_a"]["spec"] = get_spec(graph.b_a)
            signature["b_a"]["shape"] = (None, None)
            signature["b_a"]["dtype"] = tf.as_dtype(graph.b_a.dtype)
        if graph.y is not None:
            signature["y"] = dict()
            signature["y"]["spec"] = get_spec(graph.y)
            signature["y"]["shape"] = (self.n_labels,)
            signature["y"]["dtype"] = tf.as_dtype(np.array(graph.y).dtype)
        return signature
    
dataset = BPMNGraphDataset(balanced_samples)

# Parameters
F = dataset.n_node_features  # Dimension of node features
S = dataset.n_edge_features  # Dimension of edge features
n_out = dataset.n_labels  # Dimension of the target

# Train/test split
idxs = np.random.permutation(len(dataset))
split = int(0.9 * len(dataset))
idx_tr, idx_te = np.split(idxs, [split])
dataset_tr, dataset_te = dataset[idx_tr], dataset[idx_te]
# Out:
# c:\Users\StefaanVercoutere\OneDrive - Sirus NV\OPH\gnn-citations\.conda\Lib\site-packages\spektral\data\dataset.py:120: UserWarning: The graphs in this dataset have no adjacency matrix. Is this intentional?
#   warnings.warn(

# %%
len(dataset_tr), len(dataset_te)
# Out:
# (38863, 4319)

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, Input, Dot, Lambda, Concatenate, Dense
import tensorflow.keras.backend as K
from spektral.layers import GCNConv, GlobalAvgPool, GlobalAttentionPool

def create_gcn_layers(embedding_dims):
    # Define the shared GCN layers
    graph_conv = GCNConv(embedding_dims, activation='relu', name='graph_conv')
    dropout = Dropout(0.2, name='dropout')
    graph_conv_2 = GCNConv(embedding_dims, activation='relu', name='graph_conv_2')
    dropout_2 = Dropout(0.2, name='dropout_2')
    graph_conv_3 = GCNConv(embedding_dims, activation='relu', name='graph_conv_3')
    global_pool = GlobalAttentionPool(embedding_dims,name='global_pool')
    #global_pool = GlobalAvgPool(name='global_pool')

    return graph_conv, dropout, graph_conv_2, dropout_2, graph_conv_3, global_pool

def create_graph_model(X_in, A_in, graph_layers):
    graph_conv, dropout, graph_conv_2, dropout_2, graph_conv_3, global_pool = graph_layers

    # Pass graph through the shared layers
    graph_conv_out = graph_conv([X_in, A_in])
    dropout_out = dropout(graph_conv_out)
    graph_conv_2_out = graph_conv_2([dropout_out, A_in])
    dropout_2_out = dropout_2(graph_conv_2_out)
    graph_conv_3_out = graph_conv_3([dropout_2_out, A_in])
    graph_embedding = global_pool(graph_conv_3_out)

    return graph_embedding

def create_models(n_features, embedding_dims):
    # Define the inputs for graph A
    A_X_in = Input(shape=(None, n_features), name='A_Node_features')
    A_A_in = Input((None, ), sparse=True, name='A_Adjacency_matrix')

    # Define the inputs for graph B
    B_X_in = Input(shape=(None, n_features), name='B_Node_features')
    B_A_in = Input((None, ), sparse=True, name='B_Adjacency_matrix')

    # Create the GCN layers
    graph_layers = create_gcn_layers(embedding_dims)

    # Create the graph embeddings
    A_graph_embedding = create_graph_model(A_X_in, A_A_in, graph_layers)
    B_graph_embedding = create_graph_model(B_X_in, B_A_in, graph_layers)


    # concatenate the two embeddings
    concatenated = Concatenate(name='concatenated')([A_graph_embedding, B_graph_embedding])
    dense_layer = Dense(64, activation='relu')(concatenated)
    dense_layer = Dropout(0.2, name='dropout_conc')(dense_layer)
    dense_output = Dense(1, activation='sigmoid', name='output')(dense_layer)


    # Perform dot product between the two graph embeddings
    dot_product = Dot(axes=1, normalize=True, name='dot_product')([A_graph_embedding, B_graph_embedding])
    
    # Create the main model
    model = Model(inputs=[A_X_in, A_A_in, B_X_in, B_A_in], outputs=dense_output, name='my_model')

    # Create the embedding model
    embedding_model = Model(inputs=[A_X_in, A_A_in], outputs=A_graph_embedding, name='embedding_model')

    return model, embedding_model

# Create the model
model, embedding_model = create_models(n_features=384, embedding_dims=384)
model.summary()
# Out:
# C:\Users\StefaanVercoutere\AppData\Roaming\Python\Python311\site-packages\keras\src\initializers\initializers.py:120: UserWarning: The initializer GlorotUniform is unseeded and being called multiple times, which will return identical values each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initializer instance more than once.
#   warnings.warn(
# Model: "my_model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  A_Node_features (InputLaye  [(None, None, 384)]          0         []
#  r)
#
#  A_Adjacency_matrix (InputL  [(None, None)]               0         []
#  ayer)
#
#  B_Node_features (InputLaye  [(None, None, 384)]          0         []
#  r)
#
#  B_Adjacency_matrix (InputL  [(None, None)]               0         []
#  ayer)
#
#  graph_conv (GCNConv)        (None, None, 384)            147840    ['A_Node_features[0][0]',
#                                                                      'A_Adjacency_matrix[0][0]',
#                                                                      'B_Node_features[0][0]',
#                                                                      'B_Adjacency_matrix[0][0]']
#
#  dropout (Dropout)           (None, None, 384)            0         ['graph_conv[0][0]',
#                                                                      'graph_conv[1][0]']
#
#  graph_conv_2 (GCNConv)      (None, None, 384)            147840    ['dropout[0][0]',
#                                                                      'A_Adjacency_matrix[0][0]',
#                                                                      'dropout[1][0]',
#                                                                      'B_Adjacency_matrix[0][0]']
#
#  dropout_2 (Dropout)         (None, None, 384)            0         ['graph_conv_2[0][0]',
#                                                                      'graph_conv_2[1][0]']
#
#  graph_conv_3 (GCNConv)      (None, None, 384)            147840    ['dropout_2[0][0]',
#                                                                      'A_Adjacency_matrix[0][0]',
#                                                                      'dropout_2[1][0]',
#                                                                      'B_Adjacency_matrix[0][0]']
#
#  global_pool (GlobalAttenti  (None, 384)                  295680    ['graph_conv_3[0][0]',
#  onPool)                                                             'graph_conv_3[1][0]']
#
#  concatenated (Concatenate)  (None, 768)                  0         ['global_pool[0][0]',
#                                                                      'global_pool[1][0]']
#
#  dense (Dense)               (None, 64)                   49216     ['concatenated[0][0]']
#
#  dropout_conc (Dropout)      (None, 64)                   0         ['dense[0][0]']
#
#  output (Dense)              (None, 1)                    65        ['dropout_conc[0][0]']
#
# ==================================================================================================
# Total params: 788481 (3.01 MB)
# Trainable params: 788481 (3.01 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
import matplotlib.pyplot as plt

def train_model(model, dataset, batch_size=32, epochs=10):
    """
    Trains the model on the given dataset.

    Parameters:
    model (Model): The model to train.
    dataset (Dataset): The dataset to train the model on.
    batch_size (int): The batch size to use for training.
    epochs (int): The number of epochs to train the model for.

    Returns:
    History: A History object. Its History.history attribute is a record of training loss values and metrics values at successive epochs.
    """
    try:
        from tensorflow.keras.optimizers import Adam
        from tensorflow.keras.metrics import Precision, Recall, AUC
        
        # Create the model
        model, embedding_model = create_models(n_features=384, embedding_dims=384)
        
        # Compile the model with additional metrics
        model.compile(optimizer=Adam(), 
                      loss='binary_crossentropy',
                      metrics=['accuracy', Precision(), Recall(), AUC()])
        
        # Create a loader
        loader = BpmmComparingSpektralLoader(dataset, batch_size=batch_size, shuffle=True)

        # Log the shapes of the inputs and targets
        batch = next(loader.load())
        inputs, y = batch
        A_X, A_A, B_X, B_A = inputs
        
        print(f"A shape:( {A_X.shape}, {A_A.shape}), B shape:( {B_X.shape}, {B_A.shape}), y shape: {y.shape}")

        # Train the model
        history = model.fit(loader.load(), steps_per_epoch=loader.steps_per_epoch, epochs=epochs)

        return model, embedding_model, history
    except Exception as e:
        print(f"An error occurred: {e}")

    return None, None, None

def evaluate_model(model, dataset, batch_size=32):
    """
    Evaluates the model on the given dataset.

    Parameters:
    model (Model): The model to evaluate.
    dataset (Dataset): The dataset to evaluate the model on.
    batch_size (int): The batch size to use for evaluation.

    Returns:
    float: The loss value & accuracy value of the model.
    """
    try:
        # Create a loader
        loader = BpmmComparingSpektralLoader(dataset, batch_size=batch_size, shuffle=False)

        # Evaluate the model
        results = model.evaluate(loader.load(), steps=loader.steps_per_epoch)

        return results
    except Exception as e:
        print(f"An error occurred: {e}")

    return None, None

def plot_history(history, metric):
    # Plot training & validation metric values
    plt.figure(figsize=(12, 4))
    
    plt.subplot(1, 2, 1)
    plt.plot(history.history[metric])
    plt.title('Model ' + metric)
    plt.ylabel(metric.capitalize())
    plt.xlabel('Epoch')
    plt.legend(['Train'], loc='upper left')

    # Plot training & validation loss values
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'])
    plt.title('Model loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train'], loc='upper left')

    plt.tight_layout()
    plt.show()


# Train the model
#model, embedding_model, history = train_model(model, dataset_tr, epochs = 10)

# %%
eval_loss, eval_accuracy = evaluate_model(model, dataset_te)
print(f"Eval loss: {eval_loss}, Eval accuracy: {eval_accuracy}")

# Plot the training history
plot_history(history)
# Out:
# 72/72 [==============================] - 28s 376ms/step - loss: 0.3244 - accuracy: 0.4998 - precision_18: 0.9965 - recall_18: 0.9983 - auc_18: 0.9990
# An error occurred: too many values to unpack (expected 2)
# Eval loss: None, Eval accuracy: None

# %% [markdown]
# # Testing retrieval performance

# %%
list(all_bpmns.keys())
# Out:
# ['sb_res_13bdebb53b584fbabd26a2e588c1547e.bpmn',
#  'warenversand_-_english_e07e91f12a5741ed836579651fd0b38d.bpmn',
#  'Aufgabe_1_38ebadc4d2744116ba565d266ebcc6af.bpmn',
#  'Exercise_3_0d661bca636d43e79602b216cd8bc923.bpmn',
#  'Claim_f339fddf3b1645a68a5c5745faf44e88.bpmn',
#  'Neuer_Prozess_8_e667e365805046c9a1bf2ea764479fe5.bpmn',
#  'Schufascoring_25040d9524894835b03b1ed68e87fe04.bpmn',
#  'Neuer_Prozess_9e9fce4f6ccf4c8793cbb83dcf8beb69.bpmn',
#  'warenversand_-_english_b8d95a804fb54510bafaae1fa10d3991.bpmn',
#  'Ueb_1_5af419e60a25409697d7f768c7ce166c.bpmn',
#  '-__bung_3_aa020f86ca734ca78c9e1dfb8c92b088.bpmn',
#  'Restaurant_39ed618a5da04516af2ea39466dab4b2.bpmn',
#  'Ueb_1_ae84ec3090aa4980a8dac59e4d557b47.bpmn',
#  'Exercise3_Regress_41a37ed15e824f5dafac82ffd71ea1de.bpmn',
#  'Versandbeauftragung_4e5073f5431f4e64b62f37df29306ffa.bpmn',
#  '-_Schufa_9831eb834a924b9f9c4591000c9387ef.bpmn',
#  'scoring_20b470b2f0c44dedaf1cb2f7c5924280.bpmn',
#  'Excercise_3_-_Subrogation_995343cb589c438e9e0edd816860d54f.bpmn',
#  'regress_-_english_4b98a50bf0b24719a8fad81c847d3734.bpmn',
#  'Recourse_1a23bebbb6d843ebb130a87bee972c21.bpmn',
#  'Self_service_restaurant_3dfe8771037544b8943240cca22b8f00.bpmn',
#  '07_-_Schufascoring_4787494aaa1543539717c95ca3dca6c8.bpmn',
#  'Schufascoring_162aac108c1a4c91953c4bccbf2898fd.bpmn',
#  'Exercise_3_Claim_2b5b6781fb694ec09e825f6d4673fb88.bpmn',
#  'scoring_d287ae5d136c473aac47bd32e3b4845b.bpmn',
#  '-__bung_1_887e88cab0d94585a5c6fb3e3ac12469.bpmn',
#  'Regressnahme_0a89ef9d86084dcc96ba63f71f39f0f2.bpmn',
#  'Aufgabe_1_ac57014427b94f1fa04661006dbeadfc.bpmn',
#  'schufa_-_english_19ef703740f44a41b915c282b662a488.bpmn',
#  'Dispatchin_of_goods_ca3ac1d3e9ce4cda979953ebc59bf6b7.bpmn',
#  'sbres_ca974254031c461fa0f94561d2421bb4.bpmn',
#  'sb_res_d0ae9b36287d41589856cdd568bb0bac.bpmn',
#  'excersise_no1_6e8c0acfcb0740d7bc60580f0d64a6bb.bpmn',
#  'A7_b0448c6829944874a20606ff351eecd7.bpmn',
#  'Versandprozess_010dc35c54084bb986a532a2e48042df.bpmn',
#  'warenversand_-_english_f8e003ebf21d4c14b0b58ca444aa63c9.bpmn',
#  'Gruppe_3_3f16a0d28f324661a36524770b4167a5.bpmn',
#  'Neuer_Prozess_2593c913e86842f592bd73737b301369.bpmn',
#  'Neuer_Prozess_609a38dc9b404bbba300a7eefb0deeed.bpmn',
#  'Ueb_1_8dcd3061c0804591a2d7af2f00796152.bpmn',
#  '03_-_Regressnahme_25cbac3aa336467199f85f29f8db84c5.bpmn',
#  'Ueb_1_316f88d03ad0432199336573cc4fafa1.bpmn',
#  'Dispatch_01_6a478fb945e4464abc19d1a74b903390.bpmn',
#  'Schufascoring_1c347ff05b9d4af7aeaaf3dec3c83d27.bpmn',
#  '-__bung_8_d53e88c969ba4f81b6a2fd1053bd704d.bpmn',
#  'Trainer_-_Ueb1_48ff73d8c89a483f9e2404d56b3baf12.bpmn',
#  'Schufascoring_0e5ea5b73ae54d03b822087016645b43.bpmn',
#  '02Regressnahme_fe2a7ad5737d4474908913c52950a268.bpmn',
#  'Neuer_Warenversand_4fb85acf907341009d03b3560fb58408.bpmn',
#  'Exercise_5_-_Credit_Scoring_5853ff7b1fd342319ddb52a8a7c7282a.bpmn',
#  'regress_-_english_d400a92f895a4d0c938b5c0d84220b1f.bpmn',
#  'Regressnahme_09befb3c71d44465b0659c92958f6f1e.bpmn',
#  'Regressnahme_18dc6f50cd2d453cbaa8560ec5e4076c.bpmn',
#  'Aufgabe_1_-_Warenversand_aa918f1b0a5e40d997a6b52bb21df01c.bpmn',
#  'Neuer_Prozess_0ab62efa0a7a43dd8733e94e9b147ba9.bpmn',
#  'Ueb_1_f488507c272a4cff809242be94608a68.bpmn',
#  'SB-Restaurant_f92b4e4bcbd04c29af51a35e5acf6378.bpmn',
#  'Dispatch_of_Goods_bc722883a18e42f1bf5e53626e77a811.bpmn',
#  'Schufascoring_-__bung_7_bc4b7d9bcd0f46fc8937cfb5df1fbc0a.bpmn',
#  '-__bung_7_0baaba4c86fa488e88f74bd7dabad073.bpmn',
#  'Ueb1_-_Warenversand_7ba95b0ca9a34696bf13b9d70d7102ae.bpmn',
#  'Demo_Signavio_5b48b8fee22c4ea7ae2ef4599511dc17.bpmn',
#  'Uebung_1_ef1aa7ff3f614868985f5e21c3a71644.bpmn',
#  'Uebung1_6b0205981ffc42f1bfc71dede2cad8ec.bpmn',
#  'regressnahme_-_english_f35b3f01b9974644a4ca4bcf9d34a720.bpmn',
#  'Restaurant_b00a7590f12b4053b26094047baf60bc.bpmn',
#  'sbres_9f9bf32d974c4f749e5548b289214be3.bpmn',
#  '-_Task_3_84c455b8b0db45b388e7e176598502a9.bpmn',
#  'Self_service_restaurant_0670f1076f5849e785f1d51adeec3fc5.bpmn',
#  'Schufascoring_266241535aa04f96a6918ff3dda87ed5.bpmn',
#  'regress_-_english_9daf7d8b9cd84b83bbbf7d43538d59b9.bpmn',
#  'Ex_3_906bd7c47cfb4257ac43aa297c2da4cf.bpmn',
#  'Schufascoring_02c8772c4ac7403b80c39376fc70cf37.bpmn',
#  'Mc_Doof_e1fe50a7813f41268db660af8021604e.bpmn',
#  'sb_res_f7bc73069b764137af78eaa9b2d50d50.bpmn',
#  'sb_res_11ca13d016034e3e85f18fb4c0655006.bpmn',
#  'Kreditvergabe_829acb3cd8a54d519bd8a698fe018f3f.bpmn',
#  'Neuer_Prozess_131b84011e18477793620aa072d82a5f.bpmn',
#  'Dispatch_of_goods_4d749c4b3bb04cf499218261d60d9ccb.bpmn',
#  'Schufa-Scoring_a234cde359bb44f9a7b400ae6a267ff4.bpmn',
#  'regressnahme_0268db1288ad487a80396f01bb282196.bpmn',
#  'sb_res_0fa7f90a2f724ba187cb921f56bdcfa4.bpmn',
#  'ueb_self_service_ab46cfa8a3014df7a97f17649d2ebba0.bpmn',
#  'Exercise_5_-_Credit_Scoring_d1af8de4c3924cdf9d108449b011c790.bpmn',
#  'Uebung1_a3a097e2f2f745fe9d6b107f6e3f01fa.bpmn',
#  'Regressnahme_084e5fb09cce4df886e2ff9c5323498f.bpmn',
#  'Self-service_restaurant_25f72c5cbb8346eaa25c5aa59b2778f0.bpmn',
#  'Regressnahme_02670f3791de4f6695079cb0599139ab.bpmn',
#  'Schufascoring_0816e5d888534999ab96ddea474eed98.bpmn',
#  'Regressnahme_13955af89274447f86b7948cd5dbaeea.bpmn',
#  'schufa-scoring-t6_98ae446a7389493c899533f5a3ccc759.bpmn',
#  'SB_Res_20b75011f5ff4e9e95b9adffe72fb6a4.bpmn',
#  'exercise6_ae404919f5844a9ea6d95c071d362ecb.bpmn',
#  'Warenversand_d64d8276cf1d488992195f9b8144f880.bpmn',
#  'New_Process_fe7d4533db844216be2fa85a13293b1a.bpmn',
#  '05Schufascoring_9a98a9585a984a6aba5deadb7cf346b9.bpmn',
#  'Team_1_Warenversand_7b09a6f6693d4c8aa8a6550b16f89601.bpmn',
#  'Exercise1_18550dfe434d4b1ab796685f63d461f5.bpmn',
#  'Schufascoring_1a10af494ca14f50982c0a82b9cc3e99.bpmn',
#  '04__Schufa__neu__6d05933288214e2e9aff97e3f06ac825.bpmn',
#  'Regressnahme_11f52254c6aa4dbc87eaf61a4839fc38.bpmn',
#  'warenversand_-_english_a850c588e7d54de1add30aaddce62cd6.bpmn',
#  'Schufascoring_28731feeee954a61a2d4d7a41c5c23fa.bpmn',
#  'u1_89bcef290caa412fbcd8b444b5345e0f.bpmn',
#  'excercise_2_e438edc959504171b3bf167751eff4ba.bpmn',
#  'sb_res_00b13b6ee3d849a9942ea33628bd9c2f.bpmn',
#  'Beispiel_2_Regress_e5eb798baee240389669a43dd2216bef.bpmn',
#  'Regressnahme_1573263eff264101b85d3f8d76832a75.bpmn',
#  'Warenversand_7f50c52e9d69490db819c1d685c59e3a.bpmn',
#  'Exercise_1_1a0ff183655647289efd3c0f663b2131.bpmn',
#  'Aufgabe3_Regressnahme_7bffccf60796457ea72f8f8e17b82193.bpmn',
#  'Neuer_Prozess_e83dddd2bd4a4a058e7101ba38af18f9.bpmn',
#  'Recourse_fb013b492cba4b8fb0fd38bdbcec65f5.bpmn',
#  'Exercise_1_29bb622b0c3a4edb90fa7c3810cc076a.bpmn',
#  'Regressnahme_0583e805ab5148668d6eff2ec4230928.bpmn',
#  'Ueb_1__Vorbereitung_Warenversand_45f5a8f56720447e9992d941531d7f2f.bpmn',
#  'Schufa-Auskunft__L_sung__c22421c9c9b249d1963d23536115201b.bpmn',
#  'Regressnahme_08795d591f9c4913917e8c9a11a1ddd0.bpmn',
#  'regress_-_english_fc1f3bbf2d534b528d5b9d8a2d89d993.bpmn',
#  'Regressnahme_0f31624f95ad4f1fb3671b72b1beefff.bpmn',
#  'Recourse_5ac35cacc88b43f9a0712c2b46ddbc07.bpmn',
#  'Exercise_1_21a36e3570ab48d59098702f4f8ad279.bpmn',
#  'Schufascoring_0784b41f95e042ac9d01608aba89b266.bpmn',
#  'Aufgabe_3_-_Regressnahme_85ba47b6b06c429da81ed4723f0ebe5e.bpmn',
#  'Schufa-Auskunft_75884ea714454bb0bbbaa5fbf40c4596.bpmn',
#  'sb_res_28616a39f470438396925a8adb5c55e9.bpmn',
#  'Schufascoring_0e13073c16054adf8e97d8a4bd46fa61.bpmn',
#  'warenversand_-_english_027ce98fab3a4b3dada547ccf03e3c51.bpmn',
#  'Regressnahme_009bae25b7624f68bd163a2dd5bf7644.bpmn',
#  'Ueb_1_-_Warenversand_11887d02537e4e529a1ee2af157c2cd8.bpmn',
#  'Exercise_1_Dispatch_of_Goods_1b80d86d36ee4cf79bcd427aebdd943d.bpmn',
#  'Exercise_5_-_Credit_Scoring_ae81702502134ab08dcc64b46b902b6e.bpmn',
#  'Dispatch_of_goods_4baa7cbe64fc477fbd1500efbbe57e98.bpmn',
#  'Schufascoring_2afd78986edc4e06a6bb32a85c1a7236.bpmn',
#  'Ueb_1_05b3e147f1004b0a9e3ffbc5a5c101e2.bpmn',
#  'sb_res_2fae0f7a0d8041d8a418d696f3d2ff8c.bpmn',
#  'Regressnahme_0429bddca9594c3c98975876612bb0ad.bpmn',
#  'Dispatch_1cb656bdb9ec435fbe33bf4df633c2f5.bpmn',
#  'Credit_Scoring_7840de1bde374062bdf1fff4786bc668.bpmn',
#  'regress_-_english_a48fe24df7194f07b25f42ab92a0ab0f.bpmn',
#  'Beispiel_3_restaurant_d1d1df576d3144e3b2a9d4d46f989706.bpmn',
#  'Regressnahme_1af9cd3b8e0f4265b32093ce71e6879c.bpmn',
#  'Warenversand_0b2da3201db14d2fa8294de710ff153b.bpmn',
#  'sb_res_0d730f91a2ed4ca786e7c030cf6b8f65.bpmn',
#  'SB_restaurant_0f435c5ab7684590b0a1d1c35e6eaff0.bpmn',
#  '01_-_Vorbereitung_Warenversand_e29ad857608345f4a3c8ee5eefc44129.bpmn',
#  'Ueb_1_dcf1a94a46fb4ab4ba0ace2f84e4dc12.bpmn',
#  'Neuer_Prozess_8c21f4dd57ff4b2ba56e91d8ebc0bfcf.bpmn',
#  'exercise_3_Recourse_8eaa8a46882d4aff825b60bdf79e0e0c.bpmn',
#  'Aufgabe_3_a6287b5ad26d4bd1a3ef1c9bc8fe46c2.bpmn',
#  'Schufascoring_07dc588f6927499e87022848fa64bf67.bpmn',
#  '8.__bung_Selbstbedienungsrestaurant_ee3d9b9c56d0402393fa2c4b64cd45bd.bpmn',
#  'Schufascoring_0d7223175e964f19b02d5595930efb8e.bpmn',
#  'Uebung_1_990e7afbafe0416f86deff22f44d9175.bpmn',
#  'sb_res_13d6c71b86d74b738bd789accd51b130.bpmn',
#  'Kreditvergabe_2d15761958d94397b11086cb65c92a0f.bpmn',
#  'Excersise_No_3_2cdc3da0a0f64bc0bfd988cf04dd4245.bpmn',
#  'SB_Res_0b97e9114ce8471ab473e4957949b469.bpmn',
#  'Schufascoring_1678c7818f18467eab2ad14f67e9d81f.bpmn',
#  'Exercise1_DispatchingOfGoods_481c5e8b98774e5a9550acafcb20893b.bpmn',
#  'Warenversand_b330b8dc9dae47039d4f8fcdaeb14b22.bpmn',
#  'Uebung_1_ed4163c98ee64eba9620824466dbad91.bpmn',
#  'excercise_6_afcdef8852d1452e9d970e6b8000b8ce.bpmn',
#  '7-Schufascoring_ff8f009b0114494894845b8a721d956d.bpmn',
#  'Restaurant_3a7f1a4d9cb14b4180a6fd80529141ac.bpmn',
#  'sb_res_20ef510749044a85abbd63222b3ad52c.bpmn',
#  'Excercise_6_9407eba90a3c4a80a09711d0f6fa1e64.bpmn',
#  'Exercise5_CreditScoring_cf6f52570b7843b4b30c3e46c7472e32.bpmn',
#  'sb_res_0c8609b3cd8a47cc8cb0c47b2ff77a23.bpmn',
#  '1.__bung_Vorbereitung_des_Warenversand_b1924b3dfc1a48b48375847178d53af3.bpmn',
#  'regress_-_english_343df7a7d3f7487abf26f786bc997b14.bpmn',
#  'schufa_-_english_f43a962ad5274f569ca52bb5ceb7a544.bpmn',
#  'Exercise_3_f2ef3302a810413795d0fd9aa0f3d44c.bpmn',
#  'Schufascore_e5320a9a7c0648658b8669230a421718.bpmn',
#  'Exercise_6_483864ed893c44b4a8d3cc1d10a042e7.bpmn',
#  'erster_Prozess_0eed78ea0d5f44f2bcf0a4d0c4e19035.bpmn',
#  'warenversand_-_english_669fbdb6351d46bfab81ac608bf3bf67.bpmn',
#  'Ueb1_Warenversand_f9a7cfff5ed24f8992c963ec99be0f91.bpmn',
#  'Ueb_1__Kopie__e38adaf67e0a45ad977c25832eedfdbd.bpmn',
#  'Exercise_5__2fa7a262d4ec4ad2bbd0e10cbc50d149.bpmn',
#  'Schufascoring_16983a85fadc4cd38f459065e3a5c83b.bpmn',
#  'exercise7_c385f6618b6d446f82fff5ad3bba8f99.bpmn',
#  'sb_res_1b65580336c24531b6fab5d7c94a9555.bpmn',
#  'exercise_1_894e8554304340fdbebc31610f683939.bpmn',
#  'Banking_97d94af1573f443fbf6ae42eba61c8f4.bpmn',
#  '03_Regressfall_7fa68b043d164a6d9bccbfcdb31b42db.bpmn',
#  'Self-Service_Restaurant_9bcb9b015c3340a6820253c964748c4b.bpmn',
#  'SBR_5e6fc94fb80e426599a9a922886d6344.bpmn',
#  'SB_Res_21adb6c7f2fa41feb9e7a139ccbc975a.bpmn',
#  'Warenversand_b6183314a40a4041b05ac542cc468ac5.bpmn',
#  'Ueb_1_9718db2cd9f84649bb99c484b4d3cd08.bpmn',
#  'sb_res_3523a86015e04bbf99649a9b43198da6.bpmn',
#  'Dispatch_of_goods_42528d54df304f9fa9c747c8d40deb35.bpmn',
#  'Exercise_3_-_Recourse_4fd5fffa728a4c5ab18cc6ae7a1cb95a.bpmn',
#  'Regressnahme_1b55d633d7cc4d42a686f4d0ec5a8b0e.bpmn',
#  'Neuer_Prozess_4331176882024b8cbfb4744a3afd4fdf.bpmn',
#  'Ueb1_warenversand_f5945d019bbb4c87b620e2acb9a5eaae.bpmn',
#  'Introduction_process_1a576095714945a6b69a0db064f2796e.bpmn',
#  'Regressnahme_0d677f1c89c7408a82ad9f0a9f301431.bpmn',
#  'Uebung_1_188fef94641f40ed819e499bd971ebda.bpmn',
#  'New_Process__bung_3_825e5707085c4cdfa76d23328e62c36f.bpmn',
#  'BPMN__bung8_0edf9a98f128438ea799cbcfd5d1006a.bpmn',
#  'AR_Selbstbedienungsrestaurant_0480957f29034d5890e1c7627876fb1a.bpmn',
#  'exercise5_d009430cddd648bb878e9718b9ffa27d.bpmn',
#  'exercise_4_adf9842718024dda988ae361bc983aa8.bpmn',
#  'Aufgabe_8_2c644cf8073c4f5786c6730e37e94a19.bpmn',
#  'Verpackung_59743237aa054032829604ae1c7b5d2e.bpmn',
#  'Regressnahme_1bb4f5b1eacc4135b257f068e55b3c94.bpmn',
#  'Schufascoring_05d7624502d14be2a8ed43182d5d10d7.bpmn',
#  'Regress7_85eb9b5d80b844179c1f66a4ae8f2f71.bpmn',
#  'sb_res_1c1b79546b0c4fa98eb8b5d61cd9c4b6.bpmn',
#  'Excercise_No_6_3230544fcc2245c7b4eadacd1ae3317d.bpmn',
#  'regress_-_english_00f46cfbf12d40259b9d3bc5f6265be6.bpmn',
#  'Neuer_Prozess_bf8f68238ff4425590cc3f5ba96b8c65.bpmn',
#  'Restaurant_02f9dfb2ae1d42aaa6e5e6de77867dfc.bpmn',
#  'Neuer_Prozess_c3a474cc6e414e249c747a31f530dcbe.bpmn',
#  'Aufgabe_3_539351f911444c3388d2661ba83ee73d.bpmn',
#  'uebung1_ab7669de0efc4b479f4f12d5af7130a5.bpmn',
#  'sb_res_f510acbd50284681a5d3ad7d1e4975a2.bpmn',
#  'SB_restaurant_10f3f260a04e4e65a701d0e99904e2e5.bpmn',
#  'Regressnahme_018315c4274049429ebd46d907d4b34f.bpmn',
#  'Exercise_3_0266c9c0cf4c407bbcdbb3e4ff245102.bpmn',
#  'Bestellprozess_beddf31ae83240119a346ca7ba0be591.bpmn',
#  'Regressnahme_137682c6bc164e8e848ebd537e4c209f.bpmn',
#  'Regressnahme_18b199f35b4e4186af3aa5e757fc6456.bpmn',
#  'Regressnahme_183b656fd4d8429b9b20a5ebc5edb113.bpmn',
#  'Warenversand_2e1ffeb733064bb9a2ac6ea9850df7b2.bpmn',
#  'Shipping1_c87ef14a31294d689947d679015e8afb.bpmn',
#  'Neuer_Prozess7_fde2374fe2f842b7a1da9c9a02ce2a93.bpmn',
#  'Regressnahme_1560f130df094c5f948948659e492267.bpmn',
#  'Regressnahme.bpmn_30c7e60e802a4f5da84c2a83222b8171.bpmn',
#  '1_61cde83dea954a0a80b769e291a7a462.bpmn',
#  'Regressnahme_19a2de1273ec47a7832148e5f048a342.bpmn',
#  'Dispatch_of_goods_e18aeed5fd1c4518a19ec88c87286f64.bpmn',
#  'Neuer_Prozess_b6a9732ef2874d58bbd70a96b0244a68.bpmn',
#  'schufa_a4f38b939b51458195055439e1483665.bpmn',
#  'Regressannahme_29a462158c0d4940890fbb9c7934465f.bpmn',
#  'Regressnahme_110825829b9042309158efef92416e71.bpmn',
#  'Neuer_Prozess_3_1ba0b5ab33e74eaea6267c207c5651d2.bpmn',
#  '4._Schufascoring_ab3591e0a0ad4280b33f60e7cf710988.bpmn',
#  'sb_res_0763249e134740f58fa5a0f4c06f2e2e.bpmn',
#  'Regressannahme_305ef4e463504378b2e2bd905ced7950.bpmn',
#  'Uebung_1__Kopie__34a375846b714369a1397470a9fcf36c.bpmn',
#  'Warenversand_c3e03fcb2b124ea3b3d8b9633ef145dc.bpmn',
#  'Banking_example_9c5d8339e9a344cd92a7ab481b70fb6a.bpmn',
#  'Uebung_1_2f63ecefd45d4e4db0c96fbbdcb885cf.bpmn',
#  'Excercise_6_-_Self_Service_Restaurant_582de3fc75fe426cabc4ba2eb23d41e9.bpmn',
#  'scoring_aaf4822263e449e0802d5d52d9ccc176.bpmn',
#  'U1_f529f48ede854a4b83de5aeb2bafe821.bpmn',
#  'schufa_-_english_9036e9ee5ce6477f9e5f77de6a1f71d7.bpmn',
#  'Schufascoring_2673700f3fe044b6aed92c1536fd4a13.bpmn',
#  'Aufgabe7_Schufascoring_Falsch_e881faad883d4dd9ac2d5ff8513bbaf2.bpmn',
#  'SB_Res_06e77a083e464850a392cb977b9b4a96.bpmn',
#  'Neuer_Prozess_38bdce6c4e9746a8833a6de718f6ca9a.bpmn',
#  'sbres_3a84596aece546b7b57e4959fc8d2b5c.bpmn',
#  'ueb_3_2aa01db67fcb490bbcf30506401a3520.bpmn',
#  'Exercise_6_-_Mo_cbcda7ed659747ce83406a85a54e054c.bpmn',
#  'regressnahme_-_english_c2c66918832340b5b437c6e1c6657b34.bpmn',
#  'regress_-_english_f28e862436f04ed9b8c4185607655706.bpmn',
#  'sb_res_157bc5904c244788ac1f58263a3d9312.bpmn',
#  '3.__bung_Regressnahme_6ad77fb7929143dd85d80f6b49a4ed7a.bpmn',
#  'Uebung1_Warenversand_108dffb5eb63403396717aa9457ebd70.bpmn',
#  'Schufascoring_0cc41d7a15494c96885eed28e6149a60.bpmn',
#  'Gruppe_2_87b19c8d212b4b58a8e7ba45934e05d3.bpmn',
#  '5_ec7492dcedfd4b7ea8184c2eb3b73e06.bpmn',
#  'Goods_Dispatch_Process_88375b73af094489a0cdf68a5d7638a5.bpmn',
#  'schufa_-_english_308188c10b7347afae658abc50a04948.bpmn',
#  'U1_ed0c7408524f4fd5b0345d788749b239.bpmn',
#  'Schufascoring_1a4d378b974e4e01a97927b65e8768c1.bpmn',
#  'Schufascoring_2e82aa7722a348b297a621062f03dfd3.bpmn',
#  'Schufascoring_08fd90bd43874dde850c2fa414fd21da.bpmn',
#  'sb_res_753450cf3552485a85c7d471354fd27a.bpmn',
#  'Aufgabe_7_Schufascoring_c612cc8ea5584028a549329658ff9811.bpmn',
#  'Regressnahme_1ba8743239894a7694eadb1a60b0fa69.bpmn',
#  'Exercise_6_c3f0e803cac24477bb8208f6deff6fd1.bpmn',
#  'Uebung_1__d27d470b22ac4c13860a644ba38d44b0.bpmn',
#  'sb_res_0689b59bd71e424aa17666864c43dce5.bpmn',
#  '8-SB-Restaurant_50db89bd483140b893e94689c43adc28.bpmn',
#  'Warenversand_d01f9fe7bbc848908890d43211a4b62d.bpmn',
#  'Neuer_Prozess_b6c58db3ffe54406b81c2a50f7725d68.bpmn',
#  'Dispatch_of_goods_e15d4cc6ccaa497bb89d24d2447af7c7.bpmn',
#  'Exercise6_SelfServiceRestaurant_98eed32c8f5944608143c34879ac079e.bpmn',
#  'Restaurant_4793c69525874b249384b29b41192815.bpmn',
#  'sb_res_-_english_3bfc8a6ce50d4a049e1c8581660105bd.bpmn',
#  'Schufascoring_0a7b16f376254bcab0c6a115fc6929cf.bpmn',
#  'Regressnahme_14bbc1e0cb9f41a78aea8bc329ba1cc2.bpmn',
#  'Regressnahme_192623ae4d5948b2a6a32c11acfc0116.bpmn',
#  'Regressnahme_114c02b4cd654a3f8f56b9d5960d0991.bpmn',
#  'Schufascoring_29e8c87d5e994977870f4d725eeef013.bpmn',
#  'regressnahme_-_english_108be4bbda21469d889ec3aedb4ec7c6.bpmn',
#  'Regressnahme_10646063c9af436cbd1087b0b12a460d.bpmn',
#  'sb_res_2579331798f84f89a1d9c41c23900995.bpmn',
#  'dispatch_of_goods_e7a9ade4d2b74b9aba073f36d424c23a.bpmn',
#  'Aufgabe_1_13fffd5830674bb8895ca7f4b4ac7546.bpmn',
#  'Versand_14b06c4bbf2947498f09d7774bec16d3.bpmn',
#  'Essensausgabe_df7ca16d07cc4bf6a64a291fa63a6518.bpmn',
#  'Credit-Scoring_1b37e3c83ccb4102baa284e941257249.bpmn',
#  'Neuer_Prozess_a7e30e0867cb472e8b3c1e87f00e00bc.bpmn',
#  'Exercise_5_-_Credit_Scoring_37798b8209004e66b3da74e355ed1da9.bpmn',
#  'restaurant_ffc7b73e879346bd83c7434a7b0c0791.bpmn',
#  'SB_Res_0894786236e14658a4caa26a66b4947e.bpmn',
#  'Aufgabe_8_5bdb6c217e2643e79d3ed434dbcae86e.bpmn',
#  'Restaurant_e19e0b46712e4927b8de269bb0d51714.bpmn',
#  'Aufgabe1_cb5f3852bee94c998b75208aed16e373.bpmn',
#  'SB-Restaurant_42f5aa38f59b4a058a83e0d4c73bdec3.bpmn',
#  'SB-Restaurant__bung_8_7d918bd14dda434683fe6c148a6886db.bpmn',
#  'schufa_-_english_934efdba928b45e2a088984c80a605f5.bpmn',
#  'Kreditvergabe_Schufascoring_2fc73ea29913423cbd8b8e41278e9f0b.bpmn',
#  'Recourse_d59e20f0a25a43598bbb124c8df8bd42.bpmn',
#  'Exercise_6_ca91688a44e242399e0ecccfe91aa3f7.bpmn',
#  'Ueb_1_2406a119b36d4622bb15acecc633b3e8.bpmn',
#  'Gruppe_3_6e2af121e6b3468b9405c89b1df90445.bpmn',
#  'sb_res_31c985d8f759416daabedeea33cd263f.bpmn',
#  'Schufascoring_298230100d204035960fd1478a7dcaa5.bpmn',
#  'Ueb1_06a9fb661e12460da44d83a9f6cf8c59.bpmn',
#  'Ueb1_f5c1c57832e0445fbd8d4b6cc19c63b6.bpmn',
#  'New_Process_e4405e688afa461a912b03281c13e44d.bpmn',
#  'Uebung_1__Kopie__1f68aea533824fd19a25edc72f9288a1.bpmn',
#  '01Warenversand_39f5a5faf1c5480a9b04bc7bb39fb095.bpmn',
#  'Regressnahme_0dd4ea15cdd842f3821ce0c79be07f70.bpmn',
#  'ex6_ba4409baa5b04e3b86dd1d9d84a4940b.bpmn',
#  'sb_res_201955102baa434a970461281e2c2ca8.bpmn',
#  'Neuer_Prozess_55d0873f5076426bbadfa972a1941b4f.bpmn',
#  'SB-Rest_c1f338eeb4a84e1d99429824c4cc0812.bpmn',
#  'Exercise_6_7caa2d0ef6e24b9c8f9ba67ac52218e4.bpmn',
#  'Schufascoring_063c54c7ddaa461386d3eeb1fd3cfb01.bpmn',
#  'Uebung_1_4b25fc319e424a81b24217fdcaef3fcc.bpmn',
#  'sb_res_1f758516e8c2424b83e5b105365d7af9.bpmn',
#  'schufa_cc1cce726da04f8ca0c2ee3002ec84ea.bpmn',
#  'Prozess_Regressnahme_d2aeec12059a4b26a8f62cbd72b0ae48.bpmn',
#  'Warenversand_548dc90cb01e4f8d974ae747b7063277.bpmn',
#  'Regressnahme_008d9ebad34a4414bffef240b8c98a8c.bpmn',
#  '1._Warenversand_f98ccccb5a944ffd9d958cdd3d8d709c.bpmn',
#  'ex_5_c70fdbb34707491aa86dfa0e8cf7ab74.bpmn',
#  'sb_res_c43915cc6c2d4937bee210ba0a0f3af5.bpmn',
#  'sb_res_5ac4e5e23c4f42369229de8242e18544.bpmn',
#  'Uebung_1_11343739c9cd40469faf78966f0985e4.bpmn',
#  'Neuer_Prozess_d11c9ad349b94352a9c79ad30b3d6527.bpmn',
#  'Ueb_1_5b90622ea1ec482d84c8f917677e4750.bpmn',
#  'Exercise_Self_service_12f9a20eeb7f43438eca598a8c6679e1.bpmn',
#  'Ex_1_5c938029abe34f469fb9681f46bbbe05.bpmn',
#  'Credit_Scoring_cf0e56ba1f6747d6a21978128da3fe4c.bpmn',
#  'Aufgabe_8_b459e598bbea479cbe49c5d84a6d43dd.bpmn',
#  'Schufascoring_29c7316b86894ad585fbb8aab514bf6b.bpmn',
#  'Regressannahme_ba77a60c32f548288e4b11210becbf73.bpmn',
#  'Ship_Stuff_Places_d10f51a64bc44b66b62d075c86a44acb.bpmn',
#  'Aufgabe1_Warenversand_Alternative_cdc7b6dcb6c142c18ba2a1e0ef9b2b1e.bpmn',
#  'New_Process_fb4af19e87fc436591f5699c7bbd6aac.bpmn',
#  'Neuer_Prozess_72826da3814c4aa893e3044243bd6640.bpmn',
#  'Aufgabe8_Selbstbedienungsrestaurant_9c9fec2b44ea43439db65e7b08c5bb7d.bpmn',
#  'Neuer_Prozess_dcae3792e19348208aae308ca6baeaf3.bpmn',
#  'Ueb_1__Kopie__f3db524a254e487c9efcab6e18726efe.bpmn',
#  'Uebung1_Warenversand_e665d28399534649880567f75d775638.bpmn',
#  'Regressnahme_1488e4c63dae480bb46c33c6d653791a.bpmn',
#  'Schufascoring_29a83927191f452296741e43aea8f701.bpmn',
#  'sb_res_007a6696804a4a54ad3ef642a3c4448d.bpmn',
#  'Aufgabe_7_afcf1e818a444213ae439ecbb29f97a9.bpmn',
#  'sb_res_1ff3f0b3ffb84d2598f99fed2ef1a039.bpmn',
#  'warenversand_-_english_f82c49fe7d3049508df36c3c5e85f670.bpmn',
#  'Warenversand_a4b39bf1472141fbb7b5fa74036e6b18.bpmn',
#  'warenversand_-_english_9e898f1d45534679ac6317895675bb1b.bpmn',
#  'Aufgabe_1_5b60340cf441488b9f9fe17194b370b2.bpmn',
#  'Schufascoring_0c64a3abcf674e2ea46db09567d909cd.bpmn',
#  'schufascoring_2bc862c72213466a9fa6d8ad75a3c526.bpmn',
#  'Regressanspruch_an_VN_7375f350582640cdb87abd9d9ff5d875.bpmn',
#  'Versand_86a3d58f7ba44a8f8a983854cb91adcc.bpmn',
#  'Regressnahme_04e22456cc9b4a6db6c187d983e45f53.bpmn',
#  'Aufgabe_7_-_Schufascoring_112537f7ba20411196e8c58da704a8a5.bpmn',
#  'sb_res_-_english_08695596d1e042c8810e806ba86c4626.bpmn',
#  'Aufgabe7_852ebf89163047f98afe469f8dcd803a.bpmn',
#  '08_Restaurant_e841593ad625450d951d0558b35d6c02.bpmn',
#  'sb_res_-_english_f32cdfca071e410b8f1cba20e7eb987a.bpmn',
#  'Uebung_1_-_Warenversand_14eead9ee2ea483aa9028df703693683.bpmn',
#  'Gruppe_3_1557c71ef31d44bc87f6cde4101d43a1.bpmn',
#  'Regressannahme_aabc0d893be747d5b981686fb3fc6389.bpmn',
#  'Uebung1_30f20e0e00f944cd941fc4048b5bb96f.bpmn',
#  'excercise_3_10a68c9e6f4e4fcc84918adf2f42d905.bpmn',
#  'schufa_-_english_0a559ba5e61147babcdd833ba726e53e.bpmn',
#  '-_Task_1_cb967b14c29e4f8f9d182d67559547a2.bpmn',
#  'Neuer_Prozess4_1920a3905ccc41f8a8d64b451d85ad42.bpmn',
#  'Demo_Signavio_a3a309cd8a0a4b9881088a1b4c1a523a.bpmn',
#  'Ueb_1_59c9268d942b44ce873250b50f61c0c5.bpmn',
#  'SB_Res_12f1b57ea7624d539cad7491a2211a1b.bpmn',
#  'Warenversand_9d83f8d992b647feb794f8441e98cb56.bpmn',
#  'Self_service_restaurant_4b8c26ed37fc4748b9b9b5185b4de357.bpmn',
#  'Regressnahme_1109562f49544672822efa1601fe666b.bpmn',
#  'sbres_713847797c6e46b8ba0ba804676c8b07.bpmn',
#  'Schufascoring_11346f14bd6a44bba74d7b04a0e809ae.bpmn',
#  'sbres_22a9f11dd4c9426a8cc76dd1ba133c47.bpmn',
#  'SB_Restaurant_b7b91f57a87c4503b86691ed00332544.bpmn',
#  'Aufgabe_3_6c08c1c8f6a54c43ae18c89d07016d0f.bpmn',
#  'sb_res_2009ea31c0d14d2394ed430213c66127.bpmn',
#  'Schufascoring_320be7db23644d77ac85209fe353c299.bpmn',
#  'Regressnahme_0c6a3dc60dbb477ba516f7df6f115439.bpmn',
#  'Exercise_2_b50619da01bf417dbb39b6d3b743f180.bpmn',
#  'Schufascoring_32a3585ee595487b9488edfe18cb1ac0.bpmn',
#  'Ueb1_9cb012f2a8a04dcb9f37f20e997562b9.bpmn',
#  'warenversand_-_english_e0b26a385fc94223bfc6636fee14cd5b.bpmn',
#  'schufascoring_0240da41b0ed4131b9aedc97609899d6.bpmn',
#  'Schufascoring_2ac9c0445421429dabf14bf7183833b8.bpmn',
#  'Exercise_3_9121248188244e0ab3eb6bc7458020d7.bpmn',
#  'Regressnahme_-__bung_2_352297699a4c42b499dce3d88d788170.bpmn',
#  'Getting_started_e777850241824c3eb82991dd22c4bcd3.bpmn',
#  'Regressnahme_189d863c3dd64bc796d2443372a494ed.bpmn',
#  'regress_-_english_b9048750ab114f7489ffaa2fbd5ae7b0.bpmn',
#  'Recourse_86d1ce1b0c73424c8edb8a136099b586.bpmn',
#  'regressnahme_1967fa861dbe41e7bba58f8ec5cbd428.bpmn',
#  'Ex_6_09b9064294754762a3a867c80c7e18e9.bpmn',
#  'Exercise_3_Recourse_d6c211d232e248ed83cad2a0dcb1e19e.bpmn',
#  'Recourse_642c92777f41437c8765ee142cb6964c.bpmn',
#  'Aufgabe_3_79db7a163b68425487ecc080bffd257b.bpmn',
#  'exercise_3_f112eba5f0e743c086ce71692223ecbc.bpmn',
#  'Regressnahme_01804d92afad4b1bab3e795aaffcad47.bpmn',
#  'Schufascoring_07b8514e6b5e48608a110ce7d9f8be84.bpmn',
#  'Aufgabe1_Warenversand_9c7ad926c64d41e0b176fa052ea60ef6.bpmn',
#  'Exercise_5_-_Credit_Scoring_1fc61d382ab94be8b898d20ef473faa2.bpmn',
#  '3_56a29c753e8648b7aa9c4715e6471363.bpmn',
#  'sb_res_1efaaca9e62e4d6bbb68e5fbf291198f.bpmn',
#  'SBRes_e7a30e03bc2245eba51ba05e188c5cb6.bpmn',
#  'Getting_started_1f8e95e3da60497c881e9fd8cd35b6ef.bpmn',
#  'sb_res_28197d17a2594045aba890cc8ba97a51.bpmn',
#  'sb_res_38b11d1c79c240e6ae43f3fa72936047.bpmn',
#  'Spedition_Versand_3cd5b9a5fb03437e8e93ec833b3062d7.bpmn',
#  'Restaurant_4e89986a847b436e9044011a477feaaa.bpmn',
#  'Schufaschoring_d3a419326e9845bf81b32e14c5d1f54d.bpmn',
#  'sb_res_2538cc5e47244b51890458072a087571.bpmn',
#  'sb_res_2f47ad10b81840d18d1a35e76b9fed09.bpmn',
#  'Uebung_1_a00858d6a49d4542a832c5b73f76c849.bpmn',
#  '1-Vorbereitung_des_Warenversands_02c53df6c112481183fec4b929fd3210.bpmn',
#  'Regressfall_9b6bf62771ab4e34a90047b19fc9077a.bpmn',
#  'Aufgabe_8_34c31fc272c14db2953b555120fe6239.bpmn',
#  'Warenversand_e74e4fbcba1a48d3a4283a2e5bea3a2f.bpmn',
#  '5._Selbstbedienungsrestaurant_8360972545fd4ec983f0e99db7b83cd3.bpmn',
#  'schufa_-_english_0946457aa55d43128d426a918a5d7236.bpmn',
#  'training4_905329c3c19346cf88db536bb88aa13c.bpmn',
#  'Gruppe_1_129b3edff83046fbbb5fe0197edcbe7e.bpmn',
#  'warenversand_-_english_f5e771b95fa9417199e370c546d07fa1.bpmn',
#  'Fastfood_39135079bae84a83855eba2eb104f2e2.bpmn',
#  'Self_Service_restaurant_cc9540b00bd74682b802d60c3a56fd4b.bpmn',
#  'sb_res_20088479b4b14fd28ae4a124e553d380.bpmn',
#  'Versand_1_36cd9a7cc49f4ec1893ae1b392a98b13.bpmn',
#  'schufa_-_english_24cb7469102143b4bd173097af0eabed.bpmn',
#  'Warenversand_02f6546a9af14168b38ec7ded24fd874.bpmn',
#  'Ueb_1_-_Warenversand_2d7b631d368f4db39985e449f50b5bee.bpmn',
#  'schufa_-_english_621180c183cd44d8bd93335fdb5df8b9.bpmn',
#  'Regress_d57d9fc240e841bd816ca2e522bb3b1f.bpmn',
#  'Schufascoring_1303f949a35a4cc98d43e111f3ffb0b4.bpmn',
#  'sb_res_04729f33ec3748bfbcd4a8fb2ace91e5.bpmn',
#  'Demo_Signavio_797994f4f44a4fe19973343fef6381c3.bpmn',
#  'SB_Res_1aa3ef24096c483e8ffd0f418bfa3872.bpmn',
#  'Ueb_1_964b8ce5bb7f42f1936a384f416a75ae.bpmn',
#  'Regressnahme_148ab4debdfd4314a3cac0928c325db2.bpmn',
#  'Schufascoring_0abaa96399cf47c598e37eaa503cf736.bpmn',
#  'excersise_no1_525ba14ce6564d30868a15be6b485914.bpmn',
#  'sb_res_b8e10fa9a55c413c98991c88dfd19ad9.bpmn',
#  'Neuer_Prozess_1627e1d15734446cb204230582ca35d6.bpmn',
#  'Regressnahme_0fce95e6a6ff43f1919f9883fd6deac0.bpmn',
#  'diagram_2__b71135062c944fefa4b8ad30f78b61d2.bpmn',
#  'Ueb1_4ec1c4a29899415e8d4c4fd99b08ced6.bpmn',
#  'SB-Restaurant7_33d3896a46be439fac116f2ea9998912.bpmn',
#  'Aufgabe_8_-_Selbstbedienungsrestaurant_feccb78234c344c68952e1c6e775a178.bpmn',
#  'self_service_804ad34a22514f049b6290366bb26ada.bpmn',
#  'Ueb_1_45ae8b02328540a49383d78a8fe78716.bpmn',
#  'sb_res_0d837718b28446af96879da267bb9d4f.bpmn',
#  'New_Process_868f6a345e8141de8ce0515f4d3dd13f.bpmn',
#  'excercise_1_a55ce1fcd0964142b053ec217b5b81df.bpmn',
#  'sb_res_0f774ac96acc41b5ac3d48c3df470b2a.bpmn',
#  'Practice_1_353c97ab7bed479d9a430698d2e28669.bpmn',
#  'sb_res_25e58d80b1d54041b5ac0b25a02a9461.bpmn',
#  'My_first_example_process_2_40ebe9ccb3e142f7823aedc43cd7d617.bpmn',
#  'Regressbearbeitung_d24b933c7fc04049a9364c72380267b4.bpmn',
#  'Schulung_01_Warenversand_a3713d7a145d414aa8a2e22ebdce3499.bpmn',
#  'Neuer_Prozess_093ca23ed382481ca97f7ff76d859e2c.bpmn',
#  'Self-Service_restaurant_9ddc1aea6c2040e1ac02d499232745d9.bpmn',
#  'Exercise_5_ba1485aebed7460fbb21dade8e766308.bpmn',
#  'sbres_675762e5e4ad495bb43ffa4281030081.bpmn',
#  'sb_res_033d7eefff9c422693945757445ae5a1.bpmn',
#  'Aufgabe_1_9bb6ec61b2df4f069bb39b728bd1bd88.bpmn',
#  'Self_service_restaurant_68f4ca540e614a5da586e3ea733cc838.bpmn',
#  'Regressnahme_11580c93ce5049bea90fa43bd76f779d.bpmn',
#  'schufa_-_english_18c538f660cc4c948c89b5e5f689373c.bpmn',
#  'Warenversand_c122e662a3914f36b71bae9049e8f1a2.bpmn',
#  'Schufascoring_03df9577c53b4b0fa45bfd070ade57b3.bpmn',
#  'Regressnahme_104eb27567b54ddba438a16fe94a0fa6.bpmn',
#  '5._Selbstbedienungsrestaurant_f65c8daf16aa41999a24ad6339e1ec8a.bpmn',
#  'New_Process_87d1dc0dfa584e25b5df54d160b7d831.bpmn',
#  'sb_res_07468767fee6426bad5e76a27c225020.bpmn',
#  'sbres_271b406dc07647cea3735a0a5a2f43c8.bpmn',
#  'Regressnahme_1494f24bf43645cf9976324c08b056c1.bpmn',
#  'Neuer_Prozess_95c331ed5d8a4073a7661a7231b4bee3.bpmn',
#  'Warenversand_035d8eef52bc4e36aac840bdd2feff21.bpmn',
#  'Schufascoring_2fec1a422ead4d57a103fa1873b5f63d.bpmn',
#  'Neuer_Prozess_3_af8453466fcf473d8ce4ba1091860349.bpmn',
#  'Essen_bestellen_6ede749721d3431b845d460dc5e6e35f.bpmn',
#  'sb_res_1fab4251148440229fece3b8798dbd6d.bpmn',
#  'Recourse_Process_4ec053cbebfd4cb88665ee6916ae9ff9.bpmn',
#  'Restaurant_0dc57ca7e61943d3abe7b386d563b9c7.bpmn',
#  'Schufascoring_15fe536bfcb047eb94bf3cd6f2d011b7.bpmn',
#  'Regressnahme_18201fad175442ca9547e3de00cd3478.bpmn',
#  'Ueb_01_Warenversand_baf03525efe34fb7bda48a05cf8d5988.bpmn',
#  'Neuer_Prozess_7d389fcd90c04b19892721e639dd2714.bpmn',
#  'Schufascoring_2106d5da4b6e40fabf564396e2e347c5.bpmn',
#  '04Selbstbedienungsrestaurant_ed827e5edd6249fca7269c8f5ff81450.bpmn',
#  'Schufascoring_2f54ed1b1033424db6116e6a1a411a55.bpmn',
#  'sbres_5a535a7dc4804241907e1441037d03e8.bpmn',
#  'Regressnahme_154a43ec5a51400c9998269ebee9308a.bpmn',
#  'Warenversand_20c63fc6e6014007803f6ad3fffbb7b3.bpmn',
#  'Regressnahme_0ad24609626e448db8000a8d6a07f53a.bpmn',
#  'Recourse_278b4fbb149046b59be1ff09f204e2e8.bpmn',
#  'Ueb_1_18e9e34d274c4b7b9f94a98deb71a098.bpmn',
#  'Self-service-restaurant_ecd08e1f85ca4517970d783023222701.bpmn',
#  'Dispatch_of_Goods_edea3e34adaf4d0aabba9f894aee435e.bpmn',
#  'SB_Res_241eb3cf62244254a6391b53cbba7799.bpmn',
#  'Neuer_Prozess_721f92d85d6244f1b2f2015f2d44caf4.bpmn',
#  'sb_res_26e39a7810c84c9987762c53d8b1d3bd.bpmn',
#  'warenversand_-_english_25daf2131b254bb988d92bf50f47165e.bpmn',
#  'Warenversand_af7eded5837d4110aaff76292a17e898.bpmn',
#  'Regressnahme_0e6503af5fff4474884eaa47c33ee2b1.bpmn',
#  'Regress_704a8615921f45399fb1ed8e6d0393c8.bpmn',
#  'Schufascoring_04975a906d4c41ada24c6651dc002ef3.bpmn',
#  'sb_res_1e71da2314734ac49a61ddca5fb3ea4f.bpmn',
#  'Regressnahme_02d6ea7cf0364bf082eada21a5432ddf.bpmn',
#  'Recourse_255e20f2a6754fa483bc4ebeed103fab.bpmn',
#  'Exersice_6_3962936d90e3428395510e481cbfc709.bpmn',
#  '6_3b62a82015a44b41a0b39cf85d6fa9c0.bpmn',
#  'Regressnahme_0d020057de0f488686d0cb56ab0d078e.bpmn',
#  'Schufascoring_231846b09cc44700813e489731ba6322.bpmn',
#  'Regressnahme_0c9922d3d1294983aa5df1f73a501fcd.bpmn',
#  'Schufa-Scoring_b374eef921fc45fca65803dcef8945a7.bpmn',
#  'BPMN__bung7_cd9a8d06b62c46ac836893bc8b518c7f.bpmn',
#  'restaurant_c5bb39524ead40cab3d7ea8264254c90.bpmn',
#  'Schufascoring_32ad5806b2584aeebf10464b0f2a0cd4.bpmn',
#  'schufascoring_0265c8a2d4104f79a46c09413bc1cc79.bpmn',
#  '3-Regressnahme_abaeb1bfe7cb46448a9126aa13cc0084.bpmn',
#  'sb_res_106255b1366f4e28a39e731d30828e93.bpmn',
#  'Aufgabe7_Schufascoring_86493d048c7d45d387dd1b0fc0539c8f.bpmn',
#  '04__Schufa_2f43881cfdd54aa2b75ea1ba63060e61.bpmn',
#  'dispatch_of_goods_2a1f9e8760a844f9b1794af65d2746ee.bpmn',
#  'schufa_-_english_fb59a964435d4aff81fdc3e113a54def.bpmn',
#  'Excercise_1_Dispatch_261502e16e3a457e8f2787775defec9d.bpmn',
#  'Uebung_1__fd9a5b04281a40329f00dfdc67dbd824.bpmn',
#  'Schufa-Scoring_ca613085d7bf484cb9d82e140bec9fba.bpmn',
#  'Regressnahme_0aad426b5f3347f695af87588489460b.bpmn',
#  'Anja_s_Prozess_90e7bd8bf5ab479488eebc022846df81.bpmn',
#  'Excersice_1_-_Dispatch_1a8a50c30419488aabd2048fbb0b05bd.bpmn',
#  'sb_res_3021f36dfd6f48118227eae91ea41081.bpmn',
#  'Schufascoring_17a5db1c566d4b10807d62daa1e0f11c.bpmn',
#  'Ueb_1_-_Warenversand_366611618d6c4626bd1d5fc7eff833d4.bpmn',
#  'Aufgabe_7_e18e5f3c92fd4c298cc56ae757499cb9.bpmn',
#  'Regressnahme_07453236629d41f783273795efa20499.bpmn',
#  'Regressforderung_388ac24aed634cc284cf38ffe13e33c7.bpmn',
#  'Recourse_8124d095ed5f49d5962d470b9f5ca4f6.bpmn',
#  'exercise3_7ee596d13551419bb641ccc3e3b626d3.bpmn',
#  'Credit_scoring_ae633fa3ecc14bceb7aeb6a7804d1856.bpmn',
#  'exercise_no5_37c17092b35247f58518eb4d2ab5645f.bpmn',
#  '3.__bung_Schufascoring_05b570bf728346a7b552f0a8d64d49da.bpmn',
#  '2._Regressnahme_fd071e371530415dbd1c605de3888422.bpmn',
#  'Regressnahme_1ba7770d7e3344a9839ce2c54499613a.bpmn',
#  'Uebung_1_c02448e060aa4b669debe456d0c2a2ae.bpmn',
#  'Regressnahme_0727a09b397c466fbd49dede436388ad.bpmn',
#  '-__bung_3_2bdcf0e75ba0441a9c2e775e9b3555b8.bpmn',
#  'Neuer_Prozess_23e938b44f824662a00e19e8935e9c3a.bpmn',
#  'Uebung01_-_Vorbereitung_des_Warenversands_7e29b9823d6e4c1794ffe90919af7028.bpmn',
#  'Exercise_1_-_Dispatch_of_goods_2713aaa1952d48a5a073e41d2eb1084d.bpmn',
#  'sb_res_d40a7067ee2246a3a35adf81f9ed8035.bpmn',
#  'regress_-_english_934d0426ada64e61ab0e9b254c4e79de.bpmn',
#  'Schufascoring_209ba4dbb9044275ab88227618f9e694.bpmn',
#  'Regressnahmen_e6fd2b6da6774634ab02d6515a9a4929.bpmn',
#  'Regressnahme_16eb61b3460141248676dfc0e8091749.bpmn',
#  'recourse_b8a5a44bb61249d19fb9b58f46492536.bpmn',
#  'Schufa-Auskunft__Kopie__01f56907b7ab4478ba528a3dce3d2b90.bpmn',
#  'schufascoring_1b7381ae775e4911b14cd3614c1d04d4.bpmn',
#  'Restaurantbesuch_03a3248b42e04f028ea810cffd2f8877.bpmn',
#  'sb_res_14325134151c4649a9be32f0f6083f8d.bpmn',
#  'Uebung1_3e24acc5f8b94defa632fb7e9b3f1bd2.bpmn',
#  'exercise_6_meal_order_81c81a3ac16946029367bc9b283ecacf.bpmn',
#  'schufa_-_english_4ab9e56a8f344f35b3b787e8c216b999.bpmn',
#  'SB_Restaurant_af85089cd17b4e9f859d85bb38ad4e09.bpmn',
#  '7.__bung_Schufascoring_2412bb6ac495488687185c74dcdcaf90.bpmn',
#  'Regressnahme_0df9a5618e1648bdb44bb5df13af73a7.bpmn',
#  'Regressnahme_0969d965707946dfb928feb6eba41a46.bpmn',
#  'warenversand_-_english_00f5b29d34c8482d9ec476f554c6dad0.bpmn',
#  'restaurant_efcfa14d4fc54f0781b3320a8f9a95ef.bpmn',
#  'warenversand_-_english_6843b3e3b2654272ae66fb40928d3858.bpmn',
#  'Schufascoring-Prozess_2e40716b5f164257be015e2ac2eaa3a9.bpmn',
#  'Regressnahme_0d921ac6a7f6406aad8f0c1d5b7f8f49.bpmn',
#  'Regressnahme_17c594259b9d49acbf73b5eaf9c4be3c.bpmn',
#  'Neuer_Prozess_1257630bfb5d4ca5979900aed5cb8f13.bpmn',
#  'Neuer_Prozess_2_41792120ac0d42fc86ec63a70f6859ad.bpmn',
#  'regressnahme_-_english_53f7c52ab6dd402a9f74f682293fb1cf.bpmn',
#  'sb_res_06c5a0349647415faec6e97da8e87808.bpmn',
#  'sb_res_22c3fa6a0dd34259a1ad03b8a8a92399.bpmn',
#  'Schufascoring_2b3dd71bf4e3496fa02cc35931562854.bpmn',
#  'sb_res_-_english_6edf5e251949497fb41e1d9d1f59f020.bpmn',
#  '-__bung_7_fe81e155c2d94fe084b74e23102f684f.bpmn',
#  'Schufascoring_2ca380b786cc4c37a014e4991ada99ed.bpmn',
#  'Schufascoring_2849235a18b04db1b6e2168a8bef2b7b.bpmn']

# %%
import numpy as np

def generate_inputs(bpmn_graph):
    """
    Generates the inputs for the embedding model from a BPMN graph.

    Parameters:
    bpmn_graph (dict): The BPMN graph.

    Returns:
    tuple: The node features and adjacency matrix of the BPMN graph.
    """
    # Create processor
    bpmn_processor = BPMNGraphProcessor()

    x = bpmn_processor.get_node_features(bpmn_graph)
    x = np.expand_dims(x, axis=0)  # Expands the dimensions to (1, N, F)

    a = bpmn_processor.get_adjacency_matrix(bpmn_graph)
    a = np.expand_dims(a.toarray(), axis=0)  # Expands the dimensions to (1, N, N)

    return x, a

def generate_embeddings(bpmn_graph, embedding_model):
    """
    Generates the embedding of a BPMN graph using a given model.

    Parameters:
    bpmn_graph (dict): The BPMN graph.
    embedding_model (Model): The model to use for generating the embedding.

    Returns:
    np.array: The embedding of the BPMN graph.
    """
    x, a = generate_inputs(bpmn_graph)
    embedding = embedding_model.predict([x, a], verbose=0)
    return embedding

def measure_similarity(graph1, graph2, prediction_model):
    """
    Measures the similarity between two BPMN graphs based on their embeddings.

    Parameters:
    graph1, graph2 (dict): The BPMN graphs to compare.
    embedding_model (Model): The model to use for generating the embeddings.

    Returns:
    float: The cosine similarity between the embeddings of the two graphs.
    """
    a_X, a_A = generate_inputs(graph1)
    b_X, b_A = generate_inputs(graph2)

    # Generate the predictions
    prediction = prediction_model.predict([a_X, a_A, b_X, b_A], verbose=0)

    return prediction[0][0]

from sklearn.metrics.pairwise import cosine_similarity

def find_most_similar_graphs(graph, all_graphs, embedding_model, n=5):
    """
    Finds the top-n most similar graphs to a given graph based on their embeddings.

    Parameters:
    graph (dict): The given graph.
    all_graphs (dict): All available graphs.
    embedding_model (Model): The model to use for computing the embeddings.
    n (int): The number of most similar graphs to return.

    Returns:
    list: The top-n most similar graphs and their similarities.
    """
    # Compute the embedding of the given graph
    graph_embedding = embed_bpmn(graph, embedding_model)[0]

    similarities = []

    # Compute the cosine similarity with each other graph
    for other_graph in tqdm(all_graphs.values()):
        other_embedding = embed_bpmn(other_graph, embedding_model)[0]
        similarity = cosine_similarity(graph_embedding.reshape(1, -1), other_embedding.reshape(1, -1))
        similarities.append((other_graph, similarity))

    # Sort the graphs by similarity in descending order
    similarities.sort(key=lambda x: x[1], reverse=True)

    # Return the top-n most similar graphs
    return similarities[:n]   

def find_most_similar_graphs_predictive(graph, all_graphs, prediction_model, n=5):
    """
    Finds the top-n most similar graphs to a given graph based on their embeddings.

    Parameters:
    graph (dict): The given graph.
    all_graphs (dict): All available graphs.
    prediction_model (Model): The model to use for computing the embeddings.
    n (int): The number of most similar graphs to return.

    Returns:
    list: The top-n most similar graphs and their similarities.
    """
    # Compute the embedding of the given graph
    graph_inputs = generate_inputs(graph)

    similarities = []

    # Compute the cosine similarity with each other graph
    for other_graph in tqdm(all_graphs.values()):
        other_inputs = generate_inputs(other_graph)
        prediction = prediction_model.predict([*graph_inputs, *other_inputs], verbose=0)[0][0]

        similarities.append((other_graph, prediction))

    # Sort the graphs by similarity in descending order
    similarities.sort(key=lambda x: x[1], reverse=True)

    # Return the top-n most similar graphs
    return similarities[:n]

# Get a random BPMN graph
bpmn_graph = all_bpmns['Warenversand_e74e4fbcba1a48d3a4283a2e5bea3a2f.bpmn']

# Predict the class
embedding = generate_embeddings(bpmn_graph, embedding_model)[0]
print(f"Embedding: {embedding[:10]}")
print(f"Original embedding: {bpmn_graph.get_graph().get('embedding')[:10]}")

from sklearn.metrics.pairwise import cosine_similarity
sim = cosine_similarity(embedding.reshape(1, -1), bpmn_graph.get_graph().get("embedding").reshape(1, -1))
print(f"Similarity: {sim}")
# Out:
# Embedding: [63.484455  -6.6351576  9.225604   0.3273945 14.887474  81.42805
#  11.767649  23.712578   7.440567  23.998283 ]
# Original embedding: [ 0.02272176 -0.04879468 -0.01840889 -0.0084742   0.05015309 -0.08949476
#   0.18099     0.09640867 -0.13617192  0.0034371 ]
# Similarity: [[0.02656512]]

# %%
bpmn_graph = all_bpmns[list(all_bpmns.keys())[5]]
matches = find_most_similar_graphs_predictive(bpmn_graph, all_bpmns, model, n=5)

print("-----------------Matching:")
print("Query: ", bpmn_graph.file_path)
print("-----------------Results:")
for match in matches:
    print(match[1], match[0].file_path)

bpmn_graph.draw_graph()
for match in matches:
    print(match[1], match[0].file_path)
    match[0].draw_graph()
# Out:
#  11%|█▏        | 68/597 [00:03<00:24, 21.45it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 2
#       1 bpmn_graph = all_bpmns[list(all_bpmns.keys())[5]]
# ----> 2 matches = find_most_similar_graphs_predictive(bpmn_graph, all_bpmns, model, n=5)
#       4 print("-----------------Matching:")
#       5 print("Query: ", bpmn_graph.file_path)
#
# Cell In[20], line 111, in find_most_similar_graphs_predictive(graph, all_graphs, prediction_model, n)
#     109 for other_graph in tqdm(all_graphs.values()):
#     110     other_inputs = generate_inputs(other_graph)
# --> 111     prediction = prediction_model.predict([*graph_inputs, *other_inputs], verbose=0)[0][0]
#     113     similarities.append((other_graph, prediction))
#     115 # Sort the graphs by similarity in descending order
#
# File ~\AppData\Roaming\Python\Python311\site-packages\keras\src\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\keras\src\engine\training.py:2550, in Model.predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    2548 callbacks.on_predict_begin()
#    2549 batch_outputs = None
# -> 2550 for _, iterator in data_handler.enumerate_epochs():  # Single epoch.
#    2551     with data_handler.catch_stop_iteration():
#    2552         for step in data_handler.steps():
#
# File ~\AppData\Roaming\Python\Python311\site-packages\keras\src\engine\data_adapter.py:1331, in DataHandler.enumerate_epochs(self)
#    1329 """Yields `(epoch, tf.data.Iterator)`."""
#    1330 with self._truncate_execution_to_epoch():
# -> 1331     data_iterator = iter(self._dataset)
#    1332     for epoch in range(self._initial_epoch, self._epochs):
#    1333         if self._insufficient_data:  # Set by `catch_stop_iteration`.
#
# File ~\AppData\Roaming\Python\Python311\site-packages\tensorflow\python\data\ops\dataset_ops.py:506, in DatasetV2.__iter__(self)
#     504 if context.executing_eagerly() or ops.inside_function():
#     505   with ops.colocate_with(self._variant_tensor):
# --> 506     return iterator_ops.OwnedIterator(self)
#     507 else:
#     508   raise RuntimeError("`tf.data.Dataset` only supports Python-style "
#     509                      "iteration in eager mode or within tf.function.")
#
# File ~\AppData\Roaming\Python\Python311\site-packages\tensorflow\python\data\ops\iterator_ops.py:710, in OwnedIterator.__init__(self, dataset, components, element_spec)
#     706   if (components is not None or element_spec is not None):
#     707     raise ValueError(
#     708         "When `dataset` is provided, `element_spec` and `components` must "
#     709         "not be specified.")
# --> 710   self._create_iterator(dataset)
#     712 self._get_next_call_count = 0
#
# File ~\AppData\Roaming\Python\Python311\site-packages\tensorflow\python\data\ops\iterator_ops.py:749, in OwnedIterator._create_iterator(self, dataset)
#     746   assert len(fulltype.args[0].args[0].args) == len(
#     747       self._flat_output_types)
#     748   self._iterator_resource.op.experimental_set_type(fulltype)
# --> 749 gen_dataset_ops.make_iterator(ds_variant, self._iterator_resource)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\tensorflow\python\ops\gen_dataset_ops.py:3451, in make_iterator(dataset, iterator, name)
#    3449 if tld.is_eager:
#    3450   try:
# -> 3451     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    3452       _ctx, "MakeIterator", name, dataset, iterator)
#    3453     return _result
#    3454   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
# Get a random BPMN graph
bpmn_graph = all_bpmns['Warenversand_e74e4fbcba1a48d3a4283a2e5bea3a2f.bpmn']

# Find the 5 most similar graphs
most_similar_graphs = find_most_similar_graphs(bpmn_graph, all_bpmns, embedding_model, n=100)

for graph, similarity in most_similar_graphs:
    print(f"Similarity: {similarity}", f"Graph: {graph.file_path}")
    # print or do something with the similar graph

for graph, similarity in most_similar_graphs:
    print(f"Similarity: {similarity}",f"Graph: {graph.file_path}")
    graph.draw_graph()
# Out:
# 100%|██████████| 597/597 [00:43<00:00, 13.86it/s]
# Similarity: [[1.]] Graph: data\camunda\English\01-Dispatch-of-goods\02-Results\Warenversand_e74e4fbcba1a48d3a4283a2e5bea3a2f.bpmn
# Similarity: [[0.9038068]] Graph: data\camunda\English\01-Dispatch-of-goods\02-Results\excercise_1_a55ce1fcd0964142b053ec217b5b81df.bpmn
# Similarity: [[0.901696]] Graph: data\camunda\English\01-Dispatch-of-goods\02-Results\excersise_no1_525ba14ce6564d30868a15be6b485914.bpmn
# Similarity: [[0.9015858]] Graph: data\camunda\English\01-Dispatch-of-goods\02-Results\excersise_no1_6e8c0acfcb0740d7bc60580f0d64a6bb.bpmn
# Similarity: [[0.8912006]] Graph: data\camunda\English\01-Dispatch-of-goods\02-Results\Dispatch_1cb656bdb9ec435fbe33bf4df633c2f5.bpmn
# Similarity: [[0.8687104]] Graph: data\camunda\English\01-Dispatch-of-goods\02-Results\Exercise_1_Dispatch_of_Goods_1b80d86d36ee4cf79bcd427aebdd943d.bpmn
# Similarity: [[0.86162627]] Graph: data\camunda\English\01-Dispatch-of-goods\02-Results\Warenversand_b6183314a40a4041b05ac542cc468ac5.bpmn
# Similarity: [[0.86141133]] Graph: data\camunda\English\01-Dispatch-of-goods\02-Results\Warenversand_9d83f8d992b647feb794f8441e98cb56.bpmn
# Similarity: [[0.85380137]] Graph: data\camunda\English\01-Dispatch-of-goods\02-Results\excercise_2_e438edc959504171b3bf167751eff4ba.bpmn
# Similarity: [[0.8517662]] Graph: data\camunda\English\01-Dispatch-of-goods\02-Results\Dispatchin_of_goods_ca3ac1d3e9ce4cda979953ebc59bf6b7.bpmn
# Similarity: [[0.85041696]] Graph: data\camunda\English\01-Dispatch-of-goods\02-Results\Exercise_1_29bb622b0c3a4edb90fa7c3810cc076a.bpmn
# Similarity: [[0.84057784]] Graph: data\camunda\English\01-Dispatch-of-goods\02-Results\Dispatch_01_6a478fb945e4464abc19d1a74b903390.bpmn
# Similarity: [[0.83995724]] Graph: data\camunda\English\01-Dispatch-of-goods\02-Results\Dispatch_of_goods_e18aeed5fd1c4518a19ec88c87286f64.bpmn
# Similarity: [[0.8350636]] Graph: data\camunda\English\01-Dispatch-of-goods\02-Results\Practice_1_353c97ab7bed479d9a430698d2e28669.bpmn
# Similarity: [[0.83267534]] Graph: data\camunda\English\01-Dispatch-of-goods\02-Results\Warenversand_0b2da3201db14d2fa8294de710ff153b.bpmn
# Similarity: [[0.8305422]] Graph: data\camunda\English\01-Dispatch-of-goods\02-Results\exercise_4_adf9842718024dda988ae361bc983aa8.bpmn
# Similarity: [[0.82948637]] Graph: data\camunda\English\01-Dispatch-of-goods\02-Results\warenversand_-_english_00f5b29d34c8482d9ec476f554c6dad0.bpmn
# Similarity: [[0.82392216]] Graph: data\camunda\English\01-Dispatch-of-goods\02-Results\Shipping1_c87ef14a31294d689947d679015e8afb.bpmn
# Similarity: [[0.8175041]] Graph: data\camunda\English\01-Dispatch-of-goods\02-Results\Warenversand_2e1ffeb733064bb9a2ac6ea9850df7b2.bpmn
# Similarity: [[0.81649137]] Graph: data\camunda\English\01-Dispatch-of-goods\02-Results\Goods_Dispatch_Process_88375b73af094489a0cdf68a5d7638a5.bpmn
# Similarity: [[0.81629646]] Graph: data\camunda\English\01-Dispatch-of-goods\02-Results\Dispatch_of_goods_4baa7cbe64fc477fbd1500efbbe57e98.bpmn
# Similarity: [[0.81601405]] Graph: data\camunda\German\01-Vorbereitung-des-Warenversands\02-Ergebnisse\Gruppe_1_129b3edff83046fbbb5fe0197edcbe7e.bpmn
# Similarity: [[0.8127464]] Graph: data\camunda\English\01-Dispatch-of-goods\02-Results\dispatch_of_goods_e7a9ade4d2b74b9aba073f36d424c23a.bpmn
# Similarity: [[0.8109126]] Graph: data\camunda\English\01-Dispatch-of-goods\02-Results\Ship_Stuff_Places_d10f51a64bc44b66b62d075c86a44acb.bpmn
# Similarity: [[0.8104649]] Graph: data\camunda\English\01-Dispatch-of-goods\02-Results\Warenversand_c3e03fcb2b124ea3b3d8b9633ef145dc.bpmn
# Similarity: [[0.809798]] Graph: data\camunda\English\01-Dispatch-of-goods\02-Results\warenversand_-_english_f8e003ebf21d4c14b0b58ca444aa63c9.bpmn
# Similarity: [[0.8091582]] Graph: data\camunda\English\01-Dispatch-of-goods\02-Results\Dispatch_of_goods_42528d54df304f9fa9c747c8d40deb35.bpmn
# Similarity: [[0.808179]] Graph: data\camunda\German\01-Vorbereitung-des-Warenversands\02-Ergebnisse\Versandprozess_010dc35c54084bb986a532a2e48042df.bpmn
# Similarity: [[0.8079136]] Graph: data\camunda\English\01-Dispatch-of-goods\02-Results\Exercise1_18550dfe434d4b1ab796685f63d461f5.bpmn
# Similarity: [[0.80787337]] Graph: data\camunda\English\01-Dispatch-of-goods\02-Results\warenversand_-_english_e0b26a385fc94223bfc6636fee14cd5b.bpmn
# Similarity: [[0.8068411]] Graph: data\camunda\English\01-Dispatch-of-goods\02-Results\Warenversand_d64d8276cf1d488992195f9b8144f880.bpmn
# Similarity: [[0.80103445]] Graph: data\camunda\English\01-Dispatch-of-goods\02-Results\New_Process_fe7d4533db844216be2fa85a13293b1a.bpmn
# Similarity: [[0.8008065]] Graph: data\camunda\English\01-Dispatch-of-goods\02-Results\Excercise_1_Dispatch_261502e16e3a457e8f2787775defec9d.bpmn
# Similarity: [[0.79602534]] Graph: data\camunda\German\01-Vorbereitung-des-Warenversands\02-Ergebnisse\Anja_s_Prozess_90e7bd8bf5ab479488eebc022846df81.bpmn
# Similarity: [[0.79451627]] Graph: data\camunda\German\01-Vorbereitung-des-Warenversands\02-Ergebnisse\U1_f529f48ede854a4b83de5aeb2bafe821.bpmn
# Similarity: [[0.79371965]] Graph: data\camunda\English\01-Dispatch-of-goods\02-Results\Warenversand_d01f9fe7bbc848908890d43211a4b62d.bpmn
# Similarity: [[0.79358983]] Graph: data\camunda\English\01-Dispatch-of-goods\02-Results\Warenversand_548dc90cb01e4f8d974ae747b7063277.bpmn
# Similarity: [[0.79154307]] Graph: data\camunda\German\01-Vorbereitung-des-Warenversands\02-Ergebnisse\-__bung_1_887e88cab0d94585a5c6fb3e3ac12469.bpmn
# Similarity: [[0.7873795]] Graph: data\camunda\German\01-Vorbereitung-des-Warenversands\02-Ergebnisse\01_-_Vorbereitung_Warenversand_e29ad857608345f4a3c8ee5eefc44129.bpmn
# Similarity: [[0.7852885]] Graph: data\camunda\English\01-Dispatch-of-goods\02-Results\warenversand_-_english_a850c588e7d54de1add30aaddce62cd6.bpmn
# Similarity: [[0.7851214]] Graph: data\camunda\English\01-Dispatch-of-goods\02-Results\Dispatch_of_Goods_edea3e34adaf4d0aabba9f894aee435e.bpmn
# Similarity: [[0.78294003]] Graph: data\camunda\English\01-Dispatch-of-goods\02-Results\Warenversand_7f50c52e9d69490db819c1d685c59e3a.bpmn
# Similarity: [[0.78268427]] Graph: data\camunda\English\01-Dispatch-of-goods\02-Results\Dispatch_of_Goods_bc722883a18e42f1bf5e53626e77a811.bpmn
# Similarity: [[0.7791196]] Graph: data\camunda\German\01-Vorbereitung-des-Warenversands\02-Ergebnisse\Ueb_1_59c9268d942b44ce873250b50f61c0c5.bpmn
# Similarity: [[0.7790054]] Graph: data\camunda\English\01-Dispatch-of-goods\02-Results\Exercise1_DispatchingOfGoods_481c5e8b98774e5a9550acafcb20893b.bpmn
# Similarity: [[0.7744192]] Graph: data\camunda\German\01-Vorbereitung-des-Warenversands\02-Ergebnisse\Team_1_Warenversand_7b09a6f6693d4c8aa8a6550b16f89601.bpmn
# Similarity: [[0.7739486]] Graph: data\camunda\German\01-Vorbereitung-des-Warenversands\02-Ergebnisse\Uebung_1__fd9a5b04281a40329f00dfdc67dbd824.bpmn
# Similarity: [[0.76660407]] Graph: data\camunda\English\01-Dispatch-of-goods\02-Results\warenversand_-_english_6843b3e3b2654272ae66fb40928d3858.bpmn
# Similarity: [[0.76559967]] Graph: data\camunda\German\01-Vorbereitung-des-Warenversands\02-Ergebnisse\Ueb_1_-_Warenversand_11887d02537e4e529a1ee2af157c2cd8.bpmn
# Similarity: [[0.7632568]] Graph: data\camunda\German\01-Vorbereitung-des-Warenversands\02-Ergebnisse\Versand_86a3d58f7ba44a8f8a983854cb91adcc.bpmn
# Similarity: [[0.7626947]] Graph: data\camunda\German\01-Vorbereitung-des-Warenversands\02-Ergebnisse\1._Warenversand_f98ccccb5a944ffd9d958cdd3d8d709c.bpmn
# Similarity: [[0.75743043]] Graph: data\camunda\English\01-Dispatch-of-goods\02-Results\Warenversand_af7eded5837d4110aaff76292a17e898.bpmn
# Similarity: [[0.7564832]] Graph: data\camunda\English\01-Dispatch-of-goods\02-Results\warenversand_-_english_027ce98fab3a4b3dada547ccf03e3c51.bpmn
# Similarity: [[0.75564647]] Graph: data\camunda\English\01-Dispatch-of-goods\02-Results\Warenversand_02f6546a9af14168b38ec7ded24fd874.bpmn
# Similarity: [[0.7545324]] Graph: data\camunda\German\01-Vorbereitung-des-Warenversands\02-Ergebnisse\Uebung1_3e24acc5f8b94defa632fb7e9b3f1bd2.bpmn
# Similarity: [[0.754436]] Graph: data\camunda\German\01-Vorbereitung-des-Warenversands\02-Ergebnisse\Neuer_Prozess_bf8f68238ff4425590cc3f5ba96b8c65.bpmn
# Similarity: [[0.75222635]] Graph: data\camunda\German\01-Vorbereitung-des-Warenversands\02-Ergebnisse\Ueb1_-_Warenversand_7ba95b0ca9a34696bf13b9d70d7102ae.bpmn
# Similarity: [[0.7517564]] Graph: data\camunda\German\01-Vorbereitung-des-Warenversands\02-Ergebnisse\Neuer_Prozess_dcae3792e19348208aae308ca6baeaf3.bpmn
# Similarity: [[0.750901]] Graph: data\camunda\German\01-Vorbereitung-des-Warenversands\02-Ergebnisse\Uebung_1_11343739c9cd40469faf78966f0985e4.bpmn
# Similarity: [[0.7493798]] Graph: data\camunda\English\01-Dispatch-of-goods\02-Results\warenversand_-_english_669fbdb6351d46bfab81ac608bf3bf67.bpmn
# Similarity: [[0.74606013]] Graph: data\camunda\German\01-Vorbereitung-des-Warenversands\02-Ergebnisse\Gruppe_3_1557c71ef31d44bc87f6cde4101d43a1.bpmn
# Similarity: [[0.7456371]] Graph: data\camunda\English\01-Dispatch-of-goods\02-Results\dispatch_of_goods_2a1f9e8760a844f9b1794af65d2746ee.bpmn
# Similarity: [[0.74417245]] Graph: data\camunda\German\01-Vorbereitung-des-Warenversands\02-Ergebnisse\Versandbeauftragung_4e5073f5431f4e64b62f37df29306ffa.bpmn
# Similarity: [[0.74411345]] Graph: data\camunda\German\01-Vorbereitung-des-Warenversands\02-Ergebnisse\Aufgabe_1_13fffd5830674bb8895ca7f4b4ac7546.bpmn
# Similarity: [[0.7426183]] Graph: data\camunda\German\01-Vorbereitung-des-Warenversands\02-Ergebnisse\Uebung1_Warenversand_e665d28399534649880567f75d775638.bpmn
# Similarity: [[0.74246705]] Graph: data\camunda\German\01-Vorbereitung-des-Warenversands\02-Ergebnisse\Neuer_Prozess_1257630bfb5d4ca5979900aed5cb8f13.bpmn
# Similarity: [[0.74231434]] Graph: data\camunda\English\01-Dispatch-of-goods\02-Results\warenversand_-_english_9e898f1d45534679ac6317895675bb1b.bpmn
# Similarity: [[0.74223]] Graph: data\camunda\German\01-Vorbereitung-des-Warenversands\02-Ergebnisse\Aufgabe_1_5b60340cf441488b9f9fe17194b370b2.bpmn
# Similarity: [[0.7421378]] Graph: data\camunda\English\01-Dispatch-of-goods\02-Results\Warenversand_c122e662a3914f36b71bae9049e8f1a2.bpmn
# Similarity: [[0.7414037]] Graph: data\camunda\English\01-Dispatch-of-goods\02-Results\1_61cde83dea954a0a80b769e291a7a462.bpmn
# Similarity: [[0.7410315]] Graph: data\camunda\German\01-Vorbereitung-des-Warenversands\02-Ergebnisse\Ueb_1_316f88d03ad0432199336573cc4fafa1.bpmn
# Similarity: [[0.74040645]] Graph: data\camunda\German\01-Vorbereitung-des-Warenversands\02-Ergebnisse\Ueb_1_8dcd3061c0804591a2d7af2f00796152.bpmn
# Similarity: [[0.7403213]] Graph: data\camunda\German\01-Vorbereitung-des-Warenversands\02-Ergebnisse\Ueb_1__Kopie__f3db524a254e487c9efcab6e18726efe.bpmn
# Similarity: [[0.7396668]] Graph: data\camunda\German\01-Vorbereitung-des-Warenversands\02-Ergebnisse\Ueb_1_964b8ce5bb7f42f1936a384f416a75ae.bpmn
# Similarity: [[0.73935854]] Graph: data\camunda\German\01-Vorbereitung-des-Warenversands\02-Ergebnisse\Ueb_1_ae84ec3090aa4980a8dac59e4d557b47.bpmn
# Similarity: [[0.7389936]] Graph: data\camunda\German\01-Vorbereitung-des-Warenversands\02-Ergebnisse\Ueb1_Warenversand_f9a7cfff5ed24f8992c963ec99be0f91.bpmn
# Similarity: [[0.738739]] Graph: data\camunda\German\01-Vorbereitung-des-Warenversands\02-Ergebnisse\Ueb_1_-_Warenversand_366611618d6c4626bd1d5fc7eff833d4.bpmn
# Similarity: [[0.738265]] Graph: data\camunda\German\01-Vorbereitung-des-Warenversands\02-Ergebnisse\Ueb_1_-_Warenversand_2d7b631d368f4db39985e449f50b5bee.bpmn
# Similarity: [[0.73791146]] Graph: data\camunda\German\01-Vorbereitung-des-Warenversands\02-Ergebnisse\Ueb_1__Vorbereitung_Warenversand_45f5a8f56720447e9992d941531d7f2f.bpmn
# Similarity: [[0.7379097]] Graph: data\camunda\English\01-Dispatch-of-goods\02-Results\warenversand_-_english_25daf2131b254bb988d92bf50f47165e.bpmn
# Similarity: [[0.7373366]] Graph: data\camunda\German\01-Vorbereitung-des-Warenversands\02-Ergebnisse\Spedition_Versand_3cd5b9a5fb03437e8e93ec833b3062d7.bpmn
# Similarity: [[0.73446983]] Graph: data\camunda\German\01-Vorbereitung-des-Warenversands\02-Ergebnisse\-_Task_1_cb967b14c29e4f8f9d182d67559547a2.bpmn
# Similarity: [[0.734161]] Graph: data\camunda\German\01-Vorbereitung-des-Warenversands\02-Ergebnisse\Ueb_1_05b3e147f1004b0a9e3ffbc5a5c101e2.bpmn
# Similarity: [[0.7340975]] Graph: data\camunda\German\01-Vorbereitung-des-Warenversands\02-Ergebnisse\Uebung_1__d27d470b22ac4c13860a644ba38d44b0.bpmn
# Similarity: [[0.7304832]] Graph: data\camunda\German\01-Vorbereitung-des-Warenversands\02-Ergebnisse\Neuer_Warenversand_4fb85acf907341009d03b3560fb58408.bpmn
# Similarity: [[0.7270708]] Graph: data\camunda\German\01-Vorbereitung-des-Warenversands\02-Ergebnisse\01Warenversand_39f5a5faf1c5480a9b04bc7bb39fb095.bpmn
# Similarity: [[0.7242442]] Graph: data\camunda\German\01-Vorbereitung-des-Warenversands\02-Ergebnisse\Ueb1_06a9fb661e12460da44d83a9f6cf8c59.bpmn
# Similarity: [[0.72366613]] Graph: data\camunda\English\01-Dispatch-of-goods\02-Results\Exercise_1_21a36e3570ab48d59098702f4f8ad279.bpmn
# Similarity: [[0.72016716]] Graph: data\camunda\German\01-Vorbereitung-des-Warenversands\02-Ergebnisse\Ueb_1_f488507c272a4cff809242be94608a68.bpmn
# Similarity: [[0.7193098]] Graph: data\camunda\German\01-Vorbereitung-des-Warenversands\02-Ergebnisse\Uebung_1_c02448e060aa4b669debe456d0c2a2ae.bpmn
# Similarity: [[0.7179655]] Graph: data\camunda\German\01-Vorbereitung-des-Warenversands\02-Ergebnisse\Uebung_1_-_Warenversand_14eead9ee2ea483aa9028df703693683.bpmn
# Similarity: [[0.7178205]] Graph: data\camunda\German\01-Vorbereitung-des-Warenversands\02-Ergebnisse\Aufgabe_1_38ebadc4d2744116ba565d266ebcc6af.bpmn
# Similarity: [[0.71686876]] Graph: data\camunda\German\01-Vorbereitung-des-Warenversands\02-Ergebnisse\Ueb_1_9718db2cd9f84649bb99c484b4d3cd08.bpmn
# Similarity: [[0.71584475]] Graph: data\camunda\German\01-Vorbereitung-des-Warenversands\02-Ergebnisse\Ueb_01_Warenversand_baf03525efe34fb7bda48a05cf8d5988.bpmn
# Similarity: [[0.7155454]] Graph: data\camunda\German\01-Vorbereitung-des-Warenversands\02-Ergebnisse\Trainer_-_Ueb1_48ff73d8c89a483f9e2404d56b3baf12.bpmn
# Similarity: [[0.7149474]] Graph: data\camunda\German\01-Vorbereitung-des-Warenversands\02-Ergebnisse\Uebung1_30f20e0e00f944cd941fc4048b5bb96f.bpmn
# Similarity: [[0.7149053]] Graph: data\camunda\German\01-Vorbereitung-des-Warenversands\02-Ergebnisse\Uebung_1_2f63ecefd45d4e4db0c96fbbdcb885cf.bpmn
# Similarity: [[0.7148144]] Graph: data\camunda\German\01-Vorbereitung-des-Warenversands\02-Ergebnisse\Uebung_1__Kopie__1f68aea533824fd19a25edc72f9288a1.bpmn
# Similarity: [[0.7147528]] Graph: data\camunda\German\01-Vorbereitung-des-Warenversands\02-Ergebnisse\Uebung_1_4b25fc319e424a81b24217fdcaef3fcc.bpmn
# Similarity: [[0.7147327]] Graph: data\camunda\German\01-Vorbereitung-des-Warenversands\02-Ergebnisse\Uebung_1_990e7afbafe0416f86deff22f44d9175.bpmn

# %%
import numpy as np
from sklearn.utils import resample
from sklearn.metrics.pairwise import cosine_similarity

similarity_threshold = 0.5
similarity_threshold_baseline = 0.5

# Separate positive and negative samples
positive_samples = [sample for sample in samples if sample["score"] > similarity_threshold]
negative_samples = [sample for sample in samples if sample["score"] <= similarity_threshold]

# Balance the samples
if len(positive_samples) > len(negative_samples):
    # Undersample the positive samples
    positive_samples = resample(positive_samples, replace=False, n_samples=len(negative_samples), random_state=42)
else:
    # Oversample the negative samples
    negative_samples = resample(negative_samples, replace=True, n_samples=len(positive_samples), random_state=42)

# Combine the balanced samples
balanced_samples = positive_samples[:200] + negative_samples[:200]

TP = FP = TN = FN = 0

samples_with_scores_and_diffs = []

from tqdm import tqdm

# Initialize the cache
embedding_cache = {}

for sample in tqdm(balanced_samples):

    # Get the embeddings from the cache if available, otherwise compute them
    query_embedding = embedding_cache.get(sample["query"])
    if query_embedding is None:
        query_embedding = generate_embeddings(sample["query"], embedding_model)[0]
        embedding_cache[sample["query"]] = query_embedding

    target_embedding = embedding_cache.get(sample["target"])
    if target_embedding is None:
        target_embedding = generate_embeddings(sample["target"], embedding_model)[0]
        embedding_cache[sample["target"]] = target_embedding

    # calculate the cosine similarity between the two embeddings and threshold it if both are not None
    if query_embedding is not None and target_embedding is not None:
        similarity = cosine_similarity(query_embedding.reshape(1, -1), target_embedding.reshape(1, -1))[0][0]
        prediction = similarity > similarity_threshold_baseline
        actual =  sample["score"] > similarity_threshold

        #print("actual: ", sample["score"], "prediction: ", similarity, "diff: ", abs(similarity - sample["score"]))

        # Calculate the difference between the score and the actual value
        diff = abs(similarity - actual)

        # Add the sample, similarity score, and difference to the list
        samples_with_scores_and_diffs.append((sample, similarity, diff))
        
        if prediction and actual:
            TP += 1
        elif prediction and not actual:
            FP += 1
        elif not prediction and actual:
            FN += 1
        else:
            TN += 1

precision = TP / (TP + FP)
recall = TP / (TP + FN)
f1_score = 2 * precision * recall / (precision + recall)

print("Precision: ", precision)
print("Recall: ", recall)
print("F1 Score: ", f1_score)

# Calculate the number of positive and negative samples
positive_samples = TP + FN
negative_samples = TN + FP

# Calculate the ratio of positive to negative samples
positive_negative_ratio = positive_samples / negative_samples

print("Positive samples: ", positive_samples)
print("Negative samples: ", negative_samples)
print("Ratio of positive to negative samples: ", positive_negative_ratio)

# Calculate the total number of samples
total_samples = positive_samples + negative_samples

# Calculate the percentage of positive and negative samples
positive_percentage = (positive_samples / total_samples) * 100
negative_percentage = (negative_samples / total_samples) * 100

print("Positive samples: {:.2f}%".format(positive_percentage))
print("Negative samples: {:.2f}%".format(negative_percentage))

# Sort the list by the absolute difference, in descending order
samples_with_scores_and_diffs.sort(key=lambda x: x[2], reverse=True)
# Out:
#   0%|          | 0/400 [00:00<?, ?it/s]
# 100%|██████████| 400/400 [00:34<00:00, 11.70it/s]
# Precision:  0.7891891891891892
# Recall:  0.73
# F1 Score:  0.7584415584415585
# Positive samples:  200
# Negative samples:  200
# Ratio of positive to negative samples:  1.0
# Positive samples: 50.00%
# Negative samples: 50.00%

# %%
loader = BpmmComparingSpektralLoader(dataset_tr, batch_size=32, shuffle=True)
history = model.fit(loader.load(), steps_per_epoch=loader.steps_per_epoch, epochs=10)
# Out:
# Epoch 1/10
# c:\Users\StefaanVercoutere\OneDrive - Sirus NV\OPH\gnn-citations\.conda\Lib\site-packages\spektral\data\utils.py:221: UserWarning: you are shuffling a 'BPMNGraphDataset' object which is not a subclass of 'Sequence'; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   np.random.shuffle(a)
#  418/1211 [=========>....................] - ETA: 1:19 - loss: 0.7076 - accuracy: 0.0015 - precision_10: 1.0000 - recall_10: 0.4983 - auc_10: 0.0000e+00
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[132], line 2
#       1 loader = BpmmComparingSpektralLoader(dataset_tr, batch_size=32, shuffle=True)
# ----> 2 history = model.fit(loader.load(), steps_per_epoch=loader.steps_per_epoch, epochs=10)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\keras\src\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\keras\src\engine\training.py:1742, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1734 with tf.profiler.experimental.Trace(
#    1735     "train",
#    1736     epoch_num=epoch,
#    (...)
#    1739     _r=1,
#    1740 ):
#    1741     callbacks.on_train_batch_begin(step)
# -> 1742     tmp_logs = self.train_function(iterator)
#    1743     if data_handler.should_sync:
#    1744         context.async_wait()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:825, in Function.__call__(self, *args, **kwds)
#     822 compiler = "xla" if self._jit_compile else "nonXla"
#     824 with OptionalXlaContext(self._jit_compile):
# --> 825   result = self._call(*args, **kwds)
#     827 new_tracing_count = self.experimental_get_tracing_count()
#     828 without_tracing = (tracing_count == new_tracing_count)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:857, in Function._call(self, *args, **kwds)
#     854   self._lock.release()
#     855   # In this case we have created variables on the first call, so we run the
#     856   # defunned version which is guaranteed to never create variables.
# --> 857   return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     858 elif self._variable_creation_fn is not None:
#     859   # Release the lock early so that multiple threads can perform the call
#     860   # in parallel.
#     861   self._lock.release()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py:148, in TracingCompiler.__call__(self, *args, **kwargs)
#     145 with self._lock:
#     146   (concrete_function,
#     147    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 148 return concrete_function._call_flat(
#     149     filtered_flat_args, captured_inputs=concrete_function.captured_inputs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py:1349, in ConcreteFunction._call_flat(self, args, captured_inputs)
#    1345 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1346 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1347     and executing_eagerly):
#    1348   # No tape is watching; skip to running the function.
# -> 1349   return self._build_call_outputs(self._inference_function(*args))
#    1350 forward_backward = self._select_forward_and_backward_functions(
#    1351     args,
#    1352     possible_gradient_type,
#    1353     executing_eagerly)
#    1354 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:196, in AtomicFunction.__call__(self, *args)
#     194 with record.stop_recording():
#     195   if self._bound_context.executing_eagerly():
# --> 196     outputs = self._bound_context.call_function(
#     197         self.name,
#     198         list(args),
#     199         len(self.function_type.flat_outputs),
#     200     )
#     201   else:
#     202     outputs = make_call_op_in_graph(self, list(args))
#
# File ~\AppData\Roaming\Python\Python311\site-packages\tensorflow\python\eager\context.py:1457, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1455 cancellation_context = cancellation.context()
#    1456 if cancellation_context is None:
# -> 1457   outputs = execute.execute(
#    1458       name.decode("utf-8"),
#    1459       num_outputs=num_outputs,
#    1460       inputs=tensor_inputs,
#    1461       attrs=attrs,
#    1462       ctx=self,
#    1463   )
#    1464 else:
#    1465   outputs = execute.execute_with_cancellation(
#    1466       name.decode("utf-8"),
#    1467       num_outputs=num_outputs,
#    (...)
#    1471       cancellation_manager=cancellation_context,
#    1472   )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
import os
import numpy as np
from  spektral.data import Graph 
# Processing all BPMN files and storing the embeddings

def generate_bpmn_embeddings(bpmn_graphs, embedding_model):
    """
    Generates embeddings for each BPMN file using the provided embedding model.

    Parameters:
    bpmn_graphs (dict of BPMNGraphs): A dictionary mapping file paths to BPMN graphs.
    embedding_model (Model): The Keras model to use for generating the embeddings.

    Returns:
    dict: A dictionary mapping file paths to their corresponding embeddings.
    """
    # Initialize the dictionary to store the embeddings
    embeddings = {}
    bpmn_processor = BPMNGraphProcessor()

    # Iterate over all the BPMN files
    for file, bpmn_graph in bpmn_graphs.items():
        try:
            # Convert the BPMN file into a graph
            x = bpmn_processor.get_node_features(bpmn_graph)
            x = np.expand_dims(x, axis=0)  # Expands the dimensions to (1, N, F)

            a = bpmn_processor.get_adjacency_matrix(bpmn_graph)
            a = np.expand_dims(a.toarray(), axis=0)  # Expands the dimensions to (1, N, N)

            # Generate the embedding
            embedding = embedding_model.predict([x, a], verbose=0)

            # Store the embedding
            embeddings[file] = embedding[0]
            
        except Exception as e:
            print(f"An error occurred during the processing of the BPMN file: {e}")
            continue

    return embeddings

embeddings = generate_bpmn_embeddings(all_bpmns, embedding_model)

# %% [markdown]
# # embedding based version

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, Input, Dot, Lambda, Concatenate, Dense
import tensorflow.keras.backend as K
from spektral.layers import GCNConv, GlobalAvgPool, GlobalAttentionPool

def create_gcn_layers(embedding_dims):
    # Define the shared GCN layers
    graph_conv = GCNConv(embedding_dims, activation='relu', name='graph_conv')
    dropout = Dropout(0.2, name='dropout')
    graph_conv_2 = GCNConv(embedding_dims, activation='relu', name='graph_conv_2')
    dropout_2 = Dropout(0.2, name='dropout_2')
    graph_conv_3 = GCNConv(embedding_dims, activation='relu', name='graph_conv_3')
    global_pool = GlobalAttentionPool(embedding_dims,name='global_pool')
    #global_pool = GlobalAvgPool(name='global_pool')

    return graph_conv, dropout, graph_conv_2, dropout_2, graph_conv_3, global_pool

def create_graph_model(X_in, A_in, graph_layers):
    graph_conv, dropout, graph_conv_2, dropout_2, graph_conv_3, global_pool = graph_layers

    # Pass graph through the shared layers
    graph_conv_out = graph_conv([X_in, A_in])
    dropout_out = dropout(graph_conv_out)
    graph_conv_2_out = graph_conv_2([dropout_out, A_in])
    dropout_2_out = dropout_2(graph_conv_2_out)
    graph_conv_3_out = graph_conv_3([dropout_2_out, A_in])
    graph_embedding = global_pool(graph_conv_3_out)

    return graph_embedding

def create_models(n_features, embedding_dims):
    # Define the inputs for graph A
    A_X_in = Input(shape=(None, n_features), name='A_Node_features')
    A_A_in = Input((None, ), sparse=True, name='A_Adjacency_matrix')

    # Define the inputs for graph B
    B_X_in = Input(shape=(None, n_features), name='B_Node_features')
    B_A_in = Input((None, ), sparse=True, name='B_Adjacency_matrix')

    # Create the GCN layers
    graph_layers = create_gcn_layers(embedding_dims)

    # Create the graph embeddings
    A_graph_embedding = create_graph_model(A_X_in, A_A_in, graph_layers)
    B_graph_embedding = create_graph_model(B_X_in, B_A_in, graph_layers)


    # concatenate the two embeddings
    concatenated = Concatenate(name='concatenated')([A_graph_embedding, B_graph_embedding])
    dense_layer = Dense(64, activation='relu')(concatenated)
    dense_layer = Dropout(0.2, name='dropout_conc')(dense_layer)
    dense_output = Dense(1, activation='sigmoid', name='output')(dense_layer)


    # Perform dot product between the two graph embeddings
    dot_product = Dot(axes=1, normalize=True, name='dot_product')([A_graph_embedding, B_graph_embedding])
    
    # Create the main model
    model = Model(inputs=[A_X_in, A_A_in, B_X_in, B_A_in], outputs=dot_product, name='my_model')

    # Create the embedding model
    embedding_model = Model(inputs=[A_X_in, A_A_in], outputs=A_graph_embedding, name='embedding_model')

    return model, embedding_model

# %%
def train_model(model, dataset, batch_size=32, epochs=10):
    """
    Trains the model on the given dataset.

    Parameters:
    model (Model): The model to train.
    dataset (Dataset): The dataset to train the model on.
    batch_size (int): The batch size to use for training.
    epochs (int): The number of epochs to train the model for.

    Returns:
    History: A History object. Its History.history attribute is a record of training loss values and metrics values at successive epochs.
    """
    try:
        from tensorflow.keras.optimizers import Adam
        from tensorflow.keras.metrics import Precision, Recall, AUC
        from tensorflow.keras.metrics import RootMeanSquaredError, MeanAbsoluteError

        
        # Create the model
        model, embedding_model = create_models(n_features=384, embedding_dims=384)
        
        # Compile the model with additional metrics
        model.compile(optimizer='adam', 
              loss='mean_squared_error', 
              metrics=[RootMeanSquaredError(), MeanAbsoluteError()])
        
        # Create a loader
        loader = BpmmComparingSpektralLoader(dataset, batch_size=batch_size, shuffle=True)

        # Log the shapes of the inputs and targets
        batch = next(loader.load())
        inputs, y = batch
        A_X, A_A, B_X, B_A = inputs
        
        print(f"A shape:( {A_X.shape}, {A_A.shape}), B shape:( {B_X.shape}, {B_A.shape}), y shape: {y.shape}")

        # Train the model
        history = model.fit(loader.load(), steps_per_epoch=loader.steps_per_epoch, epochs=epochs)

        return model, embedding_model, history
    except Exception as e:
        print(f"An error occurred: {e}")

    return None, None, None


# Train the model
model = create_models(n_features=384, embedding_dims=384)
model, embedding_model, history = train_model(model, dataset_tr, epochs = 10)
# Out:
# c:\Users\StefaanVercoutere\OneDrive - Sirus NV\OPH\gnn-citations\.conda\Lib\site-packages\spektral\data\utils.py:221: UserWarning: you are shuffling a 'BPMNGraphDataset' object which is not a subclass of 'Sequence'; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   np.random.shuffle(a)
# A shape:( (32, 43, 384), (32, 43, 43)), B shape:( (32, 43, 384), (32, 43, 43)), y shape: (32,)
# Epoch 1/10
# 1215/1215 [==============================] - 122s 99ms/step - loss: 0.0088 - root_mean_squared_error: 0.0939 - mean_absolute_error: 0.0688
# Epoch 2/10
# 1215/1215 [==============================] - 127s 104ms/step - loss: 0.0035 - root_mean_squared_error: 0.0591 - mean_absolute_error: 0.0453
# Epoch 3/10
# 1215/1215 [==============================] - 190s 156ms/step - loss: 0.0026 - root_mean_squared_error: 0.0511 - mean_absolute_error: 0.0392
# Epoch 4/10
# 1215/1215 [==============================] - 269s 222ms/step - loss: 0.0022 - root_mean_squared_error: 0.0464 - mean_absolute_error: 0.0357
# Epoch 5/10
# 1215/1215 [==============================] - 237s 195ms/step - loss: 0.0019 - root_mean_squared_error: 0.0434 - mean_absolute_error: 0.0334
# Epoch 6/10
# 1215/1215 [==============================] - 427s 351ms/step - loss: 0.0017 - root_mean_squared_error: 0.0409 - mean_absolute_error: 0.0316
# Epoch 7/10
# 1215/1215 [==============================] - 356s 294ms/step - loss: 0.0015 - root_mean_squared_error: 0.0382 - mean_absolute_error: 0.0295
# Epoch 8/10
# 1215/1215 [==============================] - 394s 324ms/step - loss: 0.0013 - root_mean_squared_error: 0.0364 - mean_absolute_error: 0.0281
# Epoch 9/10
# 1215/1215 [==============================] - 269s 221ms/step - loss: 0.0012 - root_mean_squared_error: 0.0348 - mean_absolute_error: 0.0269
# Epoch 10/10
# 1215/1215 [==============================] - 153s 126ms/step - loss: 0.0011 - root_mean_squared_error: 0.0336 - mean_absolute_error: 0.0261

# %%
loss, mse, mae = evaluate_model(model, dataset_te)
print(f"Eval loss: {loss}, Eval mse: {mse}, Eval mae: {mae}")

# Available metrics
print(f"Available metrics: {history.history.keys()}")

# Plot the training history
plot_history(history, 'root_mean_squared_error')
# Out:
# 135/135 [==============================] - 8s 51ms/step - loss: 0.0013 - root_mean_squared_error: 0.0365 - mean_absolute_error: 0.0276
# Eval loss: 0.0013356072595342994, Eval mse: 0.03654596209526062, Eval mae: 0.02764519490301609
# Available metrics: dict_keys(['loss', 'root_mean_squared_error', 'mean_absolute_error'])

# %%
# Save the models
embedding_model.save('bpmn_compare_embedding_model.h5')
model.save('bpmn_compare_full_model.h5')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# C:\Users\StefaanVercoutere\AppData\Roaming\Python\Python311\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
import numpy as np
from sklearn.utils import resample
from sklearn.metrics.pairwise import cosine_similarity

similarity_threshold = 0.5
similarity_threshold_baseline = 0.5

# Separate positive and negative samples
positive_samples = [sample for sample in samples if sample["score"] > similarity_threshold]
negative_samples = [sample for sample in samples if sample["score"] <= similarity_threshold]

# Balance the samples
if len(positive_samples) > len(negative_samples):
    # Undersample the positive samples
    positive_samples = resample(positive_samples, replace=False, n_samples=len(negative_samples), random_state=42)
else:
    # Oversample the negative samples
    negative_samples = resample(negative_samples, replace=True, n_samples=len(positive_samples), random_state=42)

# Combine the balanced samples
balanced_samples = positive_samples[:200] + negative_samples[:200]

TP = FP = TN = FN = 0

samples_with_scores_and_diffs = []

from tqdm import tqdm

# Initialize the cache
embedding_cache = {}

for sample in tqdm(balanced_samples):

    # Get the embeddings from the cache if available, otherwise compute them
    query_embedding = embedding_cache.get(sample["query"])
    if query_embedding is None:
        query_embedding = generate_embeddings(sample["query"], embedding_model)[0]
        embedding_cache[sample["query"]] = query_embedding

    target_embedding = embedding_cache.get(sample["target"])
    if target_embedding is None:
        target_embedding = generate_embeddings(sample["target"], embedding_model)[0]
        embedding_cache[sample["target"]] = target_embedding

    # calculate the cosine similarity between the two embeddings and threshold it if both are not None
    if query_embedding is not None and target_embedding is not None:
        similarity = cosine_similarity(query_embedding.reshape(1, -1), target_embedding.reshape(1, -1))[0][0]
        prediction = similarity > similarity_threshold_baseline
        actual =  sample["score"] > similarity_threshold

        #print("actual: ", sample["score"], "prediction: ", similarity, "diff: ", abs(similarity - sample["score"]))

        # Calculate the difference between the score and the actual value
        diff = abs(similarity - actual)

        # Add the sample, similarity score, and difference to the list
        samples_with_scores_and_diffs.append((sample, similarity, diff))
        
        if prediction and actual:
            TP += 1
        elif prediction and not actual:
            FP += 1
        elif not prediction and actual:
            FN += 1
        else:
            TN += 1

precision = TP / (TP + FP)
recall = TP / (TP + FN)
f1_score = 2 * precision * recall / (precision + recall)

print("Precision: ", precision)
print("Recall: ", recall)
print("F1 Score: ", f1_score)

# Calculate the number of positive and negative samples
positive_samples = TP + FN
negative_samples = TN + FP

# Calculate the ratio of positive to negative samples
positive_negative_ratio = positive_samples / negative_samples

print("Positive samples: ", positive_samples)
print("Negative samples: ", negative_samples)
print("Ratio of positive to negative samples: ", positive_negative_ratio)

# Calculate the total number of samples
total_samples = positive_samples + negative_samples

# Calculate the percentage of positive and negative samples
positive_percentage = (positive_samples / total_samples) * 100
negative_percentage = (negative_samples / total_samples) * 100

print("Positive samples: {:.2f}%".format(positive_percentage))
print("Negative samples: {:.2f}%".format(negative_percentage))

# Sort the list by the absolute difference, in descending order
samples_with_scores_and_diffs.sort(key=lambda x: x[2], reverse=True)

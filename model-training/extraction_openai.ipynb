# %%
import os
import sys
import json

def save_version_controlled_file(data, base_filename='prodigy_bpmn_search', extension='jsonl'):
    # Initialize version
    version = 1

    # Format the filename
    filename = f'{base_filename}_{str(version).zfill(2)}.{extension}'

    # Check if the file already exists
    while os.path.isfile(filename):
        # If it does, increment the version number and update the filename
        version += 1
        filename = f'{base_filename}_{str(version).zfill(2)}.{extension}'

    # Save to file
    with open(filename, 'w') as f:
        for entry in data:
            f.write(json.dumps(entry) + '\n')

    return filename

# %% [markdown]
# # openai JSON extraction using azure

# %%
from openai import AzureOpenAI


OPENAI_DEPLOYMENT_ENDPOINT = "<ENDPOINT>"
OPENAI_API_KEY = "<API_KEY>"
OPENAI_DEPLOYMENT_NAME = "gpt-4o"
OPENAI_DEPLOYMENT_VERSION ="2024-02-01"

client = AzureOpenAI(
    api_key=OPENAI_API_KEY,  
    api_version=OPENAI_DEPLOYMENT_VERSION,
    azure_endpoint=OPENAI_DEPLOYMENT_ENDPOINT
)
# Out:
# A BPMN (Business Process Model and Notation) diagram is a graphical representation used to model business processes. It provides a standard way to visualize the steps involved in a business process, making it easier for stakeholders to understand, analyze, and improve the process. BPMN diagrams are widely used in business process management and are designed to be understandable by all business users, from business analysts who create and refine the processes to technical developers responsible for implementing the processes and business managers who monitor and manage the processes.
#
# Key elements of a BPMN diagram include:
#
# 1. **Flow Objects**:
#    - **Events**: Represent something that happens (e.g., start, intermediate, end events).
#    - **Activities**: Represent work that is performed (e.g., tasks, sub-processes).
#    - **Gateways**: Represent decision points that control the flow of the process (e.g., exclusive, parallel gateways).
#
# 2. **Connecting Objects**:
#    - **Sequence Flows**: Show the order in which activities are performed.
#    - **Message Flows**: Show the flow of messages between different process participants.
#    - **Associations**: Link artifacts and text to flow objects.
#
# 3. **Swimlanes**:
#    - **Pools**: Represent major participants in a process (e.g., an entire organization).
#    - **Lanes**: Sub-divide pools to show different roles or departments within the organization.
#
# 4. **Artifacts**:
#    - **Data Objects**: Represent data required or produced by activities.
#    - **Groups**: Used to group different activities for documentation or analysis purposes.
#    - **Annotations**: Provide additional information about the process.
#
# BPMN diagrams are valuable tools for improving business processes, as they help in identifying inefficiencies, redundancies, and opportunities for automation. They also facilitate communication and collaboration among different stakeholders involved in the process.

# %% [markdown]
# # prompting GPT to generate queries and keywords for each BPMN file

# %%
import os
import time
import json
import xml.etree.ElementTree as ET


def create_prompt(prompt_template, bpmn_xml):
    bpmn_xml = bpmn_xml.replace('"', '').replace("'", '')
    return prompt_template.format(bpmn_xml=bpmn_xml)

def extract_information(system_message, prompt_template, bpmn_xml):
    prompt = create_prompt(prompt_template, bpmn_xml)
    response = client.chat.completions.create(
        model=OPENAI_DEPLOYMENT_NAME,
        response_format={ "type": "json_object" },
        messages=[
            {"role": "system", "content": system_message},
            {"role": "user", "content": prompt},
        ],
        temperature=0.5,
    )
    print(response.choices[0].message.content)
    return json.loads(response.choices[0].message.content)

def process_xml(file_path):
    """
    Parses the XML file and removes the 'bpmndi:BPMNDiagram' elements.

    Parameters:
    file_path (str): The path to the XML file.

    Returns:
    str: The modified XML as a string.
    """
    try:
        # Parse the XML file
        tree = ET.parse(file_path)
        root = tree.getroot()

        # Find and clear all 'bpmndi:BPMNDiagram' elements
        for elem in root.findall('.//bpmndi: BPMNDiagram', namespaces={'bpmndi': 'http://www.omg.org/spec/BPMN/20100524/DI'}):
            elem.clear()

        # Convert the modified XML tree back to a string
        xml_str = ET.tostring(root, encoding='utf-8').decode('utf-8')

        return xml_str
    except ET.ParseError as e:
        print(f"Error parsing XML file {file_path}: {e}")
        return None
    except Exception as e:
        print(f"Unexpected error processing XML file {file_path}: {e}")
        return None

def process_file(system_message, prompt_template, file_path):
    # Read the BPMN file
    bpmn_xml = process_xml(file_path)
    # Extract information from the BPMN XML
    extracted_info = extract_information(system_message, prompt_template, bpmn_xml)

    return extracted_info

def process_folder(system_message, prompt_template, folder_path):
    processed_files = {}

    # Get all files in the folder
    files = os.listdir(folder_path)

    # Process each file
    for file in files:
        file_path = os.path.join(folder_path, file)

        # Skip if the file does not end with .bpmn
        if not file_path.lower().endswith('.bpmn'):
            continue

        print(f"Processing file: {file_path}")

        try:
            processed_files[file] = process_file(system_message, prompt_template, file_path)
        except Exception as e:
            print(f"Error processing file: {file_path}")
            print(e)

        # pause for 5 seconds
        time.sleep(5)

    return processed_files


# Process all BPMN files in the folder
system_message = "You are an AI model trained to analyze text extracted from BPMN files and provide relevant information about the process described in the file. Your task is to identify keywords, provide a brief description of the process, and suggest relevant search queries made to a BPMN search engine. Respond in Dutch."
prompt_template = "The following text is extracted from a BPMN file: \"{bpmn_xml}\". Please analyze the text and provide the following information in a JSON format with fields 'keywords', 'description' and 'queries': 1) Dutch keywords that describe the diagram as a whole, 2) A brief description of the processes described in the XML file in Dutch, and 3) Formulate ten search queries in both Dutch, English and French (10 pairs of query and language for each language). These queries should be designed in such a way that if they were entered into a BPMN search engine, the given BPMN diagram would be among the top results. The queries should be closely related to the unique processes and features described in the BPMN file."
#processed_files = process_folder(system_message, prompt_template, 'data/bpmn')

# %%
# Convert to pandas dataframe
import pandas as pd


# Process all BPMN files in the folder
system_message = "You are an AI model trained to analyze text extracted from BPMN files and generate relevant natural language questions about the process described in the file. Your task is to generate 5 questions in Dutch that would lead to the process or one of its subprocesses if entered into a BPMN search engine."
prompt_template = """
The following text is extracted from a BPMN file: \"{bpmn_xml}\". 
Please analyze the text and generate 10 natural language questions in Dutch. 
These questions should be designed in such a way that if they were entered into a BPMN search engine, 
the given BPMN diagram or one of its subprocesses would be among the top results. 

The questions could start with phrases like:
- 'Geef mij een BPMN over ...'
- 'Ik zoek een procesdiagram dat ... betreft'
-  ...

The output should be a JSON object with the following structure:

{{
    "questions": [
        "Question 1",
        "Question 2",
        "Question 3",
        ...
    ]
}}
"""
processed_files = process_folder(system_message, prompt_template, 'data/bpmn')


processed_files_formatted = {}

for file, data in processed_files.items():
    processed_files_formatted[file] = {
        'keywords': [],
        'description': "",
        'queries': [{"query": query, "language": "Dutch"} for query in data["questions"]]
    }


# Create dataframe use key as the 'file' column
df = pd.DataFrame(processed_files_formatted).T

# Rename the index column to 'file'
df.index.name = 'file'

df.to_csv('data/bpmn/data_extraction/openai_keywords_search_queries.02.csv')
# Out:
# Processing file: data/bpmn\dispatch.bpmn
# {
#     "questions": [
#         "Geef mij een BPMN over de verzending van goederen door een computerhardwarewinkel.",
#         "Ik zoek een procesdiagram dat betrekking heeft op het verzekeren van pakketten.",
#         "Toon mij een BPMN-diagram met een proces voor het schrijven van verzendlabels.",
#         "Geef mij een BPMN over de selectie van logistieke bedrijven en het plaatsen van bestellingen.",
#         "Ik zoek een procesdiagram dat betrekking heeft op het voorbereiden van goederen voor verzending.",
#         "Toon mij een BPMN-diagram met een proces voor het verkrijgen van offertes van logistieke bedrijven.",
#         "Geef mij een BPMN over het verpakken van goederen in een magazijn.",
#         "Ik zoek een procesdiagram dat betrekking heeft op het bepalen van de verzendmethode.",
#         "Toon mij een BPMN-diagram met een proces voor het afhandelen van speciale verzendingen.",
#         "Geef mij een BPMN over het voorbereiden van een zending voor afhaling."
#     ]
# }
# Processing file: data/bpmn\hoofdprocesProcesMelding.bpmn
# {
#     "questions": [
#         "Geef mij een BPMN over het hoofdproces 'Proces Melding'.",
#         "Ik zoek een procesdiagram dat betrekking heeft op 'Behandel melding'.",
#         "Toon me een BPMN-diagram waarin 'Verstuur notificatie vraag tot aanpassing' voorkomt.",
#         "Geef mij een BPMN over 'Vul meldingsformulier in'.",
#         "Ik zoek een procesdiagram dat 'Verstuur ontvangstbevestiging naar melder' bevat.",
#         "Toon me een BPMN-diagram waarin 'Aanvraag ingediend' voorkomt.",
#         "Geef mij een BPMN over 'Pas meldingsformulier aan'.",
#         "Ik zoek een procesdiagram dat 'Verstuur notificatie nieuwe melding naar MC' bevat.",
#         "Toon me een BPMN-diagram waarin 'Verstuur mail herclassificatie' voorkomt.",
#         "Geef mij een BPMN over 'Haal logindata op'."
#     ]
# }
# Processing file: data/bpmn\Jeugd-Fuifkwaliteitslabel-aanvraag-Poperinge_v0.1.bpmn
# {
#     "questions": [
#         "Geef mij een BPMN over het evalueren van een aanvraag",
#         "Ik zoek een procesdiagram dat het invullen van een aanvraagformulier betreft",
#         "Toon mij een BPMN-diagram met een exclusieve gateway genaamd 'Compleet?'",
#         "Geef mij een BPMN over het berekenen van punten en het maken van een rangschikking",
#         "Ik zoek een procesdiagram dat de evaluatie van verantwoordingsstukken betreft",
#         "Toon mij een BPMN-diagram met een activiteit genaamd 'Uitbetalen aan organisatoren'",
#         "Geef mij een BPMN over het op de hoogte brengen van organisatoren",
#         "Ik zoek een procesdiagram dat een startgebeurtenis heeft genaamd '1 maand voor de fuif'",
#         "Toon mij een BPMN-diagram met een handmatige taak genaamd 'Op agenda plaatsen van CBS'",
#         "Geef mij een BPMN over het aanvullen van informatie op een evaluatieformulier"
#     ]
# }
# Processing file: data/bpmn\Jeugd-Kadervormingsubsidieaanvraag-Poperinge_v0.1.bpmn
# {
#     "questions": [
#         "Geef mij een BPMN over het indienen van een aanvraagformulier",
#         "Ik zoek een procesdiagram dat betrekking heeft op het aanvullen van bewijzen kadervorming",
#         "Geef mij een BPMN over het evalueren van aanvraagformulieren",
#         "Ik zoek een procesdiagram dat de uitbetaling aan jongeren of verenigingen betreft",
#         "Geef mij een BPMN over het berekenen van bedragen",
#         "Ik zoek een procesdiagram dat de evaluatie en goedkeuring van aanvragen betreft",
#         "Geef mij een BPMN over het plaatsen van een onderwerp op de agenda van CBS",
#         "Ik zoek een procesdiagram dat een exclusieve gateway voor goedkeuring bevat",
#         "Geef mij een BPMN over de verwerking van gegevens door de jeugd- en financiële dienst",
#         "Ik zoek een procesdiagram dat een handmatige taak voor het evalueren van aanvraagformulieren betreft"
#     ]
# }
# Processing file: data/bpmn\Jeugd-Project-subsidieaanvraag-Poperinge_v0.1.bpmn
# {
#     "questions": [
#         "Geef mij een BPMN over het invullen van een aanvraagformulier",
#         "Ik zoek een procesdiagram dat de evaluatie van een aanvraag beschrijft",
#         "Welke BPMN beschrijft het indienen van verantwoordingsstukken?",
#         "Toon mij een BPMN-diagram met een exclusieve gateway voor de vraag 'Compleet?'",
#         "Geef mij een BPMN over het aanvullen van informatie voor verantwoordingsstukken",
#         "Ik zoek een procesdiagram dat de evaluatie van verantwoordingsstukken betreft",
#         "Welke BPMN beschrijft het berekenen van totalen per organisator?",
#         "Toon mij een BPMN-diagram met een taak voor het op de hoogte brengen van de organisator",
#         "Geef mij een BPMN over de evaluatie en goedkeuring van een project",
#         "Ik zoek een procesdiagram dat het uitbetalen aan de organisator beschrijft"
#     ]
# }
# Processing file: data/bpmn\Jeugd-subsidieaanvraag-Poperinge_v0.1.bpmn
# {
#     "questions": [
#         "Geef mij een BPMN over subsidieaanvraag communicatie naar verenigingen.",
#         "Ik zoek een procesdiagram dat de evaluatie van vereniging dossier/subsidie betreft.",
#         "Toon mij een BPMN-diagram met de taak 'Invullen werkingssubsidie'.",
#         "Hoe ziet het proces eruit dat begint met 'StartEvent_020hdqw'?",
#         "Welke stappen zijn er in het proces 'Evaluatie en goedkeuring'?",
#         "Geef mij een BPMN-diagram met de activiteit 'Vereniging op de hoogte brengen'.",
#         "Ik zoek een diagram over het berekenen van totalen per vereniging.",
#         "Toon mij een proces waarin 'Uitbetalen aan vereniging' voorkomt.",
#         "Wat zijn de stappen in het proces van 'Op agenda plaatsen van CBS'?",
#         "Hoe is het proces opgebouwd dat eindigt met 'EndEvent_1t9fyic'?"
#     ]
# }
# Processing file: data/bpmn\Jeugd-verenigingen-met-specifieke-doelgroep-subsidie-Poperinge_v0.1.bpmn
# {
#     "questions": [
#         "Geef mij een BPMN over het indienen van facturen",
#         "Ik zoek een procesdiagram dat de evaluatie van facturen betreft",
#         "Toon mij een BPMN waarin bedragen op de agenda van CBS worden geplaatst",
#         "Ik zoek een BPMN-diagram over het uitbetalen aan verenigingen",
#         "Geef mij een procesdiagram over het berekenen van bedragen",
#         "Toon mij een BPMN over het aanvullen van informatie of facturen",
#         "Ik zoek een procesdiagram waarin verenigingen op de hoogte worden gebracht van beslissingen",
#         "Geef mij een BPMN over de communicatie van subsidieaanvragen naar verenigingen",
#         "Toon mij een BPMN waarin de evaluatie en goedkeuring van een proces plaatsvindt",
#         "Ik zoek een procesdiagram waarin een milieuraad betrokken is"
#     ]
# }
# Processing file: data/bpmn\Klachten-Heuvelland.bpmn
# {
#     "questions": [
#         "Geef mij een BPMN over het indienen van een webformulier klachten",
#         "Ik zoek een procesdiagram dat de evaluatie van een klacht betreft",
#         "Toon mij een BPMN met een exclusieve gateway genaamd 'Is een melding of klacht?'",
#         "Ik zoek een BPMN over het registreren van een klacht in het klachtenregister",
#         "Geef mij een procesdiagram over het versturen van een ontvangstmelding klacht",
#         "Toon mij een BPMN met het proces 'Vraag om verduidelijking klacht'",
#         "Ik zoek een BPMN over het behandelen van een antwoord op een klacht",
#         "Geef mij een procesdiagram over het opstellen van een brief met antwoord op klacht",
#         "Toon mij een BPMN dat de taak 'Onderzoeken klacht' bevat",
#         "Ik zoek een BPMN over het versturen van een brief met antwoord op een klacht"
#     ]
# }
# Processing file: data/bpmn\Klachten-Kortemark.bpmn
# {
#     "questions": [
#         "Geef mij een BPMN over het indienen van een webformulier klachten.",
#         "Ik zoek een procesdiagram dat de evaluatie van een klacht betreft.",
#         "Toon mij een BPMN-diagram waarin een klacht wordt geregistreerd in het klachtenregister.",
#         "Geef mij een BPMN over het versturen van een brief met antwoord op een klacht.",
#         "Ik zoek een BPMN-diagram dat de registratie van een klacht in e-bestuur betreft.",
#         "Toon mij een BPMN-diagram over het versturen van onontvankelijkheid en redenen naar de melder.",
#         "Geef mij een BPMN over de vraag of een klacht ontvankelijk is.",
#         "Ik zoek een procesdiagram dat de behandeling van een klacht als melding betreft.",
#         "Toon mij een BPMN-diagram waarin een klacht wordt doorgegeven aan de klachtencoördinator.",
#         "Geef mij een BPMN over het indienen van een klacht via een mail."
#     ]
# }
# Processing file: data/bpmn\klachtenbehandeling.bpmn
# Error processing file: data/bpmn\klachtenbehandeling.bpmn
# Error code: 400 - {'error': {'message': "Invalid 'messages[1].content': string too long. Expected a string with maximum length 1048576, but got a string with length 1940779 instead.", 'type': 'invalid_request_error', 'param': 'messages[1].content', 'code': 'string_above_max_length'}}
# Processing file: data/bpmn\Meldingen-Heuvelland.bpmn
# {
#     "questions": [
#         "Geef mij een BPMN over het evalueren van meldingen via telefoon",
#         "Ik zoek een procesdiagram dat het doorverbinden van een telefoon naar een dienst betreft",
#         "Geef mij een BPMN over het maken van een werkopdracht in 3P",
#         "Ik zoek een procesdiagram dat de communicatie naar burgers over het oppakken van meldingen betreft",
#         "Geef mij een BPMN over het invullen van een meldingsformulier op een website",
#         "Ik zoek een procesdiagram dat het scannen van berichten op de Facebook-pagina van de gemeente betreft",
#         "Geef mij een BPMN over het doorsturen van een Facebook-bericht naar een dienst",
#         "Ik zoek een procesdiagram dat het behandelen van een melding door een dienst betreft",
#         "Geef mij een BPMN over het plaatsen van een bericht op de Facebook-pagina van de gemeente",
#         "Ik zoek een procesdiagram dat het beantwoorden van een Facebook-bericht betreft"
#     ]
# }
# Processing file: data/bpmn\Meldingen-Kortemark.bpmn
# {
#     "questions": [
#         "Geef mij een BPMN over het invullen van een meldingsformulier op de website",
#         "Ik zoek een procesdiagram dat de evaluatie van een melding via mail betreft",
#         "Toon mij een BPMN-diagram over het versturen van een notificatie naar de melder dat de werkopdracht afgerond is",
#         "Geef een procesdiagram over de melding aan burgemeester of schepenen",
#         "Ik ben op zoek naar een BPMN-diagram dat de uitvoering van een werkopdracht beschrijft",
#         "Toon een BPMN over het doorgeven van een melding aan een andere instantie",
#         "Geef een BPMN-diagram over de evaluatie van een aanvraag",
#         "Ik zoek een procesdiagram dat de registratie van een melding in 3P betreft",
#         "Toon mij een BPMN-diagram over de afsluiting van een werkopdracht",
#         "Geef een BPMN over de evaluatie van een melding aan het loket"
#     ]
# }
# Processing file: data/bpmn\rijbewijs.bpmn
# {
#     "questions": [
#         "Geef mij een BPMN over de aanvraag van een rijbewijs",
#         "Ik zoek een procesdiagram dat de aanvraag van een voorlopig rijbewijs beschrijft",
#         "Geef mij een BPMN over de aanvraag van een internationaal rijbewijs",
#         "Ik zoek een procesdiagram dat de controle van rijbewijsgegevens omvat",
#         "Geef mij een BPMN over de controle van de geldigheid van rijbewijzen",
#         "Ik zoek een procesdiagram dat de afhandeling van rijbewijsaanvragen beschrijft",
#         "Geef mij een BPMN over het contact opnemen met de veroorzaker bij een incomplete rijbewijsaanvraag",
#         "Ik zoek een procesdiagram dat de opmaak van een rijbewijs beschrijft",
#         "Geef mij een BPMN over het melden aan de burger wanneer een rijbewijs beschikbaar is",
#         "Ik zoek een procesdiagram dat de afhandeling van internationale rijbewijsaanvragen beschrijft"
#     ]
# }
# Processing file: data/bpmn\Sport-Subsidieaanvraag-De-Panne_v0.1.bpmn
# {
#     "questions": [
#         "Geef mij een BPMN over de subsidieaanvraag communicatie naar vereniging",
#         "Ik zoek een procesdiagram dat de evaluatie van een vereniging dossier/subsidie betreft",
#         "Toon een BPMN-diagram met het proces van uitbetaling aan een vereniging",
#         "Wat is het BPMN-proces voor het invullen van een beleidssubsidie?",
#         "Geef mij een BPMN-diagram over de goedkeuring van subsidieaanvragen",
#         "Ik zoek een BPMN-diagram dat het doorgeven van toegekende bedragen aan de financiële dienst betreft",
#         "Wat is het BPMN-proces voor het evalueren van de verdeling van subsidies?",
#         "Toon een BPMN-diagram met het proces van telling van punten en verdeling van subsidiebedragen",
#         "Geef mij een BPMN over het doorsturen van verslagen naar sportverenigingen",
#         "Ik zoek een BPMN-diagram dat het proces van het plaatsen van verdeling op de agenda van de gemeenteraad betreft"
#     ]
# }
# Processing file: data/bpmn\Sport-Subsidieaanvraag-De-Panne_v0.1_translated_English.bpmn
# {
#     "questions": [
#         "Geef mij een BPMN over subsidieaanvragen communicatie naar vereniging",
#         "Ik zoek een procesdiagram dat evaluatie van verenigingsdossiers/subsidie betreft",
#         "Geef mij een BPMN over het invullen van beleidsubsidie",
#         "Ik zoek een procesdiagram dat goedkeuring van verdeling en goedkeuring betreft",
#         "Geef mij een BPMN over rapporten verzenden naar sportverenigingen",
#         "Ik zoek een procesdiagram dat het doorgeven van toegewezen bedragen aan de financiële dienst betreft",
#         "Geef mij een BPMN over betalingen aan verenigingen",
#         "Ik zoek een procesdiagram dat evaluatie van verdeling betreft",
#         "Geef mij een BPMN over het plaatsen van verdeling op de gemeenteraad agenda",
#         "Ik zoek een procesdiagram dat werken met jeugd betreft"
#     ]
# }
# Processing file: data/bpmn\Sport-Subsidieaanvraag-De-Panne_v0.1_translated_French.bpmn
# {
#     "questions": [
#         "Geef mij een BPMN over het evalueren van een subsidieaanvraag",
#         "Ik zoek een procesdiagram dat de communicatie van een subsidieaanvraag naar een vereniging betreft",
#         "Geef mij een BPMN over het goedkeuren van de verdeling van subsidies",
#         "Ik zoek een procesdiagram dat het versturen van een rapport naar sportclubs betreft",
#         "Geef mij een BPMN over het invullen van een politieke subsidie",
#         "Ik zoek een procesdiagram dat het evalueren van de dossier/subsidie van een vereniging betreft",
#         "Geef mij een BPMN over het invullen van een impulsiesubsidie",
#         "Ik zoek een procesdiagram dat het versturen van toegewezen bedragen naar de financiële dienst betreft",
#         "Geef mij een BPMN over het goedkeuren van een verdeling",
#         "Ik zoek een procesdiagram dat de betaling aan een vereniging betreft"
#     ]
# }
# Processing file: data/bpmn\Sport-Subsidieaanvraag-GrootstGemeneDeler_v0.3.bpmn
# {
#     "questions": [
#         "Geef mij een BPMN over subsidieaanvraag communicatie naar vereniging",
#         "Ik zoek een procesdiagram dat de evaluatie van een verenigingsdossier/subsidie omvat",
#         "Welke BPMN-diagram beschrijft de toewijzing van subsidiebedragen?",
#         "Toon me een BPMN-diagram waarin de sportdienst betrokken is",
#         "Geef mij een procesdiagram over de goedkeuring van subsidieaanvragen",
#         "Ik zoek een BPMN over het uitbetalen aan een vereniging",
#         "Welke BPMN-diagram bevat de activiteit 'Vereniging op de hoogte brengen'?",
#         "Geef mij een BPMN waarin een subsidieaanvraag wordt geëvalueerd en goedgekeurd",
#         "Toon me een BPMN-diagram dat de communicatie naar de financiële dienst beschrijft",
#         "Ik zoek een procesdiagram over de invulling van werkingssubsidies"
#     ]
# }

# %% [markdown]
# # Generate a textual description of the bpmn-diagram

# %%
# Define the system prompt and prompt template
system_prompt = "You are an assistant that summarizes BPMN processes."
prompt_template = "Break down the BPMN process diagram described in the following XML file into its sub-processes. Provide a detailed description in Dutch of each sub-process, focusing on the sequence of tasks, decision points, and key activities and events. Ensure clarity on the flow and purpose of each sub-process:\n\n\"{bpmn_xml}\"\n\n"
#message = f"Please summarize the BPMN process described in the following XML file:\n\n{bpmn_xml}\n\nFocus on the sequence of tasks, decision points, and key activities and events. Provide a detailed description of each step in the process, ensuring clarity on the flow and purpose of each action. The summary should be in Dutch."
#message = f"Summarize the BPMN process diagram described in the following XML file. Focus on the sequence of tasks, decision points, and key activities and events. The summary is in Dutch and provides a detailed description of each step in the process, ensuring clarity on the flow and purpose of each action:\n\n{bpmn_xml}\n\n"

# Call the process_folder function with the new system prompt and prompt template
processed_files = process_folder(system_prompt, prompt_template, 'data/bpmn')
# Out:
# Processing files:   0%|          | 0/26 [00:00<?, ?it/s]
# Skipping file (not bpmn): data/bpmn\data_extraction
# Skipping file (exists): data/bpmn\dispatch.bpmn
# Skipping file (not bpmn): data/bpmn\dispatch.txt
# Skipping file (exists): data/bpmn\hoofdprocesProcesMelding.bpmn
# Skipping file (not bpmn): data/bpmn\hoofdprocesProcesMelding.txt
# Skipping file (exists): data/bpmn\Jeugd-Fuifkwaliteitslabel-aanvraag-Poperinge_v0.1.bpmn
# Skipping file (not bpmn): data/bpmn\Jeugd-Fuifkwaliteitslabel-aanvraag-Poperinge_v0.1.txt
# Skipping file (exists): data/bpmn\Jeugd-Kadervormingsubsidieaanvraag-Poperinge_v0.1.bpmn
# Skipping file (not bpmn): data/bpmn\Jeugd-Kadervormingsubsidieaanvraag-Poperinge_v0.1.txt
# Skipping file (exists): data/bpmn\Jeugd-Project-subsidieaanvraag-Poperinge_v0.1.bpmn
# Skipping file (not bpmn): data/bpmn\Jeugd-Project-subsidieaanvraag-Poperinge_v0.1.txt
# Skipping file (exists): data/bpmn\Jeugd-subsidieaanvraag-Poperinge_v0.1.bpmn
# Skipping file (not bpmn): data/bpmn\Jeugd-subsidieaanvraag-Poperinge_v0.1.txt
# Skipping file (exists): data/bpmn\Jeugd-verenigingen-met-specifieke-doelgroep-subsidie-Poperinge_v0.1.bpmn
# Skipping file (not bpmn): data/bpmn\Jeugd-verenigingen-met-specifieke-doelgroep-subsidie-Poperinge_v0.1.txt
# Skipping file (exists): data/bpmn\Klachten-Heuvelland.bpmn
# Skipping file (not bpmn): data/bpmn\Klachten-Heuvelland.txt
# Skipping file (exists): data/bpmn\Klachten-Kortemark.bpmn
# Skipping file (not bpmn): data/bpmn\Klachten-Kortemark.txt
# Processing file: data/bpmn\klachtenbehandeling.bpmn
# Processing files:  77%|███████▋  | 20/26 [00:03<00:01,  5.14it/s]
# Error processing file: data/bpmn\klachtenbehandeling.bpmn
# Error code: 400 - {'error': {'message': "This model's maximum context length is 128000 tokens. However, your messages resulted in 723641 tokens. Please reduce the length of the messages.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Processing file: data/bpmn\Meldingen-Heuvelland.bpmn
# Processing files:  81%|████████  | 21/26 [01:35<00:31,  6.27s/it]
# Processing file: data/bpmn\Meldingen-Kortemark.bpmn
# Processing files:  85%|████████▍ | 22/26 [03:01<00:52, 13.24s/it]
# Processing file: data/bpmn\rijbewijs.bpmn
# Processing files:  88%|████████▊ | 23/26 [04:44<01:09, 23.12s/it]
# Skipping file (exists): data/bpmn\Sport-Subsidieaanvraag-De-Panne_v0.1.bpmn
# Skipping file (not bpmn): data/bpmn\Sport-Subsidieaanvraag-De-Panne_v0.1.txt
# Processing file: data/bpmn\Sport-Subsidieaanvraag-GrootstGemeneDeler_v0.3.bpmn
# Processing files: 100%|██████████| 26/26 [08:25<00:00, 19.45s/it]

# %% [markdown]
# # Creating search dataset: query-bpmn pairs using the description as proxy

# %%
import pandas as pd
import ast
import random
from sentence_transformers import InputExample
from tqdm import tqdm

# Step 1: Load bpmn descriptions back into a dictionary
def load_bpmn_descriptions(folder_path):
    file_name_to_sentence = {}
    files = os.listdir(folder_path)
    for file in tqdm(files, desc="Loading BPMN descriptions"):
        file_path = os.path.join(folder_path, file)
        if file_path.lower().endswith('.txt'):
            try:
                with open(file_path, 'r') as f:
                    file_name = os.path.splitext(file)[0]
                    file_name_to_sentence[file_name+".bpmn"] = f.read()
            except Exception as e:
                print(f"Error reading file: {file_path}")
                print(e)

    return file_name_to_sentence

# Step 2: Fetch the data
def loading_bpmn_queries(file_path):
    df = pd.read_csv(file_path)
    data_dict = {}
    for _, row in tqdm(df.iterrows(), total=df.shape[0], desc="Loading BPMN queries"):
        file_name = os.path.splitext(row['file'].split('/')[-1])[0]
        keywords = ast.literal_eval(row['keywords'])
        queries = ast.literal_eval(row['queries'])
        description = row['description']
        data_dict[file_name] = {'keywords': keywords, 'queries': queries, 'description': description}

    return data_dict

# Step 3: Create positive examples
def create_positive_examples(data_dict, file_name_to_sentence):
    positive_examples = []
    for file_name, data in data_dict.items():
        if file_name in file_name_to_sentence:
            for keyword in data['keywords']:
                positive_examples.append(InputExample(texts=[keyword, file_name_to_sentence[file_name]], label=1))
            for query in data['queries']:
                positive_examples.append(InputExample(texts=[query["query"], file_name_to_sentence[file_name]], label=1))
    return positive_examples

# Step 3.b: Create positive examples
def postive_queries(data_dict, file_name_to_sentence):
    positive_examples = []
    for file_name, data in data_dict.items():
        if file_name in file_name_to_sentence:
            for query in data['queries']:
                positive_examples.append({'query': query["query"],
                                           "content": file_name_to_sentence[file_name],
                                           'meta':{"type": "query", "language": query["language"], "file": file_name, "label": True}})
    return positive_examples

# Step 4: Create negative examples
def create_negative_examples(data_dict, file_name_to_sentence, num_negative_examples):
    negative_examples = []
    for file_name, data in data_dict.items():
        if file_name in file_name_to_sentence:
            other_file_names = [other_file for other_file in file_name_to_sentence.keys() if other_file != file_name]
            for _ in range(num_negative_examples):
                negative_file_name = random.choice(other_file_names)
                for keyword in data['keywords']:
                    negative_examples.append(InputExample(texts=[keyword, file_name_to_sentence[negative_file_name]], label=0))
                for query in data['queries']:
                    negative_examples.append(InputExample(texts=[query["query"], file_name_to_sentence[negative_file_name]], label=0))
                negative_examples.append(InputExample(texts=[data['description'], file_name_to_sentence[negative_file_name]], label=0))
    return negative_examples

# Step 4.b: Create negative queries
def negative_queries(data_dict, file_name_to_sentence, num_negative_examples):
    negative_examples = []
    for file_name, data in data_dict.items():
        if file_name in file_name_to_sentence:
            other_file_names = [other_file for other_file in file_name_to_sentence.keys() if other_file != file_name]
            
            for query in data['queries']:
                for _ in range(num_negative_examples):
                    negative_file_name = random.choice(other_file_names)
                    negative_examples.append({'query': query["query"], 
                                              "content": file_name_to_sentence[negative_file_name],
                                                'meta':{"type": "query", "language": query["language"], "file": negative_file_name, "label": False}})
    return negative_examples

# Fetch the data
bpmn_descriptions = load_bpmn_descriptions('data/bpmn/descriptions')
bpmn_queries = loading_bpmn_queries('data/bpmn/data_extraction/openai_keywords_search_queries.02.csv')

# Create positive and negative examples
#positive_examples = create_positive_examples(bpmn_queries, bpmn_descriptions)
#negative_examples = create_negative_examples(bpmn_queries, bpmn_descriptions, num_negative_examples=1)

# Create positive and negative queries
positive_queries = postive_queries(bpmn_queries, bpmn_descriptions)
negative_queries = negative_queries(bpmn_queries, bpmn_descriptions, num_negative_examples=4)

# Combine positive and negative queries
training_data = positive_queries + negative_queries

# Logging the number of positive and negative examples
num_positive_examples = len(positive_queries)
num_negative_examples = len(negative_queries)
print(f"Number of positive queries: {num_positive_examples}")
print(f"Number of negative queries: {num_negative_examples}")
print(f"Total number of training queries: {len(training_data)}")

save_version_controlled_file(training_data, base_filename='prodigy_bpmn_search', extension='jsonl')
# Out:
# Loading BPMN descriptions: 100%|██████████| 15/15 [00:00<00:00, 114.67it/s]
# Loading BPMN queries: 100%|██████████| 16/16 [00:00<00:00, 3193.99it/s]
# Number of positive queries: 140
# Number of negative queries: 560
# Total number of training queries: 700
# 'bpmn_search_dataset_01.jsonl'

# %%
# sample the training data
import random
random.shuffle(training_data)
training_data = training_data[:5]

# Display the training data
for example in training_data:
    print(example)
# Out:
# {'query': 'Ik zoek een procesdiagram dat betrekking heeft op het aanvullen van bewijzen kadervorming', 'content': 'De BPMN-procesdiagram beschreven in het XML-bestand bevat verschillende sub-processen die zijn verdeeld over verschillende banen (lanes). Hieronder volgt een gedetailleerde beschrijving van elk sub-proces in het Nederlands, met aandacht voor de volgorde van taken, beslissingspunten en belangrijke activiteiten en gebeurtenissen:\n\n### Sub-proces 1: Aanvraagproces\n**Baan:** Lane_0yge0ax\n1. **Start van het proces:** Het proces begint met een startevenement.\n2. **Indienen aanvraagformulier:** Een gebruikerstaak waarbij een aanvraagformulier wordt ingediend.\n3. **Aanvullen bewijzen kadervorming:** Na het indienen van het aanvraagformulier, als er aanvullende bewijzen nodig zijn voor de kadervorming, wordt deze taak uitgevoerd.\n\n### Sub-proces 2: Evaluatieproces\n**Baan:** Lane_0fpfr75\n1. **Evalueren aanvraagformulieren:** Een handmatige taak waarbij de ingediende aanvraagformulieren worden geëvalueerd.\n2. **Beslissingspunt - Compleet:** Een exclusieve gateway die controleert of de aanvraag compleet is. Indien ja, gaat het proces verder naar het berekenen van bedragen, indien nee, gaat het terug naar het aanvullen van bewijzen.\n3. **Berekenen bedragen:** Een zakelijke regeltaak waarbij de bedragen worden berekend op basis van de ingediende gegevens.\n4. **Op agenda plaatsen van CBS:** Een handmatige taak waarbij de aanvraag op de agenda van het CBS wordt geplaatst voor verdere evaluatie en goedkeuring.\n\n### Sub-proces 3: Goedkeuringsproces\n**Baan:** Lane_03on54b\n1. **Evaluatie en goedkeuring:** Een taak waarbij de aanvraag wordt geëvalueerd en al dan niet wordt goedgekeurd.\n2. **Beslissingspunt - Goedgekeurd:** Een exclusieve gateway die bepaalt of de aanvraag is goedgekeurd. Indien ja, gaat het proces verder naar het uitbetalen aan de jongere of vereniging, indien nee, gaat het terug naar het evalueren van de aanvraagformulieren.\n\n### Sub-proces 4: Uitbetalingsproces\n**Baan:** Lane_01e2b99\n1. **Uitbetalen aan jongere of vereniging:** Een gebruikerstaak waarbij de goedgekeurde bedragen worden uitbetaald aan de jongere of de vereniging.\n2. **Einde van het proces:** Het proces eindigt met een eindgebeurtenis nadat de betalingen zijn uitgevoerd.\n\nElk van deze sub-processen is essentieel voor het beheer van aanvragen binnen de organisatie, van het indienen en evalueren van aanvragen tot de uiteindelijke goedkeuring en uitbetaling. De beslissingspunten (gateways) zorgen ervoor dat de aanvragen correct en volledig zijn voordat ze verder worden verwerkt, wat bijdraagt aan de efficiëntie en effectiviteit van het proces.', 'meta': {'type': 'query', 'language': 'Dutch', 'file': 'Jeugd-Kadervormingsubsidieaanvraag-Poperinge_v0.1', 'label': True}}
# {'query': 'Geef een BPMN-diagram over de evaluatie van een aanvraag', 'content': 'De BPMN-procesdiagram beschreven in het XML-bestand bevat verschillende sub-processen die samen een complex proces vormen voor het behandelen van klachten en meldingen binnen een organisatie. Hieronder volgt een gedetailleerde beschrijving van elk sub-proces, gericht op de volgorde van taken, beslissingspunten en belangrijke activiteiten en gebeurtenissen:\n\n### 1. Start van het proces\n- **StartEvent_1**: Het proces begint met een startevenement waarbij een klacht wordt ingediend.\n- **Activity_13ouyfg (Indienen webformulier klachten)**: De klager dient een klacht in via een webformulier.\n\n### 2. Evaluatie van de klacht\n- **Activity_02e0a29 (Evaluatie klacht)**: Na het indienen van de klacht wordt deze geëvalueerd om te bepalen of het een melding of een klacht betreft.\n- **Gateway_16s0eb3 (Is een melding of klacht?)**: Afhankelijk van de evaluatie wordt besloten of het proces verder gaat als een melding of als een klacht.\n\n### 3. Behandeling als melding\n- **Activity_19154ou (Behandel verder als melding)**: Als het een melding is, wordt deze verder behandeld volgens een specifiek subproces voor meldingen.\n- **Event_1wf0u5q**: Het subproces eindigt met een eindgebeurtenis.\n\n### 4. Registratie en verdere behandeling van de klacht\n- **Activity_0dsk5lq (Klacht registreren in klachtenregister)**: Als het een klacht is, wordt deze geregistreerd in het klachtenregister.\n- **Activity_0rykv92 (Klacht registreren in e-bestuur)**: De klacht wordt ook geregistreerd in een elektronisch bestuurssysteem.\n- **Gateway_0agv90p (Klacht ontvankelijk)**: Er wordt bepaald of de klacht ontvankelijk is.\n- **Activity_1sss3wd (Versturen onontvankelijkheid en redenen naar melder)**: Als de klacht niet ontvankelijk is, worden de redenen naar de melder verstuurd.\n- **Event_0rtldmo**: Het subproces eindigt met een eindgebeurtenis als de klacht niet ontvankelijk is.\n\n### 5. Verdere afhandeling van een ontvankelijke klacht\n- **Gateway_0bkydwh (Van wie is klacht en over wie?)**: Afhankelijk van over wie de klacht gaat, wordt een passende klachtenbehandelaar aangewezen.\n- **Activity_07yd6vn, Activity_1jzf7dr, Activity_14eaj22**: Afhankelijk van de aard van de klacht wordt een diensthoofd, de algemeen directeur of het college van burgemeester en schepenen aangewezen als klachtenbehandelaar.\n- **Activity_0qbfin9 (Klacht doorsturen naar klachtenbehandelaar)**: De klacht wordt doorgestuurd naar de aangewezen klachtenbehandelaar.\n\n### 6. Onderzoek en afhandeling door de klachtenbehandelaar\n- **Activity_15y3jnq (Onderzoeken klacht)**: De klachtenbehandelaar onderzoekt de klacht.\n- **Activity_0f2yk70 (Verslag opmaken)**: Er wordt een verslag opgemaakt van het onderzoek.\n- **Event_1h9nxt0 (Binnen 20 dagen na doorgeven klacht)**: Binnen 20 dagen moet het verslag klaar zijn en doorgestuurd worden naar de klachtencoördinator.\n- **Activity_1umijcc (Verslag sturen naar klachtencoördinator)**: Het verslag wordt naar de klachtencoördinator gestuurd.\n- **Activity_1hnvlcl (Antwoord op klacht behandelen)**: Het antwoord op de klacht wordt behandeld.\n- **Activity_1dj5fjh (Opstellen brief met antwoord op klacht)**: Er wordt een brief opgesteld met het antwoord op de klacht.\n- **Event_0y4hste (Binnen 5 werkdagen na ontvangen eindverslag)**: Binnen 5 werkdagen na het ontvangen van het eindverslag moet de brief verstuurd zijn.\n- **Activity_05bg88f (Versturen brief met antwoord op klacht)**: De brief met het antwoord op de klacht wordt verstuurd.\n- **Event_1sh8q78**: Het subproces eindigt met een eindgebeurtenis.\n\nDit proces zorgt ervoor dat klachten en meldingen systematisch en efficiënt worden behandeld, waarbij elke stap zorgvuldig wordt gedocumenteerd en gevolgd, van ontvangst tot afhandeling.', 'meta': {'type': 'query', 'language': 'Dutch', 'file': 'Klachten-Kortemark', 'label': False}}
# {'query': 'Toon een BPMN-diagram met het proces van telling van punten en verdeling van subsidiebedragen', 'content': 'De BPMN-procesdiagram beschreven in het XML-bestand bevat verschillende subprocessen, verdeeld over meerdere banen (lanes). Hieronder volgt een gedetailleerde beschrijving van elk subprocess in het Nederlands, gericht op de volgorde van taken, beslissingspunten en belangrijke activiteiten en gebeurtenissen:\n\n### Subproces 1: Start en Communicatie Subsidieaanvraag\n- **StartEvent_020hdqw**: Het proces begint met een startevenement.\n- **Activity_1c3d5wv**: Een verzendtaak genaamd "Subsidieaanvraag communicatie naar vereniging" wordt uitgevoerd. Dit houdt in dat er communicatie plaatsvindt naar de vereniging over de subsidieaanvraag.\n\n### Subproces 2: Invullen Subsidies\n- **Activity_034qtmd**: Een gebruikerstaak "Invullen beleidssubsidie" waarbij beleidssubsidie formulieren worden ingevuld.\n- **Gateway_0thyowe**: Een exclusieve gateway "Werken met jeugd" die bepaalt of de volgende taak gericht is op jeugdwerk.\n- **Activity_033151x**: Als de gateway besluit dat het jeugdwerk betreft, wordt de gebruikerstaak "Invullen impulssubsidie" uitgevoerd.\n\n### Subproces 3: Evaluatie en Verdeling\n- **Activity_1rbcl6h**: Een handmatige taak "Evalueren vereniging dossier/subsidie" waarbij het dossier en de subsidie van de vereniging worden geëvalueerd.\n- **Activity_1alfwiw**: Een bedrijfsregeltaak "Telling punten en verdeling subsidiebedragen" waarbij punten worden geteld en subsidiebedragen worden verdeeld.\n- **Activity_1sykbht**: Een handmatige taak "Evalueren verdeling" waarbij de verdeling van subsidies wordt geëvalueerd.\n- **Gateway_0t9ipo1**: Een exclusieve gateway "Goedgekeurd?" die bepaalt of de verdeling is goedgekeurd.\n\n### Subproces 4: Communicatie en Uitbetaling\n- **Activity_1px5vj5**: Een verzendtaak "Verslag doorsturen naar sportverenigingen" waarbij een verslag naar sportverenigingen wordt gestuurd.\n- **Activity_1qzavjs**: Een verzendtaak "Doorgeven toegekende bedragen aan financiële dienst" waarbij toegekende bedragen aan de financiële dienst worden doorgegeven.\n- **Activity_180syoq**: Een gebruikerstaak "Uitbetaling aan vereniging" waarbij de uitbetaling aan de vereniging wordt gedaan.\n- **EndEvent_1lpxo1d**: Het proces eindigt met een eindgebeurtenis.\n\n### Subproces 5: Evaluatie en Goedkeuring\n- **Activity_06d7dwp**: Een handmatige taak "Evalueren verdeling en goedkeuren" waarbij de verdeling wordt geëvalueerd en goedgekeurd.\n- **Gateway_11etuxr**: Een exclusieve gateway "Goedgekeurd?" die bepaalt of de evaluatie en verdeling zijn goedgekeurd.\n\n### Subproces 6: Agenda en Gemeenteraad\n- **Task_0wfdyxr**: Een taak "Verdeling op agenda plaatsen van gemeenteraad" waarbij de verdeling op de agenda van de gemeenteraad wordt geplaatst.\n\nDeze subprocessen vormen samen een complex proces waarbij verschillende taken en beslissingen worden genomen om subsidies te beheren en te verdelen onder verenigingen, met evaluaties en goedkeuringen op verschillende niveaus.', 'meta': {'type': 'query', 'language': 'Dutch', 'file': 'Sport-Subsidieaanvraag-De-Panne_v0.1', 'label': True}}
# {'query': "Toon mij een BPMN met een exclusieve gateway genaamd 'Is een melding of klacht?'", 'content': 'De BPMN-procesdiagram beschreven in het XML-bestand bevat verschillende sub-processen die zijn verdeeld over meerdere banen (lanes). Hieronder volgt een gedetailleerde beschrijving van elk sub-proces, gericht op de volgorde van taken, beslissingspunten en belangrijke activiteiten en gebeurtenissen:\n\n### Sub-proces 1: Start en Communicatie Subsidieaanvraag\n- **StartEvent (StartEvent_020hdqw)**: Het proces begint met een startevenement.\n- **SendTask (Activity_1c3d5wv, "Subsidieaanvraag communicatie naar verenigingen")**: Na het startevenement wordt een communicatie naar verenigingen gestuurd over de subsidieaanvraag.\n\n### Sub-proces 2: Evaluatie en Besluitvorming\n- **ManualTask (Activity_1rbcl6h, "Evalueren vereniging dossier/subsidie")**: De subsidieaanvragen worden geëvalueerd.\n- **ExclusiveGateway (Gateway_1jv3xum, "Compleet")**: Er wordt besloten of de informatie compleet is.\n  - **Ja**: Gaat naar Task_0g7p5xc, "Evaluatie onduidelijkheden en toegekende bedragen".\n  - **Nee**: Gaat naar UserTask (Activity_1r7w29n, "Aanvullen informatie vereniging/dossier/subsidie").\n\n### Sub-proces 3: Verwerking en Goedkeuring\n- **ManualTask (Activity_06d7dwp, "Evaluatie en goedkeuring")**: De volledigheid van de dossiers wordt geëvalueerd en goedgekeurd.\n- **ExclusiveGateway (Gateway_11etuxr, "Goedgekeurd?")**: Beslissing of de subsidie wordt goedgekeurd.\n  - **Ja**: Gaat naar UserTask (Activity_180syoq, "Uitbetalen aan vereniging").\n  - **Nee**: Gaat terug naar ManualTask (Activity_1rbcl6h, "Evalueren vereniging dossier/subsidie").\n\n### Sub-proces 4: Uitbetaling en Afsluiting\n- **UserTask (Activity_180syoq, "Uitbetalen aan vereniging")**: De goedgekeurde subsidies worden uitbetaald aan de verenigingen.\n- **EndEvent (EndEvent_0t5hapu)**: Het proces eindigt na de uitbetaling.\n\n### Sub-proces 5: Informatie Aanvulling en Notificatie\n- **UserTask (Activity_034qtmd, "Invullen werkingssubsidie")**: Informatie over de werkingssubsidie wordt ingevuld.\n- **SendTask (Activity_0hsdt5f, "Vereniging op de hoogte brengen")**: De vereniging wordt op de hoogte gebracht van de beslissing.\n- **EndEvent (EndEvent_1t9fyic)**: Het proces eindigt na de notificatie.\n\n### Sub-proces 6: Berekening en Agenda Plaatsing\n- **Task (Task_0g7p5xc, "Evaluatie onduidelijkheden en toegekende bedragen")**: Onduidelijkheden en toegekende bedragen worden geëvalueerd.\n- **BusinessRuleTask (Activity_1alfwiw, "Berekenen totalen per vereniging")**: Totalen per vereniging worden berekend.\n- **ManualTask (ManualTask_0hs58qz, "Op agenda plaatsen van CBS")**: De resultaten worden op de agenda van het CBS geplaatst.\n\nElk van deze sub-processen draagt bij aan het algehele doel van het beheren en toewijzen van subsidies aan verenigingen, waarbij elke stap zorgt voor de juiste evaluatie, besluitvorming en communicatie.', 'meta': {'type': 'query', 'language': 'Dutch', 'file': 'Jeugd-subsidieaanvraag-Poperinge_v0.1', 'label': False}}
# {'query': 'Toon mij een BPMN-diagram over de afsluiting van een werkopdracht', 'content': "De BPMN-procesdiagram beschreven in het XML-bestand bevat verschillende sub-processen, elk met specifieke taken, beslissingspunten en sleutelactiviteiten. Hieronder volgt een gedetailleerde beschrijving van enkele belangrijke sub-processen in het Nederlands:\n\n### 1. Meldingsproces\nDit sub-proces begint met een startevenement en omvat verschillende manieren waarop een melding kan worden ingediend:\n- **Invullen meldingsformulier op website**: De gebruiker vult een formulier in op de website. Dit is de start van het proces na het startevenement.\n- **Telefoon naar onthaal**: Een alternatieve route waarbij de melder telefonisch contact opneemt.\n- **Mail naar info@**: Nog een alternatieve route waarbij de melder een e-mail stuurt.\n- **Melding aan het loket**: Een persoonlijke manier waarop een melding kan worden gedaan bij een fysiek loket.\n\nElk van deze invoerwegen leidt tot een evaluatie van de melding, waarbij besloten wordt of de melding voor een andere instantie is bedoeld.\n\n### 2. Evaluatie en Routing\nNa de initiële melding worden de volgende stappen ondernomen:\n- **Evaluatie melding mail/loket/telefoon**: Afhankelijk van de invoermethode wordt de melding geëvalueerd.\n- **Beslissingspunt 'Melding is zeker voor andere instantie?'**: Hier wordt besloten of de melding moet worden doorgezet naar een andere instantie.\n- **Routing van de melding**: Afhankelijk van de beslissing wordt de melding doorgegeven aan de juiste instantie of geregistreerd in het systeem voor verdere verwerking.\n\n### 3. Verwerking en Afhandeling\nNa de evaluatie en eventuele registratie in het systeem volgen verdere stappen:\n- **Bestaat de melding al in 3P?**: Controle of de melding al bekend is in het systeem.\n- **Melding registreren in 3P**: Als de melding nieuw is, wordt deze geregistreerd.\n- **Melding doorgeven aan andere instantie**: Als besloten is dat de melding voor een andere instantie is, wordt deze doorgegeven.\n\n### 4. Afsluiting en Notificatie\nAan het einde van het proces zijn er verschillende afsluitende taken:\n- **Notificatie naar melder dat werkopdracht afgerond is**: De melder wordt geïnformeerd over de afronding van de werkzaamheden.\n- **Notificatie niet terechte melding naar melder met reden**: Als een melding niet terecht was, wordt de melder hiervan op de hoogte gesteld met de reden.\n- **Uitvoering werkopdracht**: De daadwerkelijke uitvoering van de werkzaamheden indien de melding terecht was.\n\nElk van deze subprocessen bevat specifieke taken die zijn ontworpen om de workflow van meldingen efficiënt te beheren, van ontvangst tot afhandeling. Elk beslissingspunt zorgt ervoor dat de melding correct wordt gerouteerd en verwerkt volgens de vastgestelde procedures.", 'meta': {'type': 'query', 'language': 'Dutch', 'file': 'Meldingen-Kortemark', 'label': True}}

# %% [markdown]
# # using gpt-4o for predicting if the query relates to the document

# %%
import json
import openai
from typing import List, Dict

def load_queries(file_path: str) -> List[Dict]:
    queries = []
    try:
        with open(file_path, 'r') as file:
            for line in file:
                queries.append(json.loads(line))
    except FileNotFoundError:
        print(f"File {file_path} not found.")
    except json.JSONDecodeError:
        print(f"Error decoding JSON from {file_path}.")
    return queries

def process_queries(queries: List[Dict], model: str, output_file: str, skips = 0, n_queries: int = 20) -> List[Dict]:
    from tqdm import tqdm
    import time

    processed_queries = []
    for query in tqdm(queries[skips:skips + n_queries], desc="Processing queries"):
        prompt = f"Evaluate whether the following query is related to the document content. Query: '{query['query']}'. Document: '{query['content']}'. If the query is related, respond with a JSON object structured as follows: {{'related': true, 'confidence': 'high/medium/low', 'motivation': 'short explanation'}}. If the query is not related, respond with a JSON object structured as follows: {{'related': false, 'confidence': 'high/medium/low', 'motivation': 'short explanation'}}. The 'confidence' field should reflect how strongly you think the query is correlated to the document: 'high' if you think the correlation is strong, 'medium' if you think the correlation is moderate, and 'low' if you think the correlation is weak. The 'motivation' field should contain a short explanation of why you assigned the given 'confidence' level."
        try:
            response = client.chat.completions.create(
                model=model,
                response_format={"type": "json_object"},
                messages=[
                    {"role": "system", "content": "You are a language model trained by OpenAI. Your task is to determine if a given query is related to a document and respond with a structured JSON object."},
                    {"role": "user", "content": prompt},
                ],
                temperature=0.0,
            )
            query['meta']['predicted_label'] = json.loads(response.choices[0].message.content)
            processed_queries.append(query)
            
            #print(f"Processed query '{query['text']}' for file {query['meta']['file']} with response: {query['meta']['predicted_label']}")
            
            # Save the processed query to the output file
            with open(output_file, 'a') as file:
                file.write(json.dumps(query) + '\n')
            
        except openai.OpenAIError as e:
            print(f"Error processing query '{query['text']}': {str(e)}")
    return processed_queries

def relabel_queries():
    OPENAI_DEPLOYMENT_NAME_FAST = "gpt-4o"
    input_file = 'prodigy/query_dataset/prodigy_bpmn_search_02.jsonl'
    output_file = 'prodigy/query_dataset/prodigy_bpmn_search_02_prompted.jsonl'

    queries = load_queries(input_file)
    print(len(queries))
    queries = process_queries(queries, OPENAI_DEPLOYMENT_NAME_FAST, output_file, skips=0, n_queries=700)

relabel_queries()
# Out:
# 700
# Processing queries:   0%|          | 0/700 [00:00<?, ?it/s]
# Processing queries: 100%|██████████| 700/700 [49:58<00:00,  4.28s/it]

# %% [markdown]
# # Fetching the disagreements between AI and assigned labels

# %%
OPENAI_DEPLOYMENT_NAME_FAST = "gpt-4o"
input_file_01 = 'prodigy/query_dataset/prodigy_bpmn_search_02.jsonl'
output_file_02 = 'prodigy/query_dataset/prodigy_bpmn_search_02_prompted.jsonl'

queries_01 = load_queries(input_file_01)
queries_02 = load_queries(output_file_02)

#find the difference between meta.label and meta.predicted_label.related and write them to new file
diff_queries = []
for query_01, query_02 in zip(queries_01, queries_02):
    label = query_01['meta']['label']
    related = query_02['meta']['predicted_label']['related']
    
    # Map 'positive' to True and 'negative' to False
    mapping = {'positive': True, 'negative': False, True: True, False: False}

    if related != mapping[label]:
        diff_queries.append(query_02)

# Should be manually reviewed and corrected -> prodi.gy
output_file = 'prodigy/prodigy_bpmn_search_02_differences.jsonl'

with open(output_file, 'w') as file:
    for query in diff_queries:
        file.write(json.dumps(query) + '\n')

# %% [markdown]
# # merging the datasets: annotated samples and corrected samples

# %%
import json


# File paths
original_samples_file = 'prodigy/query_dataset/prodigy_bpmn_search_02_prompted.jsonl'
annotated_samples_file = 'prodigy/query_dataset/prodigy_bpmn_search_02_differences_annotated.jsonl'

# Load samples
original_samples = load_queries(original_samples_file)
annotated_samples = load_queries(annotated_samples_file)

# Mapping labels
mapping_labels = {'positive': True, 'negative': False, True: 'positive', False: 'negative'}

# Merge the processed samples
merged_samples = annotated_samples + original_samples

# Process samples
for sample in merged_samples:
    if 'answer' in sample:
        answer = sample['answer']
        related = sample['meta']['predicted_label'].get('related', False)

        if answer == 'accept':
            sample['meta']['label'] = related
        elif answer == 'reject':
            sample['meta']['label'] = not related
    else:
        if 'predicted_label' in sample['meta']:
            sample['meta']['label'] = sample['meta']['predicted_label'].get('related', False)
        else:
            print("failed to process sample: ", sample)



# Remove duplicates based on the 'text' and 'content' fields
unique_samples = []
seen = set()

for sample in merged_samples:
    # Create a tuple of the 'text' and 'content' fields
    key = (sample['query'], sample['content'])

    # If the key is not in the seen set, add it to the unique_samples list and the seen set
    if key not in seen:
        unique_samples.append(sample)
        seen.add(key)

# Define the output file path
output_file = 'prodigy/query_dataset/prodigy_bpmn_search_02_dataset.jsonl'

# Write the unique samples to the output file
with open(output_file, 'w') as f:
    for sample in unique_samples:
        json.dump(sample, f)
        f.write('\n')
